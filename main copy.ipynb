# %%
from mqt import run_mqt_bench_experiments_incremental

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQTBench',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=2,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:22: UserWarning: Mitiq import failed: No module named 'ply'. ZNE will use simplified fallback implementation.
#   warnings.warn(f"Mitiq import failed: {e}. ZNE will use simplified fallback implementation.")
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQTBench for QASM files...
# Found 3877 QASM files
#   Loading: graphstate_nativegates_ibm_qiskit_opt0_4.qasm -> graphstate_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: graphstate_nativegates_ibm_opt0_4q, depth=18
#   Loading: dj_nativegates_ibm_qiskit_opt0_8.qasm -> dj_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: dj_nativegates_ibm_opt0_8q, depth=15
#   Loading: qnn_indep_qiskit_8.qasm -> qnn_indep (8 qubits)
#     ✓ Loaded: qnn_indep_8q, depth=74
#   Loading: qaoa_indep_qiskit_6.qasm -> qaoa_indep (6 qubits)
#     ✓ Loaded: qaoa_indep_6q, depth=8
#   Loading: qpeinexact_nativegates_ibm_qiskit_opt0_2.qasm -> qpeinexact_nativegates_ibm_opt0 (2 qubits)
#     ✓ Loaded: qpeinexact_nativegates_ibm_opt0_2q, depth=10
#   Loading: qaoa_nativegates_ibm_qiskit_opt0_4.qasm -> qaoa_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: qaoa_nativegates_ibm_opt0_4q, depth=28
#   Loading: ghz_indep_qiskit_9.qasm -> ghz_indep (9 qubits)
#     ✓ Loaded: ghz_indep_9q, depth=9
#   Loading: portfoliovqe_indep_qiskit_8.qasm -> portfoliovqe_indep (8 qubits)
#     ✓ Loaded: portfoliovqe_indep_8q, depth=33
#   Loading: qpeexact_nativegates_ibm_qiskit_opt0_2.qasm -> qpeexact_nativegates_ibm_opt0 (2 qubits)
#     ✓ Loaded: qpeexact_nativegates_ibm_opt0_2q, depth=10
#   Loading: twolocalrandom_indep_qiskit_3.qasm -> twolocalrandom_indep (3 qubits)
#     ✓ Loaded: twolocalrandom_indep_3q, depth=13
#   Loading: ae_nativegates_ibm_qiskit_opt0_6.qasm -> ae_nativegates_ibm_opt0 (6 qubits)
#     ✓ Loaded: ae_nativegates_ibm_opt0_6q, depth=98
#   Loading: qpeexact_indep_qiskit_5.qasm -> qpeexact_indep (5 qubits)
#     ✓ Loaded: qpeexact_indep_5q, depth=13
#   Loading: wstate_nativegates_ibm_qiskit_opt0_5.qasm -> wstate_nativegates_ibm_opt0 (5 qubits)
#     ✓ Loaded: wstate_nativegates_ibm_opt0_5q, depth=45
#   Loading: su2random_indep_qiskit_4.qasm -> su2random_indep (4 qubits)
#     ✓ Loaded: su2random_indep_4q, depth=17
#   Loading: pricingput_nativegates_ibm_qiskit_opt0_7.qasm -> pricingput_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: pricingput_nativegates_ibm_opt0_7q, depth=273
#   Loading: vqe_nativegates_ibm_qiskit_opt0_4.qasm -> vqe_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: vqe_nativegates_ibm_opt0_4q, depth=20
#   Loading: qwalk-noancilla_indep_qiskit_7.qasm -> qwalk-noancilla_indep (7 qubits)
#     ✓ Loaded: qwalk-noancilla_indep_7q, depth=1507
#   Loading: ae_indep_qiskit_8.qasm -> ae_indep (8 qubits)
#     ✓ Loaded: ae_indep_8q, depth=41
#   Loading: twolocalrandom_nativegates_ibm_qiskit_opt0_8.qasm -> twolocalrandom_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: twolocalrandom_nativegates_ibm_opt0_8q, depth=49
#   Loading: qwalk-v-chain_nativegates_ibm_qiskit_opt0_7.qasm -> qwalk-v-chain_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: qwalk-v-chain_nativegates_ibm_opt0_7q, depth=582
#   Loading: grover-v-chain_nativegates_ibm_qiskit_opt0_2.qasm -> grover-v-chain_nativegates_ibm_opt0 (2 qubits)
#     ✓ Loaded: grover-v-chain_nativegates_ibm_opt0_2q, depth=3
#   Loading: portfoliovqe_nativegates_ibm_qiskit_opt0_10.qasm -> portfoliovqe_nativegates_ibm_opt0 (10 qubits)
#     ✓ Loaded: portfoliovqe_nativegates_ibm_opt0_10q, depth=217
#   Loading: qnn_indep_qiskit_10.qasm -> qnn_indep (10 qubits)
#     ✓ Loaded: qnn_indep_10q, depth=94
#   Loading: qft_nativegates_ibm_qiskit_opt0_8.qasm -> qft_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: qft_nativegates_ibm_opt0_8q, depth=62
#   Loading: qftentangled_indep_qiskit_6.qasm -> qftentangled_indep (6 qubits)
#     ✓ Loaded: qftentangled_indep_6q, depth=14
#   Loading: qwalk-noancilla_nativegates_ibm_qiskit_opt0_7.qasm -> qwalk-noancilla_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: qwalk-noancilla_nativegates_ibm_opt0_7q, depth=3674
#   Loading: random_nativegates_ibm_qiskit_opt0_4.qasm -> random_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: random_nativegates_ibm_opt0_4q, depth=90
#   Loading: groundstate_small_indep_qiskit_4.qasm -> groundstate_small_indep (4 qubits)
#     ✓ Loaded: groundstate_small_indep_4q, depth=12
#   Loading: portfoliovqe_nativegates_ibm_qiskit_opt0_7.qasm -> portfoliovqe_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: portfoliovqe_nativegates_ibm_opt0_7q, depth=151
#   Loading: qwalk-noancilla_nativegates_ibm_qiskit_opt0_10.qasm -> qwalk-noancilla_nativegates_ibm_opt0 (10 qubits)
#     ✓ Loaded: qwalk-noancilla_nativegates_ibm_opt0_10q, depth=30374
#   Loading: graphstate_nativegates_ibm_qiskit_opt0_8.qasm -> graphstate_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: graphstate_nativegates_ibm_opt0_8q, depth=22
#   Loading: wstate_indep_qiskit_7.qasm -> wstate_indep (7 qubits)
#     ✓ Loaded: wstate_indep_7q, depth=14
#   Loading: graphstate_indep_qiskit_3.qasm -> graphstate_indep (3 qubits)
#     ✓ Loaded: graphstate_indep_3q, depth=4
#   Loading: dj_nativegates_ibm_qiskit_opt0_4.qasm -> dj_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: dj_nativegates_ibm_opt0_4q, depth=10
#   Loading: ghz_indep_qiskit_5.qasm -> ghz_indep (5 qubits)
#     ✓ Loaded: ghz_indep_5q, depth=5
#   Loading: qaoa_nativegates_ibm_qiskit_opt0_8.qasm -> qaoa_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: qaoa_nativegates_ibm_opt0_8q, depth=28
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     ✓ Loaded: dj_indep_10q, depth=11
#   Loading: qnn_nativegates_ibm_qiskit_opt0_10.qasm -> qnn_nativegates_ibm_opt0 (10 qubits)
#     ✓ Loaded: qnn_nativegates_ibm_opt0_10q, depth=108
#   Loading: qft_indep_qiskit_7.qasm -> qft_indep (7 qubits)
#     ✓ Loaded: qft_indep_7q, depth=14
#   Loading: qpeexact_indep_qiskit_9.qasm -> qpeexact_indep (9 qubits)
#     ✓ Loaded: qpeexact_indep_9q, depth=23
#   Loading: grover-noancilla_nativegates_ibm_qiskit_opt0_3.qasm -> grover-noancilla_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: grover-noancilla_nativegates_ibm_opt0_3q, depth=29
#   Loading: portfoliovqe_indep_qiskit_4.qasm -> portfoliovqe_indep (4 qubits)
#     ✓ Loaded: portfoliovqe_indep_4q, depth=17
#   Loading: qwalk-v-chain_indep_qiskit_3.qasm -> qwalk-v-chain_indep (3 qubits)
#     ✓ Loaded: qwalk-v-chain_indep_3q, depth=19
#   Loading: vqe_nativegates_ibm_qiskit_opt0_8.qasm -> vqe_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: vqe_nativegates_ibm_opt0_8q, depth=24
#   Loading: su2random_indep_qiskit_8.qasm -> su2random_indep (8 qubits)
#     ✓ Loaded: su2random_indep_8q, depth=33
#   Loading: wstate_nativegates_ibm_qiskit_opt0_9.qasm -> wstate_nativegates_ibm_opt0 (9 qubits)
#     ✓ Loaded: wstate_nativegates_ibm_opt0_9q, depth=81
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     ✓ Loaded: dj_indep_3q, depth=4
#   Loading: realamprandom_indep_qiskit_10.qasm -> realamprandom_indep (10 qubits)
#     ✓ Loaded: realamprandom_indep_10q, depth=41
#   Loading: twolocalrandom_nativegates_ibm_qiskit_opt0_4.qasm -> twolocalrandom_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: twolocalrandom_nativegates_ibm_opt0_4q, depth=33
#   Loading: ae_indep_qiskit_4.qasm -> ae_indep (4 qubits)
#     ✓ Loaded: ae_indep_4q, depth=17
#   Loading: random_indep_qiskit_6.qasm -> random_indep (6 qubits)
#     ✓ Loaded: random_indep_6q, depth=33
#   Loading: vqe_indep_qiskit_6.qasm -> vqe_indep (6 qubits)
#     ✓ Loaded: vqe_indep_6q, depth=10
#   Loading: su2random_nativegates_ibm_qiskit_opt0_6.qasm -> su2random_nativegates_ibm_opt0 (6 qubits)
#     ✓ Loaded: su2random_nativegates_ibm_opt0_6q, depth=45
#   Loading: grover-v-chain_indep_qiskit_2.qasm -> grover-v-chain_indep (2 qubits)
#     ✓ Loaded: grover-v-chain_indep_2q, depth=1
#   Loading: wstate_indep_qiskit_10.qasm -> wstate_indep (10 qubits)
#     ✓ Loaded: wstate_indep_10q, depth=20
#   Loading: ghz_nativegates_ibm_qiskit_opt0_3.qasm -> ghz_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: ghz_nativegates_ibm_opt0_3q, depth=5
#   Loading: qft_nativegates_ibm_qiskit_opt0_4.qasm -> qft_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: qft_nativegates_ibm_opt0_4q, depth=30
#   Loading: graphstate_indep_qiskit_10.qasm -> graphstate_indep (10 qubits)
#     ✓ Loaded: graphstate_indep_10q, depth=6
#   Loading: qftentangled_nativegates_ibm_qiskit_opt0_2.qasm -> qftentangled_nativegates_ibm_opt0 (2 qubits)
#     ✓ Loaded: qftentangled_nativegates_ibm_opt0_2q, depth=18
#   Loading: random_nativegates_ibm_qiskit_opt0_8.qasm -> random_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: random_nativegates_ibm_opt0_8q, depth=141
#   Loading: qftentangled_nativegates_ibm_qiskit_opt0_3.qasm -> qftentangled_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: qftentangled_nativegates_ibm_opt0_3q, depth=26
#   Loading: portfolioqaoa_nativegates_ibm_qiskit_opt0_3.qasm -> portfolioqaoa_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: portfolioqaoa_nativegates_ibm_opt0_3q, depth=48
#   Loading: ghz_nativegates_ibm_qiskit_opt0_2.qasm -> ghz_nativegates_ibm_opt0 (2 qubits)
#     ✓ Loaded: ghz_nativegates_ibm_opt0_2q, depth=4
#   Loading: twolocalrandom_indep_qiskit_10.qasm -> twolocalrandom_indep (10 qubits)
#     ✓ Loaded: twolocalrandom_indep_10q, depth=41
#   Loading: grover-v-chain_indep_qiskit_3.qasm -> grover-v-chain_indep (3 qubits)
#     ✓ Loaded: grover-v-chain_indep_3q, depth=9
#   Loading: su2random_nativegates_ibm_qiskit_opt0_7.qasm -> su2random_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: su2random_nativegates_ibm_opt0_7q, depth=49
#   Loading: vqe_indep_qiskit_7.qasm -> vqe_indep (7 qubits)
#     ✓ Loaded: vqe_indep_7q, depth=11
#   Loading: random_indep_qiskit_7.qasm -> random_indep (7 qubits)
#     ✓ Loaded: random_indep_7q, depth=40
#   Loading: grover-noancilla_nativegates_ibm_qiskit_opt0_2.qasm -> grover-noancilla_nativegates_ibm_opt0 (2 qubits)
#     ✓ Loaded: grover-noancilla_nativegates_ibm_opt0_2q, depth=3
#   Loading: routing_indep_qiskit_2.qasm -> routing_indep (2 qubits)
#     ✓ Loaded: routing_indep_2q, depth=7
#   Loading: qft_indep_qiskit_6.qasm -> qft_indep (6 qubits)
#     ✓ Loaded: qft_indep_6q, depth=12
#   Loading: qftentangled_indep_qiskit_7.qasm -> qftentangled_indep (7 qubits)
#     ✓ Loaded: qftentangled_indep_7q, depth=16
#   Loading: grover-v-chain_nativegates_ibm_qiskit_opt0_3.qasm -> grover-v-chain_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: grover-v-chain_nativegates_ibm_opt0_3q, depth=29
#   Loading: qwalk-noancilla_indep_qiskit_6.qasm -> qwalk-noancilla_indep (6 qubits)
#     ✓ Loaded: qwalk-noancilla_indep_6q, depth=763
#   Loading: qpeexact_nativegates_ibm_qiskit_opt0_3.qasm -> qpeexact_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: qpeexact_nativegates_ibm_opt0_3q, depth=19
#   Loading: ae_nativegates_ibm_qiskit_opt0_7.qasm -> ae_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: ae_nativegates_ibm_opt0_7q, depth=119
#   Loading: qpeinexact_nativegates_ibm_qiskit_opt0_3.qasm -> qpeinexact_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: qpeinexact_nativegates_ibm_opt0_3q, depth=23
#   Loading: qaoa_indep_qiskit_7.qasm -> qaoa_indep (7 qubits)
#     ✓ Loaded: qaoa_indep_7q, depth=9
#   Loading: qwalk-v-chain_indep_qiskit_5.qasm -> qwalk-v-chain_indep (5 qubits)
#     ✓ Loaded: qwalk-v-chain_indep_5q, depth=37
#   Loading: pricingcall_indep_qiskit_5.qasm -> pricingcall_indep (5 qubits)
#     ✓ Loaded: pricingcall_indep_5q, depth=35
#   Loading: portfolioqaoa_nativegates_ibm_qiskit_opt0_4.qasm -> portfolioqaoa_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: portfolioqaoa_nativegates_ibm_opt0_4q, depth=60
#   Loading: qpeinexact_indep_qiskit_6.qasm -> qpeinexact_indep (6 qubits)
#     ✓ Loaded: qpeinexact_indep_6q, depth=16
#   Loading: qnn_nativegates_ibm_qiskit_opt0_7.qasm -> qnn_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: qnn_nativegates_ibm_opt0_7q, depth=78
#   Loading: grover-noancilla_indep_qiskit_7.qasm -> grover-noancilla_indep (7 qubits)
#     ✓ Loaded: grover-noancilla_indep_7q, depth=1123
#   Loading: portfolioqaoa_indep_qiskit_6.qasm -> portfolioqaoa_indep (6 qubits)
#     ✓ Loaded: portfolioqaoa_indep_6q, depth=25
#   Loading: realamprandom_nativegates_ibm_qiskit_opt0_6.qasm -> realamprandom_nativegates_ibm_opt0 (6 qubits)
#     ✓ Loaded: realamprandom_nativegates_ibm_opt0_6q, depth=41
#   Loading: realamprandom_indep_qiskit_7.qasm -> realamprandom_indep (7 qubits)
#     ✓ Loaded: realamprandom_indep_7q, depth=29
#   Loading: pricingcall_indep_qiskit_9.qasm -> pricingcall_indep (9 qubits)
#     ✓ Loaded: pricingcall_indep_9q, depth=82
#   Loading: tsp_indep_qiskit_9.qasm -> tsp_indep (9 qubits)
#     ✓ Loaded: tsp_indep_9q, depth=22
#   Loading: routing_nativegates_ibm_qiskit_opt0_6.qasm -> routing_nativegates_ibm_opt0 (6 qubits)
#     ✓ Loaded: routing_nativegates_ibm_opt0_6q, depth=29
#   Loading: pricingcall_nativegates_ibm_qiskit_opt0_7.qasm -> pricingcall_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: pricingcall_nativegates_ibm_opt0_7q, depth=274
#   Loading: pricingput_indep_qiskit_5.qasm -> pricingput_indep (5 qubits)
#     ✓ Loaded: pricingput_indep_5q, depth=35
#   Loading: realamprandom_nativegates_ibm_qiskit_opt0_7.qasm -> realamprandom_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: realamprandom_nativegates_ibm_opt0_7q, depth=45
#   Loading: portfolioqaoa_indep_qiskit_7.qasm -> portfolioqaoa_indep (7 qubits)
#     ✓ Loaded: portfolioqaoa_indep_7q, depth=29
#   Loading: grover-noancilla_indep_qiskit_6.qasm -> grover-noancilla_indep (6 qubits)
#     ✓ Loaded: grover-noancilla_indep_6q, depth=401
#   Loading: tsp_indep_qiskit_4.qasm -> tsp_indep (4 qubits)
#     ✓ Loaded: tsp_indep_4q, depth=17
#   Loading: qpeinexact_indep_qiskit_7.qasm -> qpeinexact_indep (7 qubits)
#     ✓ Loaded: qpeinexact_indep_7q, depth=19
#   Loading: pricingput_indep_qiskit_9.qasm -> pricingput_indep (9 qubits)
#     ✓ Loaded: pricingput_indep_9q, depth=83
#   Loading: tsp_nativegates_ibm_qiskit_opt0_4.qasm -> tsp_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: tsp_nativegates_ibm_opt0_4q, depth=77
#   Loading: qwalk-v-chain_nativegates_ibm_qiskit_opt0_3.qasm -> qwalk-v-chain_nativegates_ibm_opt0 (3 qubits)
#     ✓ Loaded: qwalk-v-chain_nativegates_ibm_opt0_3q, depth=85
#   Loading: pricingcall_nativegates_ibm_qiskit_opt0_5.qasm -> pricingcall_nativegates_ibm_opt0 (5 qubits)
#     ✓ Loaded: pricingcall_nativegates_ibm_opt0_5q, depth=176
#   Loading: tsp_nativegates_ibm_qiskit_opt0_9.qasm -> tsp_nativegates_ibm_opt0 (9 qubits)
#     ✓ Loaded: tsp_nativegates_ibm_opt0_9q, depth=97
#   Loading: routing_indep_qiskit_6.qasm -> routing_indep (6 qubits)
#     ✓ Loaded: routing_indep_6q, depth=13
#   Loading: pricingput_nativegates_ibm_qiskit_opt0_5.qasm -> pricingput_nativegates_ibm_opt0 (5 qubits)
#     ✓ Loaded: pricingput_nativegates_ibm_opt0_5q, depth=176
#   Loading: groundstate_small_nativegates_ibm_qiskit_opt0_4.qasm -> groundstate_small_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: groundstate_small_nativegates_ibm_opt0_4q, depth=68
#   Loading: routing_nativegates_ibm_qiskit_opt0_2.qasm -> routing_nativegates_ibm_opt0 (2 qubits)
#     ✓ Loaded: routing_nativegates_ibm_opt0_2q, depth=23
#
# ✓ Total circuits loaded: 106
#   Origins: ['graphstate_nativegates_ibm_opt0', 'dj_nativegates_ibm_opt0', 'qnn_indep', 'qaoa_indep', 'qpeinexact_nativegates_ibm_opt0', 'qaoa_nativegates_ibm_opt0', 'ghz_indep', 'portfoliovqe_indep', 'qpeexact_nativegates_ibm_opt0', 'twolocalrandom_indep', 'ae_nativegates_ibm_opt0', 'qpeexact_indep', 'wstate_nativegates_ibm_opt0', 'su2random_indep', 'pricingput_nativegates_ibm_opt0', 'vqe_nativegates_ibm_opt0', 'qwalk-noancilla_indep', 'ae_indep', 'twolocalrandom_nativegates_ibm_opt0', 'qwalk-v-chain_nativegates_ibm_opt0', 'grover-v-chain_nativegates_ibm_opt0', 'portfoliovqe_nativegates_ibm_opt0', 'qft_nativegates_ibm_opt0', 'qftentangled_indep', 'qwalk-noancilla_nativegates_ibm_opt0', 'random_nativegates_ibm_opt0', 'groundstate_small_indep', 'wstate_indep', 'graphstate_indep', 'dj_indep', 'qnn_nativegates_ibm_opt0', 'qft_indep', 'grover-noancilla_nativegates_ibm_opt0', 'qwalk-v-chain_indep', 'realamprandom_indep', 'random_indep', 'vqe_indep', 'su2random_nativegates_ibm_opt0', 'grover-v-chain_indep', 'ghz_nativegates_ibm_opt0', 'qftentangled_nativegates_ibm_opt0', 'portfolioqaoa_nativegates_ibm_opt0', 'routing_indep', 'pricingcall_indep', 'qpeinexact_indep', 'grover-noancilla_indep', 'portfolioqaoa_indep', 'realamprandom_nativegates_ibm_opt0', 'tsp_indep', 'routing_nativegates_ibm_opt0', 'pricingcall_nativegates_ibm_opt0', 'pricingput_indep', 'tsp_nativegates_ibm_opt0', 'groundstate_small_nativegates_ibm_opt0']
#   Qubit range: 2 - 10
#
# ✓ Loaded progress: 24 experiments already completed
# ✓ Loaded existing results: 0 rows
#
# 2. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Total experiments: 2874
# Already completed: 24
# Remaining: 2850
# Output file: results.csv
#
# Experiment 25/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:266: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   ✓ Saved (Total rows: 1)
# Experiment 27/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 2)
# Experiment 29/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 3)
# Experiment 31/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 4)
# Experiment 33/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 5)
# Experiment 35/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 6)
# Experiment 37/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 7)
# Experiment 39/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 8)
# Experiment 41/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 9)
# Experiment 43/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 10)
# Experiment 45/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 11)
# Experiment 47/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 12)
# Experiment 49/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 13)
# Experiment 51/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 14)
# Experiment 53/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 15)
# Experiment 55/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 16)
# Experiment 57/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 17)
# Experiment 59/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 18)
# Experiment 61/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 19)
# Experiment 63/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 20)
# Experiment 65/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 21)
# Experiment 67/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 22)
# Experiment 69/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 23)
# Experiment 71/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 24)
# Experiment 73/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 25)
# Experiment 75/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 26)
# Experiment 77/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 27)
# Experiment 79/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 28)
# Experiment 81/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 29)
# Experiment 83/2874: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 30)
# Experiment 85/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 31)
# Experiment 87/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 32)
# Experiment 89/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 33)
# Experiment 91/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 34)
# Experiment 93/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 35)
# Experiment 95/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 36)
# Experiment 97/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 37)
# Experiment 99/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 38)
# Experiment 101/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 39)
# Experiment 103/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 40)
# Experiment 105/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 41)
# Experiment 107/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 42)
# Experiment 109/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 43)
# Experiment 111/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 44)
# Experiment 113/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 45)
# Experiment 115/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 46)
# Experiment 117/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 47)
# Experiment 119/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 48)
# Experiment 121/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 49)
# Experiment 123/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 50)
# Experiment 125/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 51)
# Experiment 127/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 52)
# Experiment 129/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 53)
# Experiment 131/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 54)
# Experiment 133/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 55)
# Experiment 135/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 56)
# Experiment 137/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 57)
# Experiment 139/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 58)
# Experiment 141/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 59)
# Experiment 143/2874: graphstate_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 60)
# Experiment 145/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 61)
# Experiment 147/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 62)
# Experiment 149/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 63)
# Experiment 151/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 64)
# Experiment 153/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 65)
# Experiment 155/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.001, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 66)
# Experiment 157/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 67)
# Experiment 159/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 68)
# Experiment 161/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 69)
# Experiment 163/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 70)
# Experiment 165/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 71)
# Experiment 167/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.005, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 72)
# Experiment 169/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 73)
# Experiment 171/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 74)
# Experiment 173/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 75)
# Experiment 175/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 76)
# Experiment 177/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 77)
# Experiment 179/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.01, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 78)
# Experiment 181/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 79)
# Experiment 183/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 80)
# Experiment 185/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 81)
# Experiment 187/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 82)
# Experiment 189/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 83)
# Experiment 191/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.015, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 84)
# Experiment 193/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 85)
# Experiment 195/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 86)
# Experiment 197/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 87)
# Experiment 199/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 88)
# Experiment 201/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 89)
# Experiment 203/2874: dj_nativegates_ibm_opt0_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 90)
# Experiment 205/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 91)
# Experiment 207/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 92)
# Experiment 209/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 93)
# Experiment 211/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 94)
# Experiment 213/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 95)
# Experiment 215/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 96)
# Experiment 217/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 97)
# Experiment 219/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 98)
# Experiment 221/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 99)
# Experiment 223/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 100)
# Experiment 225/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 101)
# Experiment 227/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 102)
# Experiment 229/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 103)
# Experiment 231/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 104)
# Experiment 233/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 105)
# Experiment 235/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 106)
# Experiment 237/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 107)
# Experiment 239/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 108)
# Experiment 241/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 109)
# Experiment 243/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 110)
# Experiment 245/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 111)
# Experiment 247/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 112)
# Experiment 249/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 113)
# Experiment 251/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 114)
# Experiment 253/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 115)
# Experiment 255/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 116)
# Experiment 257/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 117)
# Experiment 259/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 118)
# Experiment 261/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 119)
# Experiment 263/2874: dj_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:113: UserWarning: Circuit execution failed: 'Number of qubits (73) in circuit-7302 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:113: UserWarning: Circuit execution failed: 'Number of qubits (107) in circuit-7405 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   ✓ Saved (Total rows: 120)
# Experiment 265/2874: qnn_indep_8q (8q), global, noise=0.001, comm=1.0x, cat, parts=2
#   Error: division by zero
# Experiment 267/2874: qnn_indep_8q (8q), global, noise=0.001, comm=1.0x, cat, parts=4
#   Error: division by zero
# Experiment 269/2874: qnn_indep_8q (8q), global, noise=0.001, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:113: UserWarning: Circuit execution failed: 'Number of qubits (73) in circuit-7506 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:113: UserWarning: Circuit execution failed: 'Number of qubits (107) in circuit-7609 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:113: UserWarning: Circuit execution failed: 'Number of qubits (73) in circuit-7710 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   Error: division by zero
# Experiment 271/2874: qnn_indep_8q (8q), global, noise=0.001, comm=1.1x, cat, parts=4
#   Error: division by zero
# Experiment 273/2874: qnn_indep_8q (8q), global, noise=0.001, comm=1.2x, cat, parts=2
#   Error: division by zero
# Experiment 275/2874: qnn_indep_8q (8q), global, noise=0.001, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:113: UserWarning: Circuit execution failed: 'Number of qubits (107) in circuit-7813 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
# ...
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 166)
# Experiment 477/2874: qaoa_indep_7q (7q), global, noise=0.01, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 167)
# Experiment 479/2874: qaoa_indep_7q (7q), global, noise=0.01, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 168)
# Experiment 481/2874: qaoa_indep_7q (7q), global, noise=0.015, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 169)
# Experiment 483/2874: qaoa_indep_7q (7q), global, noise=0.015, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 170)
# Experiment 485/2874: qaoa_indep_7q (7q), global, noise=0.015, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 171)
# Experiment 487/2874: qaoa_indep_7q (7q), global, noise=0.015, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 172)
# Experiment 489/2874: qaoa_indep_7q (7q), global, noise=0.015, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 173)
# Experiment 491/2874: qaoa_indep_7q (7q), global, noise=0.015, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 174)
# Experiment 493/2874: qaoa_indep_7q (7q), global, noise=0.02, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 175)
# Experiment 495/2874: qaoa_indep_7q (7q), global, noise=0.02, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 176)
# Experiment 497/2874: qaoa_indep_7q (7q), global, noise=0.02, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 177)
# Experiment 499/2874: qaoa_indep_7q (7q), global, noise=0.02, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 178)
# Experiment 501/2874: qaoa_indep_7q (7q), global, noise=0.02, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 179)
# Experiment 503/2874: qaoa_indep_7q (7q), global, noise=0.02, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 180)
# Experiment 505/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.001, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 181)
# Experiment 507/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.001, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 182)
# Experiment 509/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.001, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 183)
# Experiment 511/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.005, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 184)
# Experiment 513/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.005, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 185)
# Experiment 515/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.005, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 186)
# Experiment 517/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.01, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 187)
# Experiment 519/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.01, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:266: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   ✓ Saved (Total rows: 188)
# Experiment 521/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.01, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 189)
# Experiment 523/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.015, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 190)
# Experiment 525/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.015, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 191)
# Experiment 527/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.015, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 192)
# Experiment 529/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.02, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 193)
# Experiment 531/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.02, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 194)
# Experiment 533/2874: qpeinexact_nativegates_ibm_opt0_2q (2q), global, noise=0.02, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 195)
# Experiment 535/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.001, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 196)
# Experiment 537/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.001, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 197)
# Experiment 539/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.001, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 198)
# Experiment 541/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.005, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 199)
# Experiment 543/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.005, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 200)
# Experiment 545/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.005, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 201)
# Experiment 547/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.01, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 202)
# Experiment 549/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.01, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 203)
# Experiment 551/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.01, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 204)
# Experiment 553/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.015, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 205)
# Experiment 555/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.015, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 206)
# Experiment 557/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.015, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 207)
# Experiment 559/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.02, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 208)
# Experiment 561/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.02, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 209)
# Experiment 563/2874: qpeinexact_nativegates_ibm_opt0_3q (3q), global, noise=0.02, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 210)
# Experiment 565/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 211)
# Experiment 567/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 212)
# Experiment 569/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 213)
# Experiment 571/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 214)
# Experiment 573/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 215)
# Experiment 575/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.001, comm=1.2x, cat, parts=4
#   ✓ Saved (Total rows: 216)
# Experiment 577/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 217)
# Experiment 579/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 218)
# Experiment 581/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 219)
# Experiment 583/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 220)
# Experiment 585/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 221)
# Experiment 587/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.005, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 222)
# Experiment 589/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 223)
# Experiment 591/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 224)
# Experiment 593/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
#   ✓ Saved (Total rows: 225)
# Experiment 595/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
#   ✓ Saved (Total rows: 226)
# Experiment 597/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
#   ✓ Saved (Total rows: 227)
# Experiment 599/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 228)
# Experiment 601/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.0x, cat, parts=2
#   ✓ Saved (Total rows: 229)
# Experiment 603/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.0x, cat, parts=4
#   ✓ Saved (Total rows: 230)
# Experiment 605/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 231)
# Experiment 607/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:289: UserWarning: ZNE extrapolation too aggressive, using noisy value
#   warnings.warn("ZNE extrapolation too aggressive, using noisy value")
#   ✓ Saved (Total rows: 232)
# Experiment 609/2874: qaoa_nativegates_ibm_opt0_4q (4q), global, noise=0.015, comm=1.2x, cat, parts=2

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQTBench',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=2,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
