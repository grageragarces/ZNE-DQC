# %%
from mqt import run_mqt_bench_experiments_incremental

# %% [markdown]
# okay so weirdly we need to re-run max_circuits_per_origin=10
# but in MQT_under15 instead of MQT_under10 -> this is setup
#
# separetly to that we need to the 'no' versions to work, which they don't atm -> TODO
#
# I think we shouldn't do cat at all we should just do tp -> simplifies analysis

# %% [markdown]
# graph_state - next to test

# %%
# test_df = run_mqt_bench_experiments_incremental(
#     mqt_folder='MQT_under10',
#     min_qubits=2,
#     max_qubits=10,
#     max_circuits_per_origin=10,
#     strategies=['no'],
#     noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
#     comm_noise_multipliers=[1.0,1.1,1.2],
#     comm_primitives=['tp'],
#     partition_counts=[1, 2, 3, 4, 5, 6],
#     shots=200,
#     output_file='results.csv',
#     progress_file='test_progress.json'
# ) #no-needs to be fixed before un-commenting

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under15',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
) #yes
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under15 for QASM files...
# Found 33 QASM files
#   Loading: ghz_indep_qiskit_9.qasm -> ghz_indep (9 qubits)
#     LOADED: ghz_indep_9q, depth=9
#   Loading: wstate_indep_qiskit_7.qasm -> wstate_indep (7 qubits)
#     LOADED: wstate_indep_7q, depth=14
#   Loading: ghz_indep_qiskit_5.qasm -> ghz_indep (5 qubits)
#     LOADED: ghz_indep_5q, depth=5
#   Loading: wstate_indep_qiskit_10.qasm -> wstate_indep (10 qubits)
#     LOADED: wstate_indep_10q, depth=20
#   Loading: ghz_indep_qiskit_4.qasm -> ghz_indep (4 qubits)
#     LOADED: ghz_indep_4q, depth=4
#   Loading: wstate_indep_qiskit_6.qasm -> wstate_indep (6 qubits)
#     LOADED: wstate_indep_6q, depth=12
#   Loading: ghz_indep_qiskit_8.qasm -> ghz_indep (8 qubits)
#     LOADED: ghz_indep_8q, depth=8
#   Loading: ghz_indep_qiskit_3.qasm -> ghz_indep (3 qubits)
#     LOADED: ghz_indep_3q, depth=3
#   Loading: ghz_indep_qiskit_2.qasm -> ghz_indep (2 qubits)
#     LOADED: ghz_indep_2q, depth=2
#   Loading: wstate_indep_qiskit_3.qasm -> wstate_indep (3 qubits)
#     LOADED: wstate_indep_3q, depth=6
#   Loading: ghz_indep_qiskit_10.qasm -> ghz_indep (10 qubits)
#     LOADED: ghz_indep_10q, depth=10
#   Loading: wstate_indep_qiskit_2.qasm -> wstate_indep (2 qubits)
#     LOADED: wstate_indep_2q, depth=4
#   Loading: wstate_indep_qiskit_9.qasm -> wstate_indep (9 qubits)
#     LOADED: wstate_indep_9q, depth=18
#   Loading: ghz_indep_qiskit_7.qasm -> ghz_indep (7 qubits)
#     LOADED: ghz_indep_7q, depth=7
#   Loading: wstate_indep_qiskit_5.qasm -> wstate_indep (5 qubits)
#     LOADED: wstate_indep_5q, depth=10
#   Loading: wstate_indep_qiskit_4.qasm -> wstate_indep (4 qubits)
#     LOADED: wstate_indep_4q, depth=8
#   Loading: ghz_indep_qiskit_6.qasm -> ghz_indep (6 qubits)
#     LOADED: ghz_indep_6q, depth=6
#   Loading: wstate_indep_qiskit_8.qasm -> wstate_indep (8 qubits)
#     LOADED: wstate_indep_8q, depth=16
#
# Total circuits loaded: 18
#   Origins: ['ghz_indep', 'wstate_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 6355 experiments already completed
# Loaded existing results: 1337 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 7675
# Already completed: 6355
# Remaining: 1320
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 6356/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1338)
# Experiment 6358/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1339)
# Experiment 6360/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1340)
# Experiment 6362/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1341)
# Experiment 6364/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1342)
# Experiment 6366/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1343)
# Experiment 6368/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1344)
# Experiment 6370/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1345)
# Experiment 6372/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1346)
# Experiment 6374/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1347)
# Experiment 6376/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1348)
# Experiment 6378/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1349)
# Experiment 6380/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1350)
# Experiment 6382/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1351)
# Experiment 6384/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1352)
# Experiment 6386/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1353)
# Experiment 6388/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1354)
# Experiment 6390/7675: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1355)
# Experiment 6392/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1356)
# Experiment 6394/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1357)
# Experiment 6396/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1358)
# Experiment 6398/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1359)
# Experiment 6400/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1360)
# Experiment 6402/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1361)
# Experiment 6404/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1362)
# Experiment 6406/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1363)
# Experiment 6408/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1364)
# Experiment 6410/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1365)
# Experiment 6412/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1366)
# Experiment 6414/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1367)
# Experiment 6416/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1368)
# Experiment 6418/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1369)
# Experiment 6420/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1370)
# Experiment 6422/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1371)
# Experiment 6424/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1372)
# Experiment 6426/7675: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1373)
# Experiment 6428/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1374)
# Experiment 6430/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1375)
# Experiment 6432/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1376)
# Experiment 6434/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1377)
# Experiment 6436/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1378)
# Experiment 6438/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1379)
# Experiment 6440/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1380)
# Experiment 6442/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1381)
# Experiment 6444/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1382)
# Experiment 6446/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1383)
# Experiment 6448/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1384)
# Experiment 6450/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1385)
# Experiment 6452/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1386)
# Experiment 6454/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1387)
# Experiment 6456/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1388)
# Experiment 6458/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1389)
# Experiment 6460/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1390)
# Experiment 6462/7675: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1391)
# Experiment 6464/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1392)
# Experiment 6466/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1393)
# Experiment 6468/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1394)
# Experiment 6470/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1395)
# Experiment 6472/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1396)
# Experiment 6474/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1397)
# Experiment 6476/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1398)
# Experiment 6478/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1399)
# Experiment 6480/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1400)
# Experiment 6482/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1401)
# Experiment 6484/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1402)
# Experiment 6486/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1403)
# Experiment 6488/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1404)
# Experiment 6490/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1405)
# Experiment 6492/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1406)
# Experiment 6494/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1407)
# Experiment 6496/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1408)
# Experiment 6498/7675: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1409)
# Experiment 6500/7675: ghz_indep_9q (9q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1410)
# Experiment 6502/7675: ghz_indep_9q (9q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1411)
# Experiment 6504/7675: ghz_indep_9q (9q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 
comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1580)
# Experiment 6842/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1581)
# Experiment 6844/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1582)
# Experiment 6846/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1583)
# Experiment 6848/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1584)
# Experiment 6850/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1585)
# Experiment 6852/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1586)
# Experiment 6854/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1587)
# Experiment 6856/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1588)
# Experiment 6858/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1589)
# Experiment 6860/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1590)
# Experiment 6862/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1591)
# Experiment 6864/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1592)
# Experiment 6866/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1593)
# Experiment 6868/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1594)
# Experiment 6870/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1595)
# Experiment 6872/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1596)
# Experiment 6874/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1597)
# Experiment 6876/7675: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1598)
# Experiment 6878/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1599)
# Experiment 6880/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1600)
# Experiment 6882/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1601)
# Experiment 6884/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1602)
# Experiment 6886/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1603)
# Experiment 6888/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1604)
# Experiment 6890/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1605)
# Experiment 6892/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1606)
# Experiment 6894/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1607)
# Experiment 6896/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1608)
# Experiment 6898/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1609)
# Experiment 6900/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1610)
# Experiment 6902/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1611)
# Experiment 6904/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1612)
# Experiment 6906/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1613)
# Experiment 6908/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1614)
# Experiment 6910/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1615)
# Experiment 6912/7675: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1616)
# Experiment 6914/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1617)
# Experiment 6916/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1618)
# Experiment 6918/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1619)
# Experiment 6920/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1620)
# Experiment 6922/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1621)
# Experiment 6924/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1622)
# Experiment 6926/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1623)
# Experiment 6928/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1624)
# Experiment 6930/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1625)
# Experiment 6932/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1626)
# Experiment 6934/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1627)
# Experiment 6936/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1628)
# Experiment 6938/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1629)
# Experiment 6940/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1630)
# Experiment 6942/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1631)
# Experiment 6944/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1632)
# Experiment 6946/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1633)
# Experiment 6948/7675: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1634)
# Experiment 6950/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1635)
# Experiment 6952/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1636)
# Experiment 6954/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1637)
# Experiment 6956/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1638)
# Experiment 6958/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1639)
# Experiment 6960/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1640)
# Experiment 6962/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1641)
# Experiment 6964/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1642)
# Experiment 6966/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1643)
# Experiment 6968/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1644)
# Experiment 6970/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1645)
# Experiment 6972/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1646)
# Experiment 6974/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1647)
# Experiment 6976/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1648)
# Experiment 6978/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1649)
# Experiment 6980/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 1650)
# Experiment 6982/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 1651)
# Experiment 6984/7675: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 1652)
# Experiment 6986/7675: ghz_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1653)
# Experiment 6988/7675: ghz_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1654)
# Experiment 6990/7675: ghz_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1655)
# Experiment 6992/7675: ghz_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1656)
# Experiment 6994/7675: ghz_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1657)
# Experiment 6996/7675: ghz_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1658)
# ...
#   SUCCESS - Saved (Total rows: 2224)
# Experiment 8130/7675: wstate_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2225)
# Experiment 8132/7675: wstate_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2226)
# Experiment 8134/7675: wstate_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2227)
# Experiment 8136/7675: wstate_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2228)
# Experiment 8138/7675: wstate_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2229)
# Experiment 8140/7675: wstate_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2230)
# Experiment 8142/7675: wstate_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2231)
# Experiment 8144/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2232)
# Experiment 8146/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2233)
# Experiment 8148/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2234)
# Experiment 8150/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2235)
# Experiment 8152/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2236)
# Experiment 8154/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2237)
# Experiment 8156/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2238)
# Experiment 8158/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2239)
# Experiment 8160/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2240)
# Experiment 8162/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2241)
# Experiment 8164/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2242)
# Experiment 8166/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2243)
# Experiment 8168/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2244)
# Experiment 8170/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2245)
# Experiment 8172/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2246)
# Experiment 8174/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2247)
# Experiment 8176/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2248)
# Experiment 8178/7675: wstate_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2249)
# Experiment 8180/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2250)
# Experiment 8182/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2251)
# Experiment 8184/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2252)
# Experiment 8186/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2253)
# Experiment 8188/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2254)
# Experiment 8190/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2255)
# Experiment 8192/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2256)
# Experiment 8194/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2257)
# Experiment 8196/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2258)
# Experiment 8198/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2259)
# Experiment 8200/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2260)
# Experiment 8202/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2261)
# Experiment 8204/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2262)
# Experiment 8206/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2263)
# Experiment 8208/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2264)
# Experiment 8210/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2265)
# Experiment 8212/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2266)
# Experiment 8214/7675: wstate_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2267)
# Experiment 8216/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2268)
# Experiment 8218/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2269)
# Experiment 8220/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2270)
# Experiment 8222/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2271)
# Experiment 8224/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2272)
# Experiment 8226/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2273)
# Experiment 8228/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2274)
# Experiment 8230/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2275)
# Experiment 8232/7675: wstate_indep_3q (3q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2276)
# Experiment 8234/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2277)
# Experiment 8236/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2278)
# Experiment 8238/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2279)
# Experiment 8240/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2280)
# Experiment 8242/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2281)
# Experiment 8244/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2282)
# Experiment 8246/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2283)
# Experiment 8248/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2284)
# Experiment 8250/7675: wstate_indep_3q (3q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2285)
# Experiment 8252/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2286)
# Experiment 8254/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2287)
# Experiment 8256/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2288)
# Experiment 8258/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2289)
# Experiment 8260/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2290)
# Experiment 8262/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2291)
# Experiment 8264/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2292)
# Experiment 8266/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2293)
# Experiment 8268/7675: wstate_indep_3q (3q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2294)
# Experiment 8270/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2295)
# Experiment 8272/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2296)
# Experiment 8274/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2297)
# Experiment 8276/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2298)
# Experiment 8278/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2299)
# Experiment 8280/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2300)
# Experiment 8282/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2301)
# Experiment 8284/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2302)
# Experiment 8286/7675: wstate_indep_3q (3q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2303)
# Experiment 8288/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2304)
# Experiment 8290/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2305)
# Experiment 8292/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2306)
# Experiment 8294/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2307)
# Experiment 8296/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2308)
# Experiment 8298/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2309)
# Experiment 8300/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2310)
# Experiment 8302/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2311)
# Experiment 8304/7675: wstate_indep_3q (3q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2312)
# Experiment 8306/7675: wstate_indep_2q (2q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2313)
# Experiment 8308/7675: wstate_indep_2q (2q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2314)
# Experiment 8310/7675: wstate_indep_2q (2q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2315)
# Experiment 8312/7675: wstate_indep_2q (2q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2316)
# Experiment 8314/7675: wstate_indep_2q (2q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2317)
# Experiment 8316/7675: wstate_indep_2q (2q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2318)
# Experiment 8318/7675: wstate_indep_2q (2q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2319)
# Experiment 8320/7675: wstate_indep_2q (2q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2320)
# Experiment 8322/7675: wstate_indep_2q (2q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2321)
# Experiment 8324/7675: wstate_indep_2q (2q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2322)
# Experiment 8326/7675: wstate_indep_2q (2q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2323)
# Experiment 8328/7675: wstate_indep_2q (2q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2324)
# Experiment 8330/7675: wstate_indep_2q (2q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2325)
# Experiment 8332/7675: wstate_indep_2q (2q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2326)
# Experiment 8334/7675: wstate_indep_2q (2q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2327)
# Experiment 8336/7675: wstate_indep_2q (2q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2328)
# Experiment 8338/7675: wstate_indep_2q (2q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2329)
# Experiment 8340/7675: wstate_indep_2q (2q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2330)
# Experiment 8342/7675: wstate_indep_2q (2q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2331)
# Experiment 8344/7675: wstate_indep_2q (2q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2332)
# Experiment 8346/7675: wstate_indep_2q (2q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2333)
# Experiment 8348/7675: wstate_indep_2q (2q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2334)
# Experiment 8350/7675: wstate_indep_2q (2q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2335)
# Experiment 8352/7675: wstate_indep_2q (2q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2336)
# Experiment 8354/7675: wstate_indep_2q (2q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2337)
# Experiment 8356/7675: wstate_indep_2q (2q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2338)
# Experiment 8358/7675: wstate_indep_2q (2q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2339)
# Experiment 8360/7675: wstate_indep_2q (2q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2340)
# Experiment 8362/7675: wstate_indep_2q (2q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2341)
# Experiment 8364/7675: wstate_indep_2q (2q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2342)
# Experiment 8366/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2343)
# Experiment 8368/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2344)
# Experiment 8370/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2345)
# Experiment 8372/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2346)
# Experiment 8374/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2347)
# Experiment 8376/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2348)
# Experiment 8378/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2349)
# Experiment 8380/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2350)
# Experiment 8382/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2351)
# Experiment 8384/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2352)
# Experiment 8386/7675: wstate_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=5

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
) #yes - unfinished: so will be re-run
#ended in 6388/6983

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under15',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
