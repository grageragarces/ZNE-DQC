# %%
from mqt import run_mqt_bench_experiments_incremental

# %% [markdown]
# graph_state - next to test

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 9 QASM files
#   Loading: wstate_indep_qiskit_7.qasm -> wstate_indep (7 qubits)
#     LOADED: wstate_indep_7q, depth=14
#   Loading: wstate_indep_qiskit_10.qasm -> wstate_indep (10 qubits)
#     LOADED: wstate_indep_10q, depth=20
#   Loading: wstate_indep_qiskit_6.qasm -> wstate_indep (6 qubits)
#     LOADED: wstate_indep_6q, depth=12
#   Loading: wstate_indep_qiskit_3.qasm -> wstate_indep (3 qubits)
#     LOADED: wstate_indep_3q, depth=6
#   Loading: wstate_indep_qiskit_2.qasm -> wstate_indep (2 qubits)
#     LOADED: wstate_indep_2q, depth=4
#   Loading: wstate_indep_qiskit_9.qasm -> wstate_indep (9 qubits)
#     LOADED: wstate_indep_9q, depth=18
#   Loading: wstate_indep_qiskit_5.qasm -> wstate_indep (5 qubits)
#     LOADED: wstate_indep_5q, depth=10
#   Loading: wstate_indep_qiskit_4.qasm -> wstate_indep (4 qubits)
#     LOADED: wstate_indep_4q, depth=8
#   Loading: wstate_indep_qiskit_8.qasm -> wstate_indep (8 qubits)
#     LOADED: wstate_indep_8q, depth=16
#
# Total circuits loaded: 9
#   Origins: ['wstate_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 0 experiments already completed
# Loaded existing results: 1198 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 315
# Already completed: 0
# Remaining: 315
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 1/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1199)
# Experiment 3/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1200)
# Experiment 5/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1201)
# Experiment 7/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1202)
# Experiment 9/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1203)
# Experiment 11/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1204)
# Experiment 13/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1205)
# Experiment 15/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1206)
# Experiment 17/315: wstate_indep_7q (7q), local, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1207)
# Experiment 19/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1208)
# Experiment 21/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1209)
# Experiment 23/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1210)
# Experiment 25/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1211)
# Experiment 27/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1212)
# Experiment 29/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1213)
# Experiment 31/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1214)
# Experiment 33/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1215)
# Experiment 35/315: wstate_indep_7q (7q), local, noise=0.005, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1216)
# Experiment 37/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1217)
# Experiment 39/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1218)
# Experiment 41/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1219)
# Experiment 43/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1220)
# Experiment 45/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1221)
# Experiment 47/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1222)
# Experiment 49/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1223)
# Experiment 51/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1224)
# Experiment 53/315: wstate_indep_7q (7q), local, noise=0.01, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1225)
# Experiment 55/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1226)
# Experiment 57/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1227)
# Experiment 59/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1228)
# Experiment 61/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1229)
# Experiment 63/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1230)
# Experiment 65/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1231)
# Experiment 67/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1232)
# Experiment 69/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1233)
# Experiment 71/315: wstate_indep_7q (7q), local, noise=0.015, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1234)
# Experiment 73/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1235)
# Experiment 75/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1236)
# Experiment 77/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1237)
# Experiment 79/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1238)
# Experiment 81/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1239)
# Experiment 83/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1240)
# Experiment 85/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1241)
# Experiment 87/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1242)
# Experiment 89/315: wstate_indep_7q (7q), local, noise=0.02, comm=1.2x, cat, parts=6

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
