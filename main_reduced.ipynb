# %%
from mqt import run_mqt_bench_experiments_incremental

# %% [markdown]
# graph_state - next to test

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['no'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 39 QASM files
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#
# Total circuits loaded: 9
#   Origins: ['dj_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 5003 experiments already completed
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 5003
# Already completed: 5003
# Remaining: 0
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
#
# ======================================================================
# 4. RESULTS SUMMARY
# ======================================================================
# Experiments completed: 0
# Results saved to: results.csv
# Skipped (simulator limit): 0

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['no'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 39 QASM files
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#
# Total circuits loaded: 9
#   Origins: ['dj_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 5003 experiments already completed
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 5003
# Already completed: 5003
# Remaining: 0
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
#
# ======================================================================
# 4. RESULTS SUMMARY
# ======================================================================
# Experiments completed: 0
# Results saved to: results.csv
# Skipped (simulator limit): 0

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 39 QASM files
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#
# Total circuits loaded: 9
#   Origins: ['dj_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 5003 experiments already completed
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 5663
# Already completed: 5003
# Remaining: 660
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 5004/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1)
# Experiment 5006/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2)
# Experiment 5008/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3)
# Experiment 5010/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 4)
# Experiment 5012/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5)
# Experiment 5014/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 6)
# Experiment 5016/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 7)
# Experiment 5018/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 8)
# Experiment 5020/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9)
# Experiment 5022/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10)
# Experiment 5024/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 11)
# Experiment 5026/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 12)
# Experiment 5028/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 13)
# Experiment 5030/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 14)
# Experiment 5032/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 15)
# Experiment 5034/5663: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows:
), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 531)
# Experiment 6066/5663: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 532)
# Experiment 6068/5663: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 533)
# Experiment 6070/5663: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 534)
# Experiment 6072/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 535)
# Experiment 6074/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 536)
# Experiment 6076/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 537)
# Experiment 6078/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 538)
# Experiment 6080/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 539)
# Experiment 6082/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 540)
# Experiment 6084/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 541)
# Experiment 6086/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 542)
# Experiment 6088/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 543)
# Experiment 6090/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 544)
# Experiment 6092/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 545)
# Experiment 6094/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 546)
# Experiment 6096/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 547)
# Experiment 6098/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 548)
# Experiment 6100/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 549)
# Experiment 6102/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 550)
# Experiment 6104/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 551)
# Experiment 6106/5663: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 552)
# Experiment 6108/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 553)
# Experiment 6110/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 554)
# Experiment 6112/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 555)
# Experiment 6114/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 556)
# Experiment 6116/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 557)
# Experiment 6118/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 558)
# Experiment 6120/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 559)
# Experiment 6122/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 560)
# Experiment 6124/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 561)
# Experiment 6126/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 562)
# Experiment 6128/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 563)
# Experiment 6130/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 564)
# Experiment 6132/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 565)
# Experiment 6134/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 566)
# Experiment 6136/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 567)
# Experiment 6138/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 568)
# Experiment 6140/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 569)
# Experiment 6142/5663: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 570)
# Experiment 6144/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 571)
# Experiment 6146/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 572)
# Experiment 6148/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 573)
# Experiment 6150/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 574)
# Experiment 6152/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 575)
# Experiment 6154/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 576)
# Experiment 6156/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 577)
# Experiment 6158/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 578)
# Experiment 6160/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 579)
# Experiment 6162/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 580)
# Experiment 6164/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 581)
# Experiment 6166/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 582)
# Experiment 6168/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 583)
# Experiment 6170/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 584)
# Experiment 6172/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 585)
# Experiment 6174/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 586)
# Experiment 6176/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 587)
# Experiment 6178/5663: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 588)
# Experiment 6180/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 589)
# Experiment 6182/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 590)
# Experiment 6184/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 591)
# Experiment 6186/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 592)
# Experiment 6188/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 593)
# Experiment 6190/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 594)
# Experiment 6192/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 595)
# Experiment 6194/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 596)
# Experiment 6196/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 597)
# Experiment 6198/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 598)
# Experiment 6200/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 599)
# Experiment 6202/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 600)
# Experiment 6204/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 601)
# Experiment 6206/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 602)
# Experiment 6208/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 603)
# Experiment 6210/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 604)
# Experiment 6212/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 605)
# Experiment 6214/5663: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 606)
# Experiment 6216/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 607)
# Experiment 6218/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 608)
# Experiment 6220/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 609)
# Experiment 6222/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 610)
# Experiment 6224/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 611)
# Experiment 6226/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 612)
# Experiment 6228/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 613)
# Experiment 6230/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 614)
# Experiment 6232/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 615)
# Experiment 6234/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 616)
# Experiment 6236/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 617)
# Experiment 6238/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 618)
# Experiment 6240/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 619)
# Experiment 6242/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 620)
# Experiment 6244/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 621)
# Experiment 6246/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 622)
# Experiment 6248/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 623)
# Experiment 6250/5663: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 624)
# Experiment 6252/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 625)
# Experiment 6254/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 626)
# Experiment 6256/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 627)
# Experiment 6258/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 628)
# Experiment 6260/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 629)
# Experiment 6262/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 630)
# Experiment 6264/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 631)
# Experiment 6266/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 632)
# Experiment 6268/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 633)
# Experiment 6270/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 634)
# Experiment 6272/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 635)
# Experiment 6274/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 636)
# Experiment 6276/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 637)
# Experiment 6278/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 638)
# Experiment 6280/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 639)
# Experiment 6282/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 640)
# Experiment 6284/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 641)
# Experiment 6286/5663: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 642)
# Experiment 6288/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 643)
# Experiment 6290/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 644)
# Experiment 6292/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 645)
# Experiment 6294/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 646)
# Experiment 6296/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 647)
# Experiment 6298/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 648)
# Experiment 6300/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 649)
# Experiment 6302/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 650)
# Experiment 6304/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 651)
# Experiment 6306/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 652)
# Experiment 6308/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 653)
# Experiment 6310/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 654)
# Experiment 6312/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 655)
# Experiment 6314/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 656)
# Experiment 6316/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 657)
# Experiment 6318/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 658)
# Experiment 6320/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 659)
# Experiment 6322/5663: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 660)
#
# ======================================================================
# 4. RESULTS SUMMARY
# ======================================================================
# Experiments completed: 660
# Results saved to: results.csv
# Skipped (simulator limit): 0
#
# Origins tested:
#   dj_indep_10q: 90 experiments
#   dj_indep_3q: 45 experiments
#   dj_indep_2q: 30 experiments
#   dj_indep_5q: 75 experiments
#   dj_indep_9q: 90 experiments
#   dj_indep_8q: 90 experiments
#   dj_indep_4q: 60 experiments
#   dj_indep_7q: 90 experiments
#   dj_indep_6q: 90 experiments

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 39 QASM files
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#
# Total circuits loaded: 9
#   Origins: ['dj_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 5663 experiments already completed
# Loaded existing results: 660 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 6323
# Already completed: 5663
# Remaining: 660
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 5664/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 661)
# Experiment 5666/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 662)
# Experiment 5668/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 663)
# Experiment 5670/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 664)
# Experiment 5672/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 665)
# Experiment 5674/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 666)
# Experiment 5676/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 667)
# Experiment 5678/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 668)
# Experiment 5680/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 669)
# Experiment 5682/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 670)
# Experiment 5684/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 671)
# Experiment 5686/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 672)
# Experiment 5688/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 673)
# Experiment 5690/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 674)
# Experiment 5692/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 675)
# Experiment 5694/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 676)
# Experiment 5696/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 677)
# Experiment 5698/6323: dj_indep_10q (10q), local, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 678)
# Experiment 5700/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 679)
# Experiment 5702/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 680)
# Experiment 5704/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 681)
# Experiment 5706/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 682)
# Experiment 5708/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 683)
# Experiment 5710/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 684)
# Experiment 5712/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 685)
# Experiment 5714/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 686)
# Experiment 5716/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 687)
# Experiment 5718/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 688)
# Experiment 5720/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.1x, cat, parts=5
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 689)
# Experiment 5722/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 690)
# Experiment 5724/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 691)
# Experiment 5726/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 692)
# Experiment 5728/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 693)
# Experiment 5730/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 694)
# Experiment 5732/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 695)
# Experiment 5734/6323: dj_indep_10q (10q), local, noise=0.005, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 696)
# Experiment 5736/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 697)
# Experiment 5738/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 698)
# Experiment 5740/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 699)
# Experiment 5742/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 700)
# Experiment 5744/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 701)
# Experiment 5746/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 702)
# Experiment 5748/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 703)
# Experiment 5750/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 704)
# Experiment 5752/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 705)
# Experiment 5754/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 706)
# Experiment 5756/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 707)
# Experiment 5758/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 708)
# Experiment 5760/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 709)
# Experiment 5762/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 710)
# Experiment 5764/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 711)
# Experiment 5766/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 712)
# Experiment 5768/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 713)
# Experiment 5770/6323: dj_indep_10q (10q), local, noise=0.01, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 714)
# Experiment 5772/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 715)
# Experiment 5774/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 716)
# Experiment 5776/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 717)
# Experiment 5778/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 718)
# Experiment 5780/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 719)
# Experiment 5782/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 720)
# Experiment 5784/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 721)
# Experiment 5786/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 722)
# Experiment 5788/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 723)
# Experiment 5790/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 724)
# Experiment 5792/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 725)
# Experiment 5794/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 726)
# Experiment 5796/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 727)
# Experiment 5798/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 728)
# Experiment 5800/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 729)
# Experiment 5802/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 730)
# Experiment 5804/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 731)
# Experiment 5806/6323: dj_indep_10q (10q), local, noise=0.015, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 732)
# Experiment 5808/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.0x, cat, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 733)
# Experiment 5810/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 734)
# Experiment 5812/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 735)
# Experiment 5814/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 736)
# Experiment 5816/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 737)
# Experiment 5818/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 738)
# Experiment 5820/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 739)
# Experiment 5822/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 740)
# Experiment 5824/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 741)
# Experiment 5826/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 742)
# Experiment 5828/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 743)
# Experiment 5830/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 744)
# Experiment 5832/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 745)
# Experiment 5834/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 746)
# Experiment 5836/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 747)
# Experiment 5838/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 748)
# Experiment 5840/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 749)
# Experiment 5842/6323: dj_indep_10q (10q), local, noise=0.02, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 750)
# Experiment 5844/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 751)
# Experiment 5846/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 752)
# Experiment 5848/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 753)
# Experiment 5850/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 754)
# Experiment 5852/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 755)
# Experiment 5854/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 756)
# Experiment 5856/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 757)
# Experiment 5858/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 758)
# Experiment 5860/6323: dj_indep_3q (3q), local, noise=0.001, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 759)
# Experiment 5862/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 760)
# Experiment 5864/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 761)
# Experiment 5866/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 762)
# Experiment 5868/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 763)
# Experiment 5870/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 764)
# Experiment 5872/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 765)
# Experiment 5874/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 766)
# Experiment 5876/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 767)
# Experiment 5878/6323: dj_indep_3q (3q), local, noise=0.005, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 768)
# Experiment 5880/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 769)
# Experiment 5882/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 770)
# Experiment 5884/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 771)
# Experiment 5886/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 772)
# Experiment 5888/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 773)
# Experiment 5890/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 774)
# Experiment 5892/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 775)
# Experiment 5894/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 776)
# Experiment 5896/6323: dj_indep_3q (3q), local, noise=0.01, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 777)
# Experiment 5898/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 778)
# Experiment 5900/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 779)
# Experiment 5902/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 780)
# Experiment 5904/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 781)
# Experiment 5906/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 782)
# Experiment 5908/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 783)
# Experiment 5910/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 784)
# Experiment 5912/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 785)
# Experiment 5914/6323: dj_indep_3q (3q), local, noise=0.015, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 786)
# Experiment 5916/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 787)
# Experiment 5918/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 788)
# Experiment 5920/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 789)
# Experiment 5922/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 790)
# Experiment 5924/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 791)
# Experiment 5926/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 792)
# Experiment 5928/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 793)
# Experiment 5930/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 794)
# Experiment 5932/6323: dj_indep_3q (3q), local, noise=0.02, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 795)
# Experiment 5934/6323: dj_indep_2q (2q), local, noise=0.001, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 796)
# Experiment 5936/6323: dj_indep_2q (2q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 797)
# Experiment 5938/6323: dj_indep_2q (2q), local, noise=0.001, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 798)
# Experiment 5940/6323: dj_indep_2q (2q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 799)
# Experiment 5942/6323: dj_indep_2q (2q), local, noise=0.001, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 800)
# Experiment 5944/6323: dj_indep_2q (2q), local, noise=0.001, comm=1.2x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 801)
# Experiment 5946/6323: dj_indep_2q (2q), local, noise=0.005, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 802)
# Experiment 5948/6323: dj_indep_2q (2q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 803)
# Experiment 5950/6323: dj_indep_2q (2q), local, noise=0.005, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 804)
# Experiment 5952/6323: dj_indep_2q (2q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 805)
# Experiment 5954/6323: dj_indep_2q (2q), local, noise=0.005, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 806)
# Experiment 5956/6323: dj_indep_2q (2q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 807)
# Experiment 5958/6323: dj_indep_2q (2q), local, noise=0.01, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 808)
# Experiment 5960/6323: dj_indep_2q (2q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 809)
# Experiment 5962/6323: dj_indep_2q (2q), local, noise=0.01, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 810)
# Experiment 5964/6323: dj_indep_2q (2q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 811)
# Experiment 5966/6323: dj_indep_2q (2q), local, noise=0.01, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 812)
# Experiment 5968/6323: dj_indep_2q (2q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 813)
# Experiment 5970/6323: dj_indep_2q (2q), local, noise=0.015, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 814)
# Experiment 5972/6323: dj_indep_2q (2q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 815)
# Experiment 5974/6323: dj_indep_2q (2q), local, noise=0.015, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 816)
# Experiment 5976/6323: dj_indep_2q (2q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 817)
# Experiment 5978/6323: dj_indep_2q (2q), local, noise=0.015, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 818)
# Experiment 5980/6323: dj_indep_2q (2q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 819)
# Experiment 5982/6323: dj_indep_2q (2q), local, noise=0.02, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 820)
# Experiment 5984/6323: dj_indep_2q (2q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 821)
# Experiment 5986/6323: dj_indep_2q (2q), local, noise=0.02, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 822)
# Experiment 5988/6323: dj_indep_2q (2q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 823)
# Experiment 5990/6323: dj_indep_2q (2q), local, noise=0.02, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 824)
# Experiment 5992/6323: dj_indep_2q (2q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 825)
# Experiment 5994/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.0x, cat, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 826)
# Experiment 5996/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 827)
# Experiment 5998/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 828)
# Experiment 6000/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 829)
# Experiment 6002/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 830)
# Experiment 6004/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 831)
# Experiment 6006/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 832)
# Experiment 6008/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 833)
# Experiment 6010/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 834)
# Experiment 6012/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 835)
# Experiment 6014/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 836)
# Experiment 6016/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 837)
# Experiment 6018/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 838)
# Experiment 6020/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 839)
# Experiment 6022/6323: dj_indep_5q (5q), local, noise=0.001, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 840)
# Experiment 6024/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 841)
# Experiment 6026/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 842)
# Experiment 6028/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 843)
# Experiment 6030/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 844)
# Experiment 6032/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 845)
# Experiment 6034/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 846)
# Experiment 6036/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 847)
# Experiment 6038/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 848)
# Experiment 6040/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 849)
# Experiment 6042/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 850)
# Experiment 6044/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 851)
# Experiment 6046/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 852)
# Experiment 6048/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 853)
# Experiment 6050/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 854)
# Experiment 6052/6323: dj_indep_5q (5q), local, noise=0.005, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 855)
# Experiment 6054/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 856)
# Experiment 6056/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 857)
# Experiment 6058/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 858)
# Experiment 6060/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 859)
# Experiment 6062/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 860)
# Experiment 6064/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 861)
# Experiment 6066/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 862)
# Experiment 6068/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 863)
# Experiment 6070/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 864)
# Experiment 6072/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 865)
# Experiment 6074/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 866)
# Experiment 6076/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 867)
# Experiment 6078/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 868)
# Experiment 6080/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 869)
# Experiment 6082/6323: dj_indep_5q (5q), local, noise=0.01, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 870)
# Experiment 6084/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 871)
# Experiment 6086/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 872)
# Experiment 6088/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 873)
# Experiment 6090/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 874)
# Experiment 6092/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 875)
# Experiment 6094/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 876)
# Experiment 6096/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 877)
# Experiment 6098/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 878)
# Experiment 6100/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 879)
# Experiment 6102/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 880)
# Experiment 6104/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 881)
# Experiment 6106/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 882)
# Experiment 6108/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 883)
# Experiment 6110/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 884)
# Experiment 6112/6323: dj_indep_5q (5q), local, noise=0.015, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 885)
# Experiment 6114/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 886)
# Experiment 6116/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 887)
# Experiment 6118/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 888)
# Experiment 6120/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 889)
# Experiment 6122/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 890)
# Experiment 6124/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 891)
# Experiment 6126/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 892)
# Experiment 6128/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 893)
# Experiment 6130/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 894)
# Experiment 6132/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 895)
# Experiment 6134/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 896)
# Experiment 6136/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 897)
# Experiment 6138/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 898)
# Experiment 6140/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 899)
# Experiment 6142/6323: dj_indep_5q (5q), local, noise=0.02, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 900)
# Experiment 6144/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 901)
# Experiment 6146/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 902)
# Experiment 6148/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 903)
# Experiment 6150/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 904)
# Experiment 6152/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 905)
# Experiment 6154/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 906)
# Experiment 6156/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 907)
# Experiment 6158/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 908)
# Experiment 6160/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 909)
# Experiment 6162/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 910)
# Experiment 6164/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 911)
# Experiment 6166/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 912)
# Experiment 6168/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 913)
# Experiment 6170/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 914)
# Experiment 6172/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 915)
# Experiment 6174/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 916)
# Experiment 6176/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 917)
# Experiment 6178/6323: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows:
6323: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1282)
# Experiment 6908/6323: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 1283)
# Experiment 6910/6323: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1284)
# Experiment 6912/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 1285)
# Experiment 6914/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1286)
# Experiment 6916/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 1287)
# Experiment 6918/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1288)
# Experiment 6920/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 1289)
# Experiment 6922/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1290)
# Experiment 6924/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 1291)
# Experiment 6926/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1292)
# Experiment 6928/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 1293)
# Experiment 6930/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1294)
# Experiment 6932/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 1295)
# Experiment 6934/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1296)
# Experiment 6936/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 1297)
# Experiment 6938/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1298)
# Experiment 6940/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 1299)
# Experiment 6942/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1300)
# Experiment 6944/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 1301)
# Experiment 6946/6323: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1302)
# Experiment 6948/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=1
#   SUCCESS - Saved (Total rows: 1303)
# Experiment 6950/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1304)
# Experiment 6952/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=3
#   SUCCESS - Saved (Total rows: 1305)
# Experiment 6954/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1306)
# Experiment 6956/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=5
#   SUCCESS - Saved (Total rows: 1307)
# Experiment 6958/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1308)
# Experiment 6960/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=1
#   SUCCESS - Saved (Total rows: 1309)
# Experiment 6962/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1310)
# Experiment 6964/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=3
#   SUCCESS - Saved (Total rows: 1311)
# Experiment 6966/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1312)
# Experiment 6968/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=5
#   SUCCESS - Saved (Total rows: 1313)
# Experiment 6970/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1314)
# Experiment 6972/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=1
#   SUCCESS - Saved (Total rows: 1315)
# Experiment 6974/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 1316)
# Experiment 6976/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=3
#   SUCCESS - Saved (Total rows: 1317)
# Experiment 6978/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 1318)
# Experiment 6980/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=5
#   SUCCESS - Saved (Total rows: 1319)
# Experiment 6982/6323: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 1320)
#
# ======================================================================
# 4. RESULTS SUMMARY
# ======================================================================
# Experiments completed: 1320
# Results saved to: results.csv
# Skipped (simulator limit): 0
#
# Origins tested:
#   dj_indep_10q: 180 experiments
#   dj_indep_3q: 90 experiments
#   dj_indep_2q: 60 experiments
#   dj_indep_5q: 150 experiments
#   dj_indep_9q: 180 experiments
#   dj_indep_8q: 180 experiments
#   dj_indep_4q: 120 experiments
#   dj_indep_7q: 180 experiments
#   dj_indep_6q: 180 experiments

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 39 QASM files
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#
# Total circuits loaded: 9
#   Origins: ['dj_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 6323 experiments already completed
# Loaded existing results: 1320 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 6983
# Already completed: 6323
# Remaining: 660
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 6324/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 1321)
# Experiment 6326/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1322)
# Experiment 6328/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1323)
# Experiment 6330/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=4
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6332/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=5
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'No counts for experiment "0"'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6334/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=6
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6336/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'Number of qubits (34) in circuit-79979 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   SUCCESS - Saved (Total rows: 1324)
# Experiment 6338/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1325)
# Experiment 6340/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1326)
# Experiment 6342/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=4
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6344/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=5
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'No counts for experiment "0"'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6346/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=6
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6348/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'Number of qubits (34) in circuit-80248 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   SUCCESS - Saved (Total rows: 1327)
# Experiment 6350/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1328)
# Experiment 6352/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1329)
# Experiment 6354/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=4
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6356/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=5
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'No counts for experiment "0"'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6358/6983: dj_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=6
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6360/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'Number of qubits (34) in circuit-80517 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   SUCCESS - Saved (Total rows: 1330)
# Experiment 6362/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1331)
# Experiment 6364/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1332)
# Experiment 6366/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=4
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6368/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=5
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'No counts for experiment "0"'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6370/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=6
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6372/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'Number of qubits (34) in circuit-80786 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 1333)
# Experiment 6374/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1334)
# Experiment 6376/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 1335)
# Experiment 6378/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=4
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6380/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=5
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'No counts for experiment "0"'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6382/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=6
#   ERROR: Division by zero - division by zero
#   This experiment likely failed due to uniform distribution output
# Experiment 6384/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:107: UserWarning: Circuit execution failed: 'Number of qubits (34) in circuit-81055 is greater than maximum (31) in the coupling_map'. Returning uniform distribution.
#   warnings.warn(f"Circuit execution failed: {e}. Returning uniform distribution.")
#   SUCCESS - Saved (Total rows: 1336)
# Experiment 6386/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 1337)
# Experiment 6388/6983: dj_indep_10q (10q), global, noise=0.005, comm=1.2x, tp, parts=3

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
