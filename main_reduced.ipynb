# %%
from mqt import run_mqt_bench_experiments_incremental

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 7 QASM files
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#
# Total circuits loaded: 7
#   Origins: ['dj_indep']
#   Qubit range: 3 - 9
#
# Loaded progress: 785 experiments already completed
# Loaded existing results: 58 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 1040
# Already completed: 785
# Remaining: 255
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 786/1040: dj_indep_3q (3q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 59)
# Experiment 788/1040: dj_indep_3q (3q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 60)
# Experiment 790/1040: dj_indep_3q (3q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 61)
# Experiment 792/1040: dj_indep_3q (3q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 62)
# Experiment 794/1040: dj_indep_3q (3q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 63)
# Experiment 796/1040: dj_indep_3q (3q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 64)
# Experiment 798/1040: dj_indep_3q (3q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 65)
# Experiment 800/1040: dj_indep_3q (3q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 66)
# Experiment 802/1040: dj_indep_3q (3q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 67)
# Experiment 804/1040: dj_indep_3q (3q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 68)
# Experiment 806/1040: dj_indep_3q (3q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 69)
# Experiment 808/1040: dj_indep_3q (3q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 70)
# Experiment 810/1040: dj_indep_3q (3q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 71)
# Experiment 812/1040: dj_indep_3q (3q), local, noise=0.02, comm=1.1x, cat, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 72)
# Experiment 814/1040: dj_indep_3q (3q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 73)
# Experiment 816/1040: dj_indep_5q (5q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 74)
# Experiment 818/1040: dj_indep_5q (5q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 75)
# Experiment 820/1040: dj_indep_5q (5q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 76)
# Experiment 822/1040: dj_indep_5q (5q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 77)
# Experiment 824/1040: dj_indep_5q (5q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 78)
# Experiment 826/1040: dj_indep_5q (5q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 79)
# Experiment 828/1040: dj_indep_5q (5q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 80)
# Experiment 830/1040: dj_indep_5q (5q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 81)
# Experiment 832/1040: dj_indep_5q (5q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 82)
# Experiment 834/1040: dj_indep_5q (5q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 83)
# Experiment 836/1040: dj_indep_5q (5q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 84)
# Experiment 838/1040: dj_indep_5q (5q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 85)
# Experiment 840/1040: dj_indep_5q (5q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 86)
# Experiment 842/1040: dj_indep_5q (5q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 87)
# Experiment 844/1040: dj_indep_5q (5q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 88)
# Experiment 846/1040: dj_indep_5q (5q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 89)
# Experiment 848/1040: dj_indep_5q (5q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 90)
# Experiment 850/1040: dj_indep_5q (5q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 91)
# Experiment 852/1040: dj_indep_5q (5q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 92)
# Experiment 854/1040: dj_indep_5q (5q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 93)
# Experiment 856/1040: dj_indep_5q (5q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 94)
# Experiment 858/1040: dj_indep_5q (5q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 95)
# Experiment 860/1040: dj_indep_5q (5q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 96)
# Experiment 862/1040: dj_indep_5q (5q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 97)
# Experiment 864/1040: dj_indep_5q (5q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 98)
# Experiment 866/1040: dj_indep_5q (5q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 99)
# Experiment 868/1040: dj_indep_5q (5q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 100)
# Experiment 870/1040: dj_indep_5q (5q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 101)
# Experiment 872/1040: dj_indep_5q (5q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 102)
# Experiment 874/1040: dj_indep_5q (5q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 103)
# Experiment 876/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 104)
# Experiment 878/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 105)
# Experiment 880/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 106)
# Experiment 882/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 107)
# Experiment 884/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 108)
# Experiment 886/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 109)
# Experiment 888/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 110)
# Experiment 890/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 111)
# Experiment 892/1040: dj_indep_9q (9q), local, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 112)
# Experiment 894/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 113)
# Experiment 896/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 114)
# Experiment 898/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 115)
# Experiment 900/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 116)
# Experiment 902/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 117)
# Experiment 904/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 118)
# Experiment 906/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 119)
# Experiment 908/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 120)
# Experiment 910/1040: dj_indep_9q (9q), local, noise=0.005, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 121)
# Experiment 912/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 122)
# Experiment 914/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 123)
# Experiment 916/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 124)
# Experiment 918/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 125)
# Experiment 920/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 126)
# Experiment 922/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 127)
# Experiment 924/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 128)
# Experiment 926/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 129)
# Experiment 928/1040: dj_indep_9q (9q), local, noise=0.01, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 130)
# Experiment 930/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 131)
# Experiment 932/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 132)
# Experiment 934/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 133)
# Experiment 936/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 134)
# Experiment 938/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 135)
# Experiment 940/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 136)
# Experiment 942/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 137)
# Experiment 944/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 138)
# Experiment 946/1040: dj_indep_9q (9q), local, noise=0.015, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 139)
# Experiment 948/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 140)
# Experiment 950/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 141)
# Experiment 952/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 142)
# Experiment 954/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 143)
# Experiment 956/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 144)
# Experiment 958/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 145)
# Experiment 960/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 146)
# Experiment 962/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 147)
# Experiment 964/1040: dj_indep_9q (9q), local, noise=0.02, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 148)
# Experiment 966/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 149)
# Experiment 968/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 150)
# Experiment 970/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 151)
# Experiment 972/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 152)
# Experiment 974/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 153)
# Experiment 976/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 154)
# Experiment 978/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 155)
# Experiment 980/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 156)
# Experiment 982/1040: dj_indep_8q (8q), local, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 157)
# Experiment 984/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 158)
# Experiment 986/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 159)
# Experiment 988/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 160)
# Experiment 990/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 161)
# Experiment 992/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 162)
# Experiment 994/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 163)
# Experiment 996/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 164)
# Experiment 998/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 165)
# Experiment 1000/1040: dj_indep_8q (8q), local, noise=0.005, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 166)
# Experiment 1002/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 167)
# Experiment 1004/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 168)
# Experiment 1006/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 169)
# Experiment 1008/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 170)
# Experiment 1010/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 171)
# Experiment 1012/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 172)
# Experiment 1014/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 173)
# Experiment 1016/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 174)
# Experiment 1018/1040: dj_indep_8q (8q), local, noise=0.01, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 175)
# Experiment 1020/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 176)
# Experiment 1022/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 177)
# Experiment 1024/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 178)
# Experiment 1026/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 179)
# Experiment 1028/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 180)
# Experiment 1030/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 181)
# Experiment 1032/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 182)
# Experiment 1034/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 183)
# Experiment 1036/1040: dj_indep_8q (8q), local, noise=0.015, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 184)
# Experiment 1038/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 185)
# Experiment 1040/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 186)
# Experiment 1042/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 187)
# Experiment 1044/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 188)
# Experiment 1046/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 189)
# Experiment 1048/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 190)
# Experiment 1050/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 191)
# Experiment 1052/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 192)
# Experiment 1054/1040: dj_indep_8q (8q), local, noise=0.02, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 193)
# Experiment 1056/1040: dj_indep_4q (4q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 194)
# Experiment 1058/1040: dj_indep_4q (4q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 195)
# Experiment 1060/1040: dj_indep_4q (4q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 196)
# Experiment 1062/1040: dj_indep_4q (4q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 197)
# Experiment 1064/1040: dj_indep_4q (4q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 198)
# Experiment 1066/1040: dj_indep_4q (4q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 199)
# Experiment 1068/1040: dj_indep_4q (4q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 200)
# Experiment 1070/1040: dj_indep_4q (4q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 201)
# Experiment 1072/1040: dj_indep_4q (4q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 202)
# Experiment 1074/1040: dj_indep_4q (4q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 203)
# Experiment 1076/1040: dj_indep_4q (4q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 204)
# Experiment 1078/1040: dj_indep_4q (4q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 205)
# Experiment 1080/1040: dj_indep_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 206)
# Experiment 1082/1040: dj_indep_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 207)
# Experiment 1084/1040: dj_indep_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 208)
# Experiment 1086/1040: dj_indep_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 209)
# Experiment 1088/1040: dj_indep_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 210)
# Experiment 1090/1040: dj_indep_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 211)
# Experiment 1092/1040: dj_indep_4q (4q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 212)
# Experiment 1094/1040: dj_indep_4q (4q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 213)
# Experiment 1096/1040: dj_indep_4q (4q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 214)
# Experiment 1098/1040: dj_indep_4q (4q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 215)
# Experiment 1100/1040: dj_indep_4q (4q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 216)
# Experiment 1102/1040: dj_indep_4q (4q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 217)
# Experiment 1104/1040: dj_indep_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 218)
# Experiment 1106/1040: dj_indep_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 219)
# Experiment 1108/1040: dj_indep_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 220)
# Experiment 1110/1040: dj_indep_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 221)
# Experiment 1112/1040: dj_indep_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 222)
# Experiment 1114/1040: dj_indep_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 223)
# Experiment 1116/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 224)
# Experiment 1118/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 225)
# Experiment 1120/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 226)
# Experiment 1122/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 227)
# Experiment 1124/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 228)
# Experiment 1126/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 229)
# Experiment 1128/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 230)
# Experiment 1130/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 231)
# Experiment 1132/1040: dj_indep_7q (7q), local, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 232)
# Experiment 1134/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 233)
# Experiment 1136/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 234)
# Experiment 1138/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 235)
# Experiment 1140/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 236)
# Experiment 1142/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.1x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 237)
# Experiment 1144/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 238)
# Experiment 1146/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 239)
# Experiment 1148/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 240)
# Experiment 1150/1040: dj_indep_7q (7q), local, noise=0.005, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 241)
# Experiment 1152/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 242)
# Experiment 1154/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 243)
# Experiment 1156/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 244)
# Experiment 1158/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 245)
# Experiment 1160/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 246)
# Experiment 1162/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 247)
# Experiment 1164/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 248)
# Experiment 1166/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 249)
# Experiment 1168/1040: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 250)
# Experiment 1170/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 251)
# Experiment 1172/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 252)
# Experiment 1174/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 253)
# Experiment 1176/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 254)
# Experiment 1178/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 255)
# Experiment 1180/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 256)
# Experiment 1182/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 257)
# Experiment 1184/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 258)
# Experiment 1186/1040: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 259)
# Experiment 1188/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 260)
# Experiment 1190/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 261)
# Experiment 1192/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 262)
# Experiment 1194/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 263)
# Experiment 1196/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 264)
# Experiment 1198/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 265)
# Experiment 1200/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 266)
# Experiment 1202/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 267)
# Experiment 1204/1040: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 268)
# Experiment 1206/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 269)
# Experiment 1208/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 270)
# Experiment 1210/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 271)
# Experiment 1212/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 272)
# Experiment 1214/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 273)
# Experiment 1216/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 274)
# Experiment 1218/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 275)
# Experiment 1220/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 276)
# Experiment 1222/1040: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 277)
# Experiment 1224/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 278)
# Experiment 1226/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 279)
# Experiment 1228/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 280)
# Experiment 1230/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 281)
# Experiment 1232/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 282)
# Experiment 1234/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 283)
# Experiment 1236/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 284)
# Experiment 1238/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 285)
# Experiment 1240/1040: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 286)
# Experiment 1242/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 287)
# Experiment 1244/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 288)
# Experiment 1246/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 289)
# Experiment 1248/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 290)
# Experiment 1250/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 291)
# Experiment 1252/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 292)
# Experiment 1254/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 293)
# Experiment 1256/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 294)
# Experiment 1258/1040: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 295)
# Experiment 1260/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 296)
# Experiment 1262/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 297)
# Experiment 1264/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 298)
# Experiment 1266/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 299)
# Experiment 1268/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 300)
# Experiment 1270/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 301)
# Experiment 1272/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 302)
# Experiment 1274/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 303)
# Experiment 1276/1040: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 304)
# Experiment 1278/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 305)
# Experiment 1280/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 306)
# Experiment 1282/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 307)
# Experiment 1284/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 308)
# Experiment 1286/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 309)
# Experiment 1288/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 310)
# Experiment 1290/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 311)
# Experiment 1292/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 312)
# Experiment 1294/1040: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 313)
#
# ======================================================================
# 4. RESULTS SUMMARY
# ======================================================================
# Experiments completed: 313
# Results saved to: results.csv
# Skipped (simulator limit): 0
#
# Origins tested:
#   dj_indep_10q: 43 experiments
#   dj_indep_2q: 15 experiments
#   dj_indep_3q: 15 experiments
#   dj_indep_5q: 30 experiments
#   dj_indep_9q: 45 experiments
#   dj_indep_8q: 45 experiments
#   dj_indep_4q: 30 experiments
#   dj_indep_7q: 45 experiments
#   dj_indep_6q: 45 experiments

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 7 QASM files
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#
# Total circuits loaded: 7
#   Origins: ['dj_indep']
#   Qubit range: 3 - 9
#
# Loaded progress: 1040 experiments already completed
# Loaded existing results: 313 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 1295
# Already completed: 1040
# Remaining: 255
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 1041/1295: dj_indep_3q (3q), global, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 314)
# Experiment 1043/1295: dj_indep_3q (3q), global, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 315)
# Experiment 1045/1295: dj_indep_3q (3q), global, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 316)
# Experiment 1047/1295: dj_indep_3q (3q), global, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 317)
# Experiment 1049/1295: dj_indep_3q (3q), global, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 318)
# Experiment 1051/1295: dj_indep_3q (3q), global, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 319)
# Experiment 1053/1295: dj_indep_3q (3q), global, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 320)
# Experiment 1055/1295: dj_indep_3q (3q), global, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 321)
# Experiment 1057/1295: dj_indep_3q (3q), global, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 322)
# Experiment 1059/1295: dj_indep_3q (3q), global, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 323)
# Experiment 1061/1295: dj_indep_3q (3q), global, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 324)
# Experiment 1063/1295: dj_indep_3q (3q), global, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 325)
# Experiment 1065/1295: dj_indep_3q (3q), global, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 326)
# Experiment 1067/1295: dj_indep_3q (3q), global, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 327)
# Experiment 1069/1295: dj_indep_3q (3q), global, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 328)
# Experiment 1071/1295: dj_indep_5q (5q), global, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 329)
# Experiment 1073/1295: dj_indep_5q (5q), global, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 330)
# Experiment 1075/1295: dj_indep_5q (5q), global, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 331)
# Experiment 1077/1295: dj_indep_5q (5q), global, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 332)
# Experiment 1079/1295: dj_indep_5q (5q), global, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 333)
# Experiment 1081/1295: dj_indep_5q (5q), global, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 334)
# Experiment 1083/1295: dj_indep_5q (5q), global, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 335)
# Experiment 1085/1295: dj_indep_5q (5q), global, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 336)
# Experiment 1087/1295: dj_indep_5q (5q), global, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 337)
# Experiment 1089/1295: dj_indep_5q (5q), global, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 338)
# Experiment 1091/1295: dj_indep_5q (5q), global, noise=0.005, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 339)
# Experiment 1093/1295: dj_indep_5q (5q), global, noise=0.005, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 340)
# Experiment 1095/1295: dj_indep_5q (5q), global, noise=0.01, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 341)
# Experiment 1097/1295: dj_indep_5q (5q), global, noise=0.01, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 342)
# Experiment 1099/1295: dj_indep_5q (5q), global, noise=0.01, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 343)
# Experiment 1101/1295: dj_indep_5q (5q), global, noise=0.01, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 344)
# Experiment 1103/1295: dj_indep_5q (5q), global, noise=0.01, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 345)
# Experiment 1105/1295: dj_indep_5q (5q), global, noise=0.01, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 346)
# Experiment 1107/1295: dj_indep_5q (5q), global, noise=0.015, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 347)
# Experiment 1109/1295: dj_indep_5q (5q), global, noise=0.015, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 348)
# Experiment 1111/1295: dj_indep_5q (5q), global, noise=0.015, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 349)
# Experiment 1113/1295: dj_indep_5q (5q), global, noise=0.015, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 350)
# Experiment 1115/1295: dj_indep_5q (5q), global, noise=0.015, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 351)
# Experiment 1117/1295: dj_indep_5q (5q), global, noise=0.015, comm=1.2x, cat, parts=4
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 352)
# Experiment 1119/1295: dj_indep_5q (5q), global, noise=0.02, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 353)
# Experiment 1121/1295: dj_indep_5q (5q), global, noise=0.02, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 354)
# Experiment 1123/1295: dj_indep_5q (5q), global, noise=0.02, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 355)
# Experiment 1125/1295: dj_indep_5q (5q), global, noise=0.02, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 356)
# Experiment 1127/1295: dj_indep_5q (5q), global, noise=0.02, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 357)
# Experiment 1129/1295: dj_indep_5q (5q), global, noise=0.02, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 358)
# Experiment 1131/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 359)
# Experiment 1133/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 360)
# Experiment 1135/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 361)
# Experiment 1137/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 362)
# Experiment 1139/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 363)
# Experiment 1141/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 364)
# Experiment 1143/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.2x, cat, parts=2
#   SUCCESS - Saved (Total rows: 365)
# Experiment 1145/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.2x, cat, parts=4
#   SUCCESS - Saved (Total rows: 366)
# Experiment 1147/1295: dj_indep_9q (9q), global, noise=0.001, comm=1.2x, cat, parts=6
#   SUCCESS - Saved (Total rows: 367)
# Experiment 1149/1295: dj_indep_9q (9q), global, noise=0.005, comm=1.0x, cat, parts=2
#   SUCCESS - Saved (Total rows: 368)
# Experiment 1151/1295: dj_indep_9q (9q), global, noise=0.005, comm=1.0x, cat, parts=4
#   SUCCESS - Saved (Total rows: 369)
# Experiment 1153/1295: dj_indep_9q (9q), global, noise=0.005, comm=1.0x, cat, parts=6
#   SUCCESS - Saved (Total rows: 370)
# Experiment 1155/1295: dj_indep_9q (9q), global, noise=0.005, comm=1.1x, cat, parts=2
#   SUCCESS - Saved (Total rows: 371)
# Experiment 1157/1295: dj_indep_9q (9q), global, noise=0.005, comm=1.1x, cat, parts=4
#   SUCCESS - Saved (Total rows: 372)
# Experiment 1159/1295: dj_indep_9q (9q), global, noise=0.005, comm=1.1x, cat, parts=6
#   SUCCESS - Saved (Total rows: 373)
# Experiment 1161/1295: dj_indep_9q (9q), global, noise=0.005, comm=1.2x, cat, parts=2
