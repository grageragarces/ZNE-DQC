# %%
from mqt import run_mqt_bench_experiments_incremental

# %% [markdown]
# after this is the 15 qubit range

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=10,
    max_qubits=15,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 39 QASM files
#   Loading: ghz_indep_qiskit_15.qasm -> ghz_indep (15 qubits)
#     LOADED: ghz_indep_15q, depth=15
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: wstate_indep_qiskit_11.qasm -> wstate_indep (11 qubits)
#     LOADED: wstate_indep_11q, depth=22
#   Loading: dj_indep_qiskit_11.qasm -> dj_indep (11 qubits)
#     LOADED: dj_indep_11q, depth=12
#   Loading: ghz_indep_qiskit_14.qasm -> ghz_indep (14 qubits)
#     LOADED: ghz_indep_14q, depth=14
#   Loading: ghz_indep_qiskit_13.qasm -> ghz_indep (13 qubits)
#     LOADED: ghz_indep_13q, depth=13
#   Loading: ghz_indep_qiskit_12.qasm -> ghz_indep (12 qubits)
#     LOADED: ghz_indep_12q, depth=12
#   Loading: wstate_indep_qiskit_14.qasm -> wstate_indep (14 qubits)
#     LOADED: wstate_indep_14q, depth=28
#   Loading: dj_indep_qiskit_14.qasm -> dj_indep (14 qubits)
#     LOADED: dj_indep_14q, depth=15
#   Loading: ghz_indep_qiskit_11.qasm -> ghz_indep (11 qubits)
#     LOADED: ghz_indep_11q, depth=11
#   Loading: dj_indep_qiskit_15.qasm -> dj_indep (15 qubits)
#     LOADED: dj_indep_15q, depth=16
#   Loading: wstate_indep_qiskit_15.qasm -> wstate_indep (15 qubits)
#     LOADED: wstate_indep_15q, depth=30
#   Loading: wstate_indep_qiskit_12.qasm -> wstate_indep (12 qubits)
#     LOADED: wstate_indep_12q, depth=24
#   Loading: dj_indep_qiskit_12.qasm -> dj_indep (12 qubits)
#     LOADED: dj_indep_12q, depth=13
#   Loading: dj_indep_qiskit_13.qasm -> dj_indep (13 qubits)
#     LOADED: dj_indep_13q, depth=14
#   Loading: wstate_indep_qiskit_13.qasm -> wstate_indep (13 qubits)
#     LOADED: wstate_indep_13q, depth=26
#
# Total circuits loaded: 16
#   Origins: ['ghz_indep', 'dj_indep', 'wstate_indep']
#   Qubit range: 10 - 15
#
# Loaded progress: 7891 experiments already completed
# Loaded existing results: 2843 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 9241
# Already completed: 7891
# Remaining: 1350
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 7892/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2844)
# Experiment 7894/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2845)
# Experiment 7896/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2846)
# Experiment 7898/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2847)
# Experiment 7900/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2848)
# Experiment 7902/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2849)
# Experiment 7904/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2850)
# Experiment 7906/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2851)
# Experiment 7908/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2852)
# Experiment 7910/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2853)
# Experiment 7912/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2854)
# Experiment 7914/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2855)
# Experiment 7916/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2856)
# Experiment 7918/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2857)
# Experiment 7920/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2858)
# Experiment 7922/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2859)
# Experiment 7924/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2860)
# Experiment 7926/9241: ghz_indep_15q (15q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2861)
# Experiment 7928/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2862)
# Experiment 7930/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2863)
# Experiment 7932/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2864)
# Experiment 7934/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2865)
# Experiment 7936/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2866)
# Experiment 7938/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2867)
# Experiment 7940/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 2868)
# Experiment 7942/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2869)
# Experiment 7944/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2870)
# Experiment 7946/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2871)
# Experiment 7948/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2872)
# Experiment 7950/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2873)
# Experiment 7952/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2874)
# Experiment 7954/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2875)
# Experiment 7956/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2876)
# Experiment 7958/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2877)
# Experiment 7960/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2878)
# Experiment 7962/9241: ghz_indep_15q (15q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2879)
# Experiment 7964/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2880)
# Experiment 7966/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2881)
# Experiment 7968/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2882)
# Experiment 7970/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2883)
# Experiment 7972/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2884)
# Experiment 7974/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2885)
# Experiment 7976/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2886)
# Experiment 7978/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2887)
# Experiment 7980/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2888)
# Experiment 7982/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2889)
# Experiment 7984/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2890)
# Experiment 7986/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2891)
# Experiment 7988/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2892)
# Experiment 7990/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2893)
# Experiment 7992/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2894)
# Experiment 7994/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2895)
# Experiment 7996/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2896)
# Experiment 7998/9241: ghz_indep_15q (15q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2897)
# Experiment 8000/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2898)
# Experiment 8002/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2899)
# Experiment 8004/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2900)
# Experiment 8006/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2901)
# Experiment 8008/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2902)
# Experiment 8010/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2903)
# Experiment 8012/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2904)
# Experiment 8014/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2905)
# Experiment 8016/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2906)
# Experiment 8018/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2907)
# Experiment 8020/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2908)
# Experiment 8022/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2909)
# Experiment 8024/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2910)
# Experiment 8026/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2911)
# Experiment 8028/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2912)
# Experiment 8030/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2913)
# Experiment 8032/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2914)
# Experiment 8034/9241: ghz_indep_15q (15q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2915)
# Experiment 8036/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2916)
# Experiment 8038/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2917)
# Experiment 8040/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2918)
# Experiment 8042/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2919)
# Experiment 8044/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2920)
# Experiment 8046/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2921)
# Experiment 8048/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2922)
# Experiment 8050/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2923)
# Experiment 8052/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2924)
# Experiment 8054/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2925)
# Experiment 8056/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2926)
# Experiment 8058/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2927)
# Experiment 8060/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2928)
# Experiment 8062/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2929)
# Experiment 8064/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2930)
# Experiment 8066/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2931)
# Experiment 8068/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2932)
# Experiment 8070/9241: ghz_indep_15q (15q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2933)
# Experiment 8072/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 2934)
# Experiment 8074/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2935)
# Experiment 8076/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2936)
# Experiment 8078/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2937)
# Experiment 8080/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2938)
# Experiment 8082/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2939)
# Experiment 8084/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 2940)
# Experiment 8086/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2941)
# Experiment 8088/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2942)
# Experiment 8090/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2943)
# Experiment 8092/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2944)
# Experiment 8094/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2945)
# Experiment 8096/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 2946)
# Experiment 8098/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2947)
# Experiment 8100/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2948)
# Experiment 8102/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2949)
# Experiment 8104/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2950)
# Experiment 8106/9241: ghz_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2951)
# Experiment 8108/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 2952)
# Experiment 8110/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2953)
# Experiment 8112/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2954)
# Experiment 8114/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2955)
# Experiment 8116/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2956)
# Experiment 8118/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2957)
# Experiment 8120/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 2958)
# Experiment 8122/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2959)
# Experiment 8124/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2960)
# Experiment 8126/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2961)
# Experiment 8128/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2962)
# Experiment 8130/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2963)
# Experiment 8132/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2964)
# Experiment 8134/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2965)
# Experiment 8136/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2966)
# Experiment 8138/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2967)
# Experiment 8140/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2968)
# Experiment 8142/9241: ghz_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2969)
# Experiment 8144/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 2970)
# Experiment 8146/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2971)
# Experiment 8148/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2972)
# Experiment 8150/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2973)
# Experiment 8152/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2974)
# Experiment 8154/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2975)
# Experiment 8156/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2976)
# Experiment 8158/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2977)
# Experiment 8160/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2978)
# Experiment 8162/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2979)
# Experiment 8164/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2980)
# Experiment 8166/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2981)
# Experiment 8168/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2982)
# Experiment 8170/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2983)
# Experiment 8172/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2984)
# Experiment 8174/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2985)
# Experiment 8176/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2986)
# Experiment 8178/9241: ghz_indep_14q (14q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2987)
# Experiment 8180/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2988)
# Experiment 8182/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2989)
# Experiment 8184/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2990)
# Experiment 8186/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2991)
# Experiment 8188/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2992)
# Experiment 8190/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2993)
# Experiment 8192/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 2994)
# Experiment 8194/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 2995)
# Experiment 8196/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 2996)
# Experiment 8198/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 2997)
# Experiment 8200/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 2998)
# Experiment 8202/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 2999)
# Experiment 8204/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3000)
# Experiment 8206/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3001)
# Experiment 8208/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3002)
# Experiment 8210/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3003)
# Experiment 8212/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3004)
# Experiment 8214/9241: ghz_indep_14q (14q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3005)
# Experiment 8216/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3006)
# Experiment 8218/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3007)
# Experiment 8220/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3008)
# Experiment 8222/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3009)
# Experiment 8224/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3010)
# Experiment 8226/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3011)
# Experiment 8228/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3012)
# Experiment 8230/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3013)
# Experiment 8232/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3014)
# Experiment 8234/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3015)
# Experiment 8236/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3016)
# Experiment 8238/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3017)
# Experiment 8240/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3018)
# Experiment 8242/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3019)
# Experiment 8244/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3020)
# Experiment 8246/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3021)
# Experiment 8248/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3022)
# Experiment 8250/9241: ghz_indep_14q (14q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3023)
# Experiment 8252/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3024)
# Experiment 8254/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3025)
# Experiment 8256/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3026)
# Experiment 8258/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3027)
# Experiment 8260/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3028)
# Experiment 8262/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3029)
# Experiment 8264/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3030)
# Experiment 8266/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3031)
# Experiment 8268/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3032)
# Experiment 8270/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3033)
# Experiment 8272/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3034)
# Experiment 8274/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3035)
# Experiment 8276/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3036)
# Experiment 8278/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3037)
# Experiment 8280/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3038)
# Experiment 8282/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3039)
# Experiment 8284/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3040)
# Experiment 8286/9241: ghz_indep_13q (13q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3041)
# Experiment 8288/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3042)
# Experiment 8290/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3043)
# Experiment 8292/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3044)
# Experiment 8294/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3045)
# Experiment 8296/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3046)
# Experiment 8298/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3047)
# Experiment 8300/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3048)
# Experiment 8302/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3049)
# Experiment 8304/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3050)
# Experiment 8306/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3051)
# Experiment 8308/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3052)
# Experiment 8310/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3053)
# Experiment 8312/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3054)
# Experiment 8314/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3055)
# Experiment 8316/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3056)
# Experiment 8318/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3057)
# Experiment 8320/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3058)
# Experiment 8322/9241: ghz_indep_13q (13q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3059)
# Experiment 8324/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3060)
# Experiment 8326/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3061)
# Experiment 8328/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3062)
# Experiment 8330/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3063)
# Experiment 8332/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3064)
# Experiment 8334/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3065)
# Experiment 8336/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3066)
# Experiment 8338/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3067)
# Experiment 8340/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3068)
# Experiment 8342/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3069)
# Experiment 8344/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3070)
# Experiment 8346/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3071)
# Experiment 8348/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3072)
# Experiment 8350/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3073)
# Experiment 8352/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3074)
# Experiment 8354/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3075)
# Experiment 8356/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3076)
# Experiment 8358/9241: ghz_indep_13q (13q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3077)
# Experiment 8360/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3078)
# Experiment 8362/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3079)
# Experiment 8364/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3080)
# Experiment 8366/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3081)
# Experiment 8368/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3082)
# Experiment 8370/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3083)
# Experiment 8372/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3084)
# Experiment 8374/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3085)
# Experiment 8376/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3086)
# Experiment 8378/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3087)
# Experiment 8380/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3088)
# Experiment 8382/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3089)
# Experiment 8384/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3090)
# Experiment 8386/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3091)
# Experiment 8388/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3092)
# Experiment 8390/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3093)
# Experiment 8392/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3094)
# Experiment 8394/9241: ghz_indep_13q (13q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3095)
# Experiment 8396/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3096)
# Experiment 8398/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3097)
# Experiment 8400/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3098)
# Experiment 8402/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3099)
# Experiment 8404/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3100)
# Experiment 8406/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3101)
# Experiment 8408/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3102)
# Experiment 8410/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3103)
# Experiment 8412/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3104)
# Experiment 8414/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3105)
# Experiment 8416/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3106)
# Experiment 8418/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3107)
# Experiment 8420/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3108)
# Experiment 8422/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.2x, tp, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3109)
# Experiment 8424/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3110)
# Experiment 8426/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3111)
# Experiment 8428/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3112)
# Experiment 8430/9241: ghz_indep_13q (13q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3113)
# Experiment 8432/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3114)
# Experiment 8434/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3115)
# Experiment 8436/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3116)
# Experiment 8438/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3117)
# Experiment 8440/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3118)
# Experiment 8442/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3119)
# Experiment 8444/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3120)
# Experiment 8446/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3121)
# Experiment 8448/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3122)
# Experiment 8450/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3123)
# Experiment 8452/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3124)
# Experiment 8454/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3125)
# Experiment 8456/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3126)
# Experiment 8458/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3127)
# Experiment 8460/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3128)
# Experiment 8462/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3129)
# Experiment 8464/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3130)
# Experiment 8466/9241: ghz_indep_12q (12q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3131)
# Experiment 8468/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3132)
# Experiment 8470/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3133)
# Experiment 8472/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3134)
# Experiment 8474/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3135)
# Experiment 8476/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3136)
# Experiment 8478/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3137)
# Experiment 8480/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3138)
# Experiment 8482/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3139)
# Experiment 8484/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3140)
# Experiment 8486/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3141)
# Experiment 8488/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3142)
# Experiment 8490/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3143)
# Experiment 8492/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3144)
# Experiment 8494/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3145)
# Experiment 8496/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3146)
# Experiment 8498/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3147)
# Experiment 8500/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3148)
# Experiment 8502/9241: ghz_indep_12q (12q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3149)
# Experiment 8504/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3150)
# Experiment 8506/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3151)
# Experiment 8508/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3152)
# Experiment 8510/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3153)
# Experiment 8512/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3154)
# Experiment 8514/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3155)
# Experiment 8516/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3156)
# Experiment 8518/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3157)
# Experiment 8520/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3158)
# Experiment 8522/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3159)
# Experiment 8524/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3160)
# Experiment 8526/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3161)
# Experiment 8528/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3162)
# Experiment 8530/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3163)
# Experiment 8532/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3164)
# Experiment 8534/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3165)
# Experiment 8536/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3166)
# Experiment 8538/9241: ghz_indep_12q (12q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3167)
# Experiment 8540/9241: ghz_indep_12q (12q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3168)
# Experiment 8542/9241: ghz_indep_12q (12q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3169)
# Experiment 8544/9241: ghz_indep_12q (12q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3170)
# Experiment 8546/9241: ghz_indep_12q (12q), local, noise=0.015, comm=1.0x, tp, parts=4
# ...
#   SUCCESS - Saved (Total rows: 3303)
# Experiment 8812/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3304)
# Experiment 8814/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3305)
# Experiment 8816/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3306)
# Experiment 8818/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3307)
# Experiment 8820/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3308)
# Experiment 8822/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3309)
# Experiment 8824/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3310)
# Experiment 8826/9241: dj_indep_11q (11q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3311)
# Experiment 8828/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3312)
# Experiment 8830/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3313)
# Experiment 8832/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3314)
# Experiment 8834/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3315)
# Experiment 8836/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3316)
# Experiment 8838/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3317)
# Experiment 8840/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3318)
# Experiment 8842/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3319)
# Experiment 8844/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.1x, tp, parts=3
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3320)
# Experiment 8846/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3321)
# Experiment 8848/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3322)
# Experiment 8850/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3323)
# Experiment 8852/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3324)
# Experiment 8854/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3325)
# Experiment 8856/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3326)
# Experiment 8858/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3327)
# Experiment 8860/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3328)
# Experiment 8862/9241: dj_indep_11q (11q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3329)
# Experiment 8864/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3330)
# Experiment 8866/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3331)
# Experiment 8868/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3332)
# Experiment 8870/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3333)
# Experiment 8872/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3334)
# Experiment 8874/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3335)
# Experiment 8876/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3336)
# Experiment 8878/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3337)
# Experiment 8880/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3338)
# Experiment 8882/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3339)
# Experiment 8884/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3340)
# Experiment 8886/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3341)
# Experiment 8888/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3342)
# Experiment 8890/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3343)
# Experiment 8892/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3344)
# Experiment 8894/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3345)
# Experiment 8896/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3346)
# Experiment 8898/9241: dj_indep_11q (11q), local, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3347)
# Experiment 8900/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3348)
# Experiment 8902/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3349)
# Experiment 8904/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3350)
# Experiment 8906/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3351)
# Experiment 8908/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3352)
# Experiment 8910/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3353)
# Experiment 8912/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3354)
# Experiment 8914/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3355)
# Experiment 8916/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3356)
# Experiment 8918/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3357)
# Experiment 8920/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3358)
# Experiment 8922/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3359)
# Experiment 8924/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3360)
# Experiment 8926/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3361)
# Experiment 8928/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3362)
# Experiment 8930/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3363)
# Experiment 8932/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3364)
# Experiment 8934/9241: dj_indep_11q (11q), local, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3365)
# Experiment 8936/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3366)
# Experiment 8938/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3367)
# Experiment 8940/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3368)
# Experiment 8942/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3369)
# Experiment 8944/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3370)
# Experiment 8946/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3371)
# Experiment 8948/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3372)
# Experiment 8950/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3373)
# Experiment 8952/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3374)
# Experiment 8954/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3375)
# Experiment 8956/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3376)
# Experiment 8958/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3377)
# Experiment 8960/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3378)
# Experiment 8962/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3379)
# Experiment 8964/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3380)
# Experiment 8966/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3381)
# Experiment 8968/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3382)
# Experiment 8970/9241: dj_indep_11q (11q), local, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3383)
# Experiment 8972/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3384)
# Experiment 8974/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3385)
# Experiment 8976/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3386)
# Experiment 8978/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3387)
# Experiment 8980/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3388)
# Experiment 8982/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3389)
# Experiment 8984/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3390)
# Experiment 8986/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3391)
# Experiment 8988/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3392)
# Experiment 8990/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3393)
# Experiment 8992/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3394)
# Experiment 8994/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3395)
# Experiment 8996/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3396)
# Experiment 8998/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3397)
# Experiment 9000/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3398)
# Experiment 9002/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3399)
# Experiment 9004/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3400)
# Experiment 9006/9241: dj_indep_14q (14q), local, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3401)
# Experiment 9008/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3402)
# Experiment 9010/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3403)
# Experiment 9012/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3404)
# Experiment 9014/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3405)
# Experiment 9016/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3406)
# Experiment 9018/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3407)
# Experiment 9020/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3408)
# Experiment 9022/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3409)
# Experiment 9024/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3410)
# Experiment 9026/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3411)
# Experiment 9028/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3412)
# Experiment 9030/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3413)
# Experiment 9032/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3414)
# Experiment 9034/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3415)
# Experiment 9036/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3416)
# Experiment 9038/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3417)
# Experiment 9040/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3418)
# Experiment 9042/9241: dj_indep_14q (14q), local, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3419)
# Experiment 9044/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3420)
# Experiment 9046/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3421)
# Experiment 9048/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3422)
# Experiment 9050/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3423)
# Experiment 9052/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3424)
# Experiment 9054/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 3425)
# Experiment 9056/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3426)
# Experiment 9058/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 3427)
# Experiment 9060/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3428)
# Experiment 9062/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 3429)
# Experiment 9064/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3430)
# Experiment 9066/9241: dj_indep_14q (14q), local, noise=0.01, comm=1.1x, tp, parts=6

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under15',
    min_qubits=10,
    max_qubits=15,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)

# %%
# test_df = run_mqt_bench_experiments_incremental(
#     mqt_folder='MQT_under10',
#     min_qubits=2,
#     max_qubits=10,
#     max_circuits_per_origin=10,
#     strategies=['global'],
#     noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
#     comm_noise_multipliers=[1.0,1.1,1.2],
#     comm_primitives=['tp'],
#     partition_counts=[1, 2, 3, 4, 5, 6],
#     shots=200,
#     output_file='results.csv',
#     progress_file='test_progress.json'
# ) #unfinished
