# %%
from mqt import run_mqt_bench_experiments_incremental
#22 - 5030

# %% [markdown]
# graph_state - next to test

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=10,
    max_qubits=21,
    max_circuits_per_origin=10,
    strategies=['no'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 30 QASM files
#   Loading: ghz_indep_qiskit_15.qasm -> ghz_indep (15 qubits)
#     LOADED: ghz_indep_15q, depth=15
#   Loading: ghz_indep_qiskit_19.qasm -> ghz_indep (19 qubits)
#     LOADED: ghz_indep_19q, depth=19
#   Loading: ghz_indep_qiskit_18.qasm -> ghz_indep (18 qubits)
#     LOADED: ghz_indep_18q, depth=18
#   Loading: wstate_indep_qiskit_11.qasm -> wstate_indep (11 qubits)
#     LOADED: wstate_indep_11q, depth=22
#   Loading: dj_indep_qiskit_11.qasm -> dj_indep (11 qubits)
#     LOADED: dj_indep_11q, depth=12
#   Loading: ghz_indep_qiskit_14.qasm -> ghz_indep (14 qubits)
#     LOADED: ghz_indep_14q, depth=14
#   Loading: dj_indep_qiskit_16.qasm -> dj_indep (16 qubits)
#     LOADED: dj_indep_16q, depth=17
#   Loading: wstate_indep_qiskit_16.qasm -> wstate_indep (16 qubits)
#     LOADED: wstate_indep_16q, depth=32
#   Loading: wstate_indep_qiskit_20.qasm -> wstate_indep (20 qubits)
#     LOADED: wstate_indep_20q, depth=40
#   Loading: dj_indep_qiskit_20.qasm -> dj_indep (20 qubits)
#     LOADED: dj_indep_20q, depth=21
#   Loading: ghz_indep_qiskit_13.qasm -> ghz_indep (13 qubits)
#     LOADED: ghz_indep_13q, depth=13
#   Loading: ghz_indep_qiskit_12.qasm -> ghz_indep (12 qubits)
#     LOADED: ghz_indep_12q, depth=12
#   Loading: wstate_indep_qiskit_17.qasm -> wstate_indep (17 qubits)
#     LOADED: wstate_indep_17q, depth=34
#   Loading: dj_indep_qiskit_17.qasm -> dj_indep (17 qubits)
#     LOADED: dj_indep_17q, depth=18
#   Loading: wstate_indep_qiskit_14.qasm -> wstate_indep (14 qubits)
#     LOADED: wstate_indep_14q, depth=28
#   Loading: dj_indep_qiskit_14.qasm -> dj_indep (14 qubits)
#     LOADED: dj_indep_14q, depth=15
#   Loading: ghz_indep_qiskit_11.qasm -> ghz_indep (11 qubits)
#     LOADED: ghz_indep_11q, depth=11
#   Loading: wstate_indep_qiskit_18.qasm -> wstate_indep (18 qubits)
#     LOADED: wstate_indep_18q, depth=36
#   Loading: dj_indep_qiskit_18.qasm -> dj_indep (18 qubits)
#     LOADED: dj_indep_18q, depth=19
#   Loading: dj_indep_qiskit_19.qasm -> dj_indep (19 qubits)
#     LOADED: dj_indep_19q, depth=20
#   Loading: wstate_indep_qiskit_19.qasm -> wstate_indep (19 qubits)
#     LOADED: wstate_indep_19q, depth=38
#   Loading: dj_indep_qiskit_15.qasm -> dj_indep (15 qubits)
#     LOADED: dj_indep_15q, depth=16
#   Loading: wstate_indep_qiskit_15.qasm -> wstate_indep (15 qubits)
#     LOADED: wstate_indep_15q, depth=30
#   Loading: ghz_indep_qiskit_17.qasm -> ghz_indep (17 qubits)
#     LOADED: ghz_indep_17q, depth=17
#   Loading: wstate_indep_qiskit_12.qasm -> wstate_indep (12 qubits)
#     LOADED: wstate_indep_12q, depth=24
#   Loading: dj_indep_qiskit_12.qasm -> dj_indep (12 qubits)
#     LOADED: dj_indep_12q, depth=13
#   Loading: dj_indep_qiskit_13.qasm -> dj_indep (13 qubits)
#     LOADED: dj_indep_13q, depth=14
#   Loading: ghz_indep_qiskit_20.qasm -> ghz_indep (20 qubits)
#     LOADED: ghz_indep_20q, depth=20
#   Loading: wstate_indep_qiskit_13.qasm -> wstate_indep (13 qubits)
#     LOADED: wstate_indep_13q, depth=26
#   Loading: ghz_indep_qiskit_16.qasm -> ghz_indep (16 qubits)
#     LOADED: ghz_indep_16q, depth=16
#
# Total circuits loaded: 30
#   Origins: ['ghz_indep', 'wstate_indep', 'dj_indep']
#   Qubit range: 11 - 20
#
# Loaded progress: 3960 experiments already completed
# Loaded existing results: 9377 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 6435
# Already completed: 3960
# Remaining: 2475
# Skipped (exceeds 31 qubit limit): 225
#
# (Too many to list - 225 experiments skipped)
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 3961/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9378)
# Experiment 3963/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9379)
# Experiment 3965/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9380)
# Experiment 3967/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9381)
# Experiment 3969/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9382)
# Experiment 3971/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9383)
# Experiment 3973/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9384)
# Experiment 3975/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9385)
# Experiment 3977/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9386)
# Experiment 3979/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9387)
# Experiment 3981/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9388)
# Experiment 3983/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9389)
# Experiment 3985/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9390)
# Experiment 3987/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9391)
# Experiment 3989/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9392)
# Experiment 3991/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9393)
# Experiment 3993/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9394)
# Experiment 3995/6435: ghz_indep_15q (15q), no, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9395)
# Experiment 3997/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9396)
# Experiment 3999/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9397)
# Experiment 4001/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9398)
# Experiment 4003/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9399)
# Experiment 4005/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9400)
# Experiment 4007/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9401)
# Experiment 4009/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9402)
# Experiment 4011/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9403)
# Experiment 4013/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9404)
# Experiment 4015/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9405)
# Experiment 4017/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9406)
# Experiment 4019/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9407)
# Experiment 4021/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9408)
# Experiment 4023/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9409)
# Experiment 4025/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9410)
# Experiment 4027/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9411)
# Experiment 4029/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9412)
# Experiment 4031/6435: ghz_indep_15q (15q), no, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9413)
# Experiment 4033/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9414)
# Experiment 4035/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9415)
# Experiment 4037/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9416)
# Experiment 4039/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9417)
# Experiment 4041/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9418)
# Experiment 4043/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9419)
# Experiment 4045/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9420)
# Experiment 4047/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9421)
# Experiment 4049/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9422)
# Experiment 4051/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9423)
# Experiment 4053/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9424)
# Experiment 4055/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9425)
# Experiment 4057/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9426)
# Experiment 4059/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9427)
# Experiment 4061/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.2x, tp, parts=3
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9428)
# Experiment 4063/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9429)
# Experiment 4065/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9430)
# Experiment 4067/6435: ghz_indep_15q (15q), no, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9431)
# Experiment 4069/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9432)
# Experiment 4071/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9433)
# Experiment 4073/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9434)
# Experiment 4075/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9435)
# Experiment 4077/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9436)
# Experiment 4079/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9437)
# Experiment 4081/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9438)
# Experiment 4083/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9439)
# Experiment 4085/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9440)
# Experiment 4087/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9441)
# Experiment 4089/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9442)
# Experiment 4091/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9443)
# Experiment 4093/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9444)
# Experiment 4095/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9445)
# Experiment 4097/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9446)
# Experiment 4099/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9447)
# Experiment 4101/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9448)
# Experiment 4103/6435: ghz_indep_15q (15q), no, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9449)
# Experiment 4105/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9450)
# Experiment 4107/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9451)
# Experiment 4109/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9452)
# Experiment 4111/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9453)
# Experiment 4113/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9454)
# Experiment 4115/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9455)
# Experiment 4117/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9456)
# Experiment 4119/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9457)
# Experiment 4121/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9458)
# Experiment 4123/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9459)
# Experiment 4125/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9460)
# Experiment 4127/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9461)
# Experiment 4129/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9462)
# Experiment 4131/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9463)
# Experiment 4133/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9464)
# Experiment 4135/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9465)
# Experiment 4137/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9466)
# Experiment 4139/6435: ghz_indep_15q (15q), no, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9467)
# Experiment 4141/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9468)
# Experiment 4143/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9469)
# Experiment 4145/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9470)
# Experiment 4147/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9471)
# Experiment 4149/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.0x, tp, parts=5
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9472)
# Experiment 4151/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9473)
# Experiment 4153/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9474)
# Experiment 4155/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9475)
# Experiment 4157/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9476)
# Experiment 4159/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9477)
# Experiment 4161/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9478)
# Experiment 4163/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9479)
# Experiment 4165/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9480)
# Experiment 4167/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9481)
# Experiment 4169/6435: ghz_indep_19q (19q), no, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9482)
# Experiment 4171/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9483)
# Experiment 4173/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9484)
# Experiment 4175/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9485)
# Experiment 4177/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9486)
# Experiment 4179/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9487)
# Experiment 4181/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9488)
# Experiment 4183/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.1x, tp, parts=2
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9489)
# Experiment 4185/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9490)
# Experiment 4187/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9491)
# Experiment 4189/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9492)
# Experiment 4191/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9493)
# Experiment 4193/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9494)
# Experiment 4195/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9495)
# Experiment 4197/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9496)
# Experiment 4199/6435: ghz_indep_19q (19q), no, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9497)
# Experiment 4201/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9498)
# Experiment 4203/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9499)
# Experiment 4205/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9500)
# Experiment 4207/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9501)
# Experiment 4209/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9502)
# Experiment 4211/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9503)
# Experiment 4213/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9504)
# Experiment 4215/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9505)
# Experiment 4217/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9506)
# Experiment 4219/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9507)
# Experiment 4221/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9508)
# Experiment 4223/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9509)
# Experiment 4225/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9510)
# Experiment 4227/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9511)
# Experiment 4229/6435: ghz_indep_19q (19q), no, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9512)
# Experiment 4231/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9513)
# Experiment 4233/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9514)
# Experiment 4235/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9515)
# Experiment 4237/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9516)
# Experiment 4239/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9517)
# Experiment 4241/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9518)
# Experiment 4243/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9519)
# Experiment 4245/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9520)
# Experiment 4247/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9521)
# Experiment 4249/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9522)
# Experiment 4251/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9523)
# Experiment 4253/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9524)
# Experiment 4255/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9525)
# Experiment 4257/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9526)
# Experiment 4259/6435: ghz_indep_19q (19q), no, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9527)
# Experiment 4261/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9528)
# Experiment 4263/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9529)
# Experiment 4265/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9530)
# Experiment 4267/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9531)
# Experiment 4269/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9532)
# Experiment 4271/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9533)
# Experiment 4273/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9534)
# Experiment 4275/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9535)
# Experiment 4277/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9536)
# Experiment 4279/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9537)
# Experiment 4281/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9538)
# Experiment 4283/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9539)
# Experiment 4285/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9540)
# Experiment 4287/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9541)
# Experiment 4289/6435: ghz_indep_19q (19q), no, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9542)
# Experiment 4291/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9543)
# Experiment 4293/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9544)
# Experiment 4295/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9545)
# Experiment 4297/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9546)
# Experiment 4299/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9547)
# Experiment 4301/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9548)
# Experiment 4303/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9549)
# Experiment 4305/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9550)
# Experiment 4307/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9551)
# Experiment 4309/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9552)
# Experiment 4311/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9553)
# Experiment 4313/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9554)
# Experiment 4315/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9555)
# Experiment 4317/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9556)
# Experiment 4319/6435: ghz_indep_18q (18q), no, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9557)
# Experiment 4321/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9558)
# Experiment 4323/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9559)
# Experiment 4325/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9560)
# Experiment 4327/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9561)
# Experiment 4329/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9562)
# Experiment 4331/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9563)
# Experiment 4333/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9564)
# Experiment 4335/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9565)
# Experiment 4337/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9566)
# Experiment 4339/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9567)
# Experiment 4341/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9568)
# Experiment 4343/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9569)
# Experiment 4345/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9570)
# Experiment 4347/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9571)
# Experiment 4349/6435: ghz_indep_18q (18q), no, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9572)
# Experiment 4351/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9573)
# Experiment 4353/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9574)
# Experiment 4355/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9575)
# Experiment 4357/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9576)
# Experiment 4359/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9577)
# Experiment 4361/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9578)
# Experiment 4363/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9579)
# Experiment 4365/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9580)
# Experiment 4367/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9581)
# Experiment 4369/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9582)
# Experiment 4371/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9583)
# Experiment 4373/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9584)
# Experiment 4375/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9585)
# Experiment 4377/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9586)
# Experiment 4379/6435: ghz_indep_18q (18q), no, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9587)
# Experiment 4381/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9588)
# Experiment 4383/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9589)
# Experiment 4385/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9590)
# Experiment 4387/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9591)
# Experiment 4389/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9592)
# Experiment 4391/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9593)
# Experiment 4393/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9594)
# Experiment 4395/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9595)
# Experiment 4397/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9596)
# Experiment 4399/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9597)
# Experiment 4401/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9598)
# Experiment 4403/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9599)
# Experiment 4405/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9600)
# Experiment 4407/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9601)
# Experiment 4409/6435: ghz_indep_18q (18q), no, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9602)
# Experiment 4411/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9603)
# Experiment 4413/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9604)
# Experiment 4415/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9605)
# Experiment 4417/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9606)
# Experiment 4419/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9607)
# Experiment 4421/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9608)
# Experiment 4423/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9609)
# Experiment 4425/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9610)
# Experiment 4427/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9611)
# Experiment 4429/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9612)
# Experiment 4431/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9613)
# Experiment 4433/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9614)
# Experiment 4435/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9615)
# Experiment 4437/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9616)
# Experiment 4439/6435: ghz_indep_18q (18q), no, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9617)
# Experiment 4441/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9618)
# Experiment 4443/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9619)
# Experiment 4445/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9620)
# Experiment 4447/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9621)
# Experiment 4449/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9622)
# Experiment 4451/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9623)
# Experiment 4453/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9624)
# Experiment 4455/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9625)
# Experiment 4457/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9626)
# Experiment 4459/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9627)
# Experiment 4461/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9628)
# Experiment 4463/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9629)
# Experiment 4465/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9630)
# Experiment 4467/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9631)
# Experiment 4469/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9632)
# Experiment 4471/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9633)
# Experiment 4473/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9634)
# Experiment 4475/6435: ghz_indep_14q (14q), no, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9635)
# Experiment 4477/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9636)
# Experiment 4479/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9637)
# Experiment 4481/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9638)
# Experiment 4483/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9639)
# Experiment 4485/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9640)
# Experiment 4487/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9641)
# Experiment 4489/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9642)
# Experiment 4491/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9643)
# Experiment 4493/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9644)
# Experiment 4495/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9645)
# Experiment 4497/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9646)
# Experiment 4499/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9647)
# Experiment 4501/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9648)
# Experiment 4503/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9649)
# Experiment 4505/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9650)
# Experiment 4507/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9651)
# Experiment 4509/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9652)
# Experiment 4511/6435: ghz_indep_14q (14q), no, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9653)
# Experiment 4513/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9654)
# Experiment 4515/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9655)
# Experiment 4517/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9656)
# Experiment 4519/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9657)
# Experiment 4521/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9658)
# Experiment 4523/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9659)
# Experiment 4525/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 9660)
# Experiment 4527/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9661)
# Experiment 4529/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9662)
# Experiment 4531/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9663)
# Experiment 4533/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9664)
# Experiment 4535/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9665)
# Experiment 4537/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9666)
# Experiment 4539/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9667)
# Experiment 4541/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9668)
# Experiment 4543/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9669)
# Experiment 4545/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9670)
# Experiment 4547/6435: ghz_indep_14q (14q), no, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9671)
# Experiment 4549/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9672)
# Experiment 4551/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9673)
# Experiment 4553/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9674)
# Experiment 4555/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9675)
# Experiment 4557/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9676)
# Experiment 4559/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9677)
# Experiment 4561/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9678)
# Experiment 4563/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9679)
# Experiment 4565/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9680)
# Experiment 4567/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9681)
# Experiment 4569/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 9682)
# Experiment 4571/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 9683)
# Experiment 4573/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 9684)
# Experiment 4575/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 9685)
# Experiment 4577/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 9686)
# Experiment 4579/6435: ghz_indep_14q (14q), no, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 9687)
# ...
#   SUCCESS - Saved (Total rows: 10198)
# Experiment 5603/6435: ghz_indep_16q (16q), no, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10199)
# Experiment 5605/6435: ghz_indep_16q (16q), no, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10200)
# Experiment 5607/6435: ghz_indep_16q (16q), no, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10201)
# Experiment 5609/6435: ghz_indep_16q (16q), no, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10202)
# Experiment 5611/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10203)
# Experiment 5613/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10204)
# Experiment 5615/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10205)
# Experiment 5617/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10206)
# Experiment 5619/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10207)
# Experiment 5621/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10208)
# Experiment 5623/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10209)
# Experiment 5625/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10210)
# Experiment 5627/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10211)
# Experiment 5629/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10212)
# Experiment 5631/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10213)
# Experiment 5633/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10214)
# Experiment 5635/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10215)
# Experiment 5637/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10216)
# Experiment 5639/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10217)
# Experiment 5641/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10218)
# Experiment 5643/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10219)
# Experiment 5645/6435: wstate_indep_11q (11q), no, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10220)
# Experiment 5647/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10221)
# Experiment 5649/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10222)
# Experiment 5651/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10223)
# Experiment 5653/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10224)
# Experiment 5655/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10225)
# Experiment 5657/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10226)
# Experiment 5659/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10227)
# Experiment 5661/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10228)
# Experiment 5663/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10229)
# Experiment 5665/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10230)
# Experiment 5667/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10231)
# Experiment 5669/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10232)
# Experiment 5671/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10233)
# Experiment 5673/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10234)
# Experiment 5675/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10235)
# Experiment 5677/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10236)
# Experiment 5679/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10237)
# Experiment 5681/6435: wstate_indep_11q (11q), no, noise=0.005, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10238)
# Experiment 5683/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10239)
# Experiment 5685/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10240)
# Experiment 5687/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10241)
# Experiment 5689/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10242)
# Experiment 5691/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10243)
# Experiment 5693/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10244)
# Experiment 5695/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10245)
# Experiment 5697/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10246)
# Experiment 5699/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10247)
# Experiment 5701/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10248)
# Experiment 5703/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10249)
# Experiment 5705/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10250)
# Experiment 5707/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10251)
# Experiment 5709/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10252)
# Experiment 5711/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10253)
# Experiment 5713/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10254)
# Experiment 5715/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10255)
# Experiment 5717/6435: wstate_indep_11q (11q), no, noise=0.01, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10256)
# Experiment 5719/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10257)
# Experiment 5721/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10258)
# Experiment 5723/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10259)
# Experiment 5725/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10260)
# Experiment 5727/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10261)
# Experiment 5729/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10262)
# Experiment 5731/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10263)
# Experiment 5733/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10264)
# Experiment 5735/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10265)
# Experiment 5737/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10266)
# Experiment 5739/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10267)
# Experiment 5741/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10268)
# Experiment 5743/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10269)
# Experiment 5745/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10270)
# Experiment 5747/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10271)
# Experiment 5749/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10272)
# Experiment 5751/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10273)
# Experiment 5753/6435: wstate_indep_11q (11q), no, noise=0.015, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10274)
# Experiment 5755/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10275)
# Experiment 5757/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10276)
# Experiment 5759/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10277)
# Experiment 5761/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10278)
# Experiment 5763/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10279)
# Experiment 5765/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10280)
# Experiment 5767/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10281)
# Experiment 5769/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10282)
# Experiment 5771/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10283)
# Experiment 5773/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10284)
# Experiment 5775/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10285)
# Experiment 5777/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10286)
# Experiment 5779/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10287)
# Experiment 5781/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10288)
# Experiment 5783/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10289)
# Experiment 5785/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10290)
# Experiment 5787/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10291)
# Experiment 5789/6435: wstate_indep_11q (11q), no, noise=0.02, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10292)
# Experiment 5791/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10293)
# Experiment 5793/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10294)
# Experiment 5795/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10295)
# Experiment 5797/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10296)
# Experiment 5799/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10297)
# Experiment 5801/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10298)
# Experiment 5803/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10299)
# Experiment 5805/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10300)
# Experiment 5807/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10301)
# Experiment 5809/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10302)
# Experiment 5811/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10303)
# Experiment 5813/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10304)
# Experiment 5815/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10305)
# Experiment 5817/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10306)
# Experiment 5819/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10307)
# Experiment 5821/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10308)
# Experiment 5823/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10309)
# Experiment 5825/6435: wstate_indep_16q (16q), no, noise=0.001, comm=1.2x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10310)
# Experiment 5827/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10311)
# Experiment 5829/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10312)
# Experiment 5831/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10313)
# Experiment 5833/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.0x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10314)
# Experiment 5835/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10315)
# Experiment 5837/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.0x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10316)
# Experiment 5839/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10317)
# Experiment 5841/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.1x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10318)
# Experiment 5843/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10319)
# Experiment 5845/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.1x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10320)
# Experiment 5847/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 10321)
# Experiment 5849/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.1x, tp, parts=6
#   SUCCESS - Saved (Total rows: 10322)
# Experiment 5851/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 10323)
# Experiment 5853/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.2x, tp, parts=2
#   SUCCESS - Saved (Total rows: 10324)
# Experiment 5855/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 10325)
# Experiment 5857/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.2x, tp, parts=4
#   SUCCESS - Saved (Total rows: 10326)
# Experiment 5859/6435: wstate_indep_16q (16q), no, noise=0.005, comm=1.2x, tp, parts=5

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=10,
    max_qubits=21,
    max_circuits_per_origin=10,
    strategies=['no'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=10,
    max_qubits=21,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=10,
    max_qubits=21,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=10,
    max_qubits=21,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=10,
    max_qubits=21,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
