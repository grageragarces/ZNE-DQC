# %%
from mqt import run_mqt_bench_experiments_incremental

# %% [markdown]
# graph_state - next to test

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 3, 5],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 27 QASM files
#   Loading: ghz_indep_qiskit_9.qasm -> ghz_indep (9 qubits)
#     LOADED: ghz_indep_9q, depth=9
#   Loading: wstate_indep_qiskit_7.qasm -> wstate_indep (7 qubits)
#     LOADED: wstate_indep_7q, depth=14
#   Loading: ghz_indep_qiskit_5.qasm -> ghz_indep (5 qubits)
#     LOADED: ghz_indep_5q, depth=5
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: wstate_indep_qiskit_10.qasm -> wstate_indep (10 qubits)
#     LOADED: wstate_indep_10q, depth=20
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: ghz_indep_qiskit_4.qasm -> ghz_indep (4 qubits)
#     LOADED: ghz_indep_4q, depth=4
#   Loading: wstate_indep_qiskit_6.qasm -> wstate_indep (6 qubits)
#     LOADED: wstate_indep_6q, depth=12
#   Loading: ghz_indep_qiskit_8.qasm -> ghz_indep (8 qubits)
#     LOADED: ghz_indep_8q, depth=8
#   Loading: ghz_indep_qiskit_3.qasm -> ghz_indep (3 qubits)
#     LOADED: ghz_indep_3q, depth=3
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: ghz_indep_qiskit_2.qasm -> ghz_indep (2 qubits)
#     LOADED: ghz_indep_2q, depth=2
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: wstate_indep_qiskit_3.qasm -> wstate_indep (3 qubits)
#     LOADED: wstate_indep_3q, depth=6
#   Loading: ghz_indep_qiskit_10.qasm -> ghz_indep (10 qubits)
#     LOADED: ghz_indep_10q, depth=10
#   Loading: wstate_indep_qiskit_2.qasm -> wstate_indep (2 qubits)
#     LOADED: wstate_indep_2q, depth=4
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#   Loading: wstate_indep_qiskit_9.qasm -> wstate_indep (9 qubits)
#     LOADED: wstate_indep_9q, depth=18
#   Loading: ghz_indep_qiskit_7.qasm -> ghz_indep (7 qubits)
#     LOADED: ghz_indep_7q, depth=7
#   Loading: wstate_indep_qiskit_5.qasm -> wstate_indep (5 qubits)
#     LOADED: wstate_indep_5q, depth=10
#   Loading: wstate_indep_qiskit_4.qasm -> wstate_indep (4 qubits)
#     LOADED: wstate_indep_4q, depth=8
#   Loading: ghz_indep_qiskit_6.qasm -> ghz_indep (6 qubits)
#     LOADED: ghz_indep_6q, depth=6
#   Loading: wstate_indep_qiskit_8.qasm -> wstate_indep (8 qubits)
#     LOADED: wstate_indep_8q, depth=16
#
# Total circuits loaded: 27
#   Origins: ['ghz_indep', 'wstate_indep', 'dj_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 1890 experiments already completed
# Loaded existing results: 3345 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 2925
# Already completed: 1890
# Remaining: 1035
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 1891/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3346)
# Experiment 1893/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3347)
# Experiment 1895/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3348)
# Experiment 1897/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3349)
# Experiment 1899/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3350)
# Experiment 1901/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3351)
# Experiment 1903/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3352)
# Experiment 1905/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3353)
# Experiment 1907/2925: ghz_indep_9q (9q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3354)
# Experiment 1909/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3355)
# Experiment 1911/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3356)
# Experiment 1913/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3357)
# Experiment 1915/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3358)
# Experiment 1917/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3359)
# Experiment 1919/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3360)
# Experiment 1921/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3361)
# Experiment 1923/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3362)
# Experiment 1925/2925: ghz_indep_9q (9q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3363)
# Experiment 1927/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3364)
# Experiment 1929/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3365)
# Experiment 1931/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3366)
# Experiment 1933/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3367)
# Experiment 1935/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3368)
# Experiment 1937/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3369)
# Experiment 1939/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3370)
# Experiment 1941/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3371)
# Experiment 1943/2925: ghz_indep_9q (9q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3372)
# Experiment 1945/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3373)
# Experiment 1947/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3374)
# Experiment 1949/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3375)
# Experiment 1951/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3376)
# Experiment 1953/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3377)
# Experiment 1955/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3378)
# Experiment 1957/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3379)
# Experiment 1959/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3380)
# Experiment 1961/2925: ghz_indep_9q (9q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3381)
# Experiment 1963/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3382)
# Experiment 1965/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3383)
# Experiment 1967/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3384)
# Experiment 1969/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3385)
# Experiment 1971/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3386)
# Experiment 1973/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3387)
# Experiment 1975/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3388)
# Experiment 1977/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3389)
# Experiment 1979/2925: ghz_indep_9q (9q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3390)
# Experiment 1981/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3391)
# Experiment 1983/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3392)
# Experiment 1985/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3393)
# Experiment 1987/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3394)
# Experiment 1989/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3395)
# Experiment 1991/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3396)
# Experiment 1993/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3397)
# Experiment 1995/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3398)
# Experiment 1997/2925: ghz_indep_5q (5q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3399)
# Experiment 1999/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3400)
# Experiment 2001/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3401)
# Experiment 2003/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3402)
# Experiment 2005/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3403)
# Experiment 2007/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3404)
# Experiment 2009/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3405)
# Experiment 2011/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3406)
# Experiment 2013/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3407)
# Experiment 2015/2925: ghz_indep_5q (5q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3408)
# Experiment 2017/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3409)
# Experiment 2019/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3410)
# Experiment 2021/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3411)
# Experiment 2023/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3412)
# Experiment 2025/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3413)
# Experiment 2027/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3414)
# Experiment 2029/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3415)
# Experiment 2031/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3416)
# Experiment 2033/2925: ghz_indep_5q (5q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3417)
# Experiment 2035/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3418)
# Experiment 2037/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3419)
# Experiment 2039/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3420)
# Experiment 2041/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3421)
# Experiment 2043/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3422)
# Experiment 2045/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3423)
# Experiment 2047/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3424)
# Experiment 2049/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3425)
# Experiment 2051/2925: ghz_indep_5q (5q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3426)
# Experiment 2053/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3427)
# Experiment 2055/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3428)
# Experiment 2057/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3429)
# Experiment 2059/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3430)
# Experiment 2061/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3431)
# Experiment 2063/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3432)
# Experiment 2065/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3433)
# Experiment 2067/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3434)
# Experiment 2069/2925: ghz_indep_5q (5q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3435)
# Experiment 2071/2925: ghz_indep_4q (4q), local, noise=0.001, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3436)
# Experiment 2073/2925: ghz_indep_4q (4q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3437)
# Experiment 2075/2925: ghz_indep_4q (4q), local, noise=0.001, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3438)
# Experiment 2077/2925: ghz_indep_4q (4q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3439)
# Experiment 2079/2925: ghz_indep_4q (4q), local, noise=0.001, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3440)
# Experiment 2081/2925: ghz_indep_4q (4q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3441)
# Experiment 2083/2925: ghz_indep_4q (4q), local, noise=0.005, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3442)
# Experiment 2085/2925: ghz_indep_4q (4q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3443)
# Experiment 2087/2925: ghz_indep_4q (4q), local, noise=0.005, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3444)
# Experiment 2089/2925: ghz_indep_4q (4q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3445)
# Experiment 2091/2925: ghz_indep_4q (4q), local, noise=0.005, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3446)
# Experiment 2093/2925: ghz_indep_4q (4q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3447)
# Experiment 2095/2925: ghz_indep_4q (4q), local, noise=0.01, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3448)
# Experiment 2097/2925: ghz_indep_4q (4q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3449)
# Experiment 2099/2925: ghz_indep_4q (4q), local, noise=0.01, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3450)
# Experiment 2101/2925: ghz_indep_4q (4q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3451)
# Experiment 2103/2925: ghz_indep_4q (4q), local, noise=0.01, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3452)
# Experiment 2105/2925: ghz_indep_4q (4q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3453)
# Experiment 2107/2925: ghz_indep_4q (4q), local, noise=0.015, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3454)
# Experiment 2109/2925: ghz_indep_4q (4q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3455)
# Experiment 2111/2925: ghz_indep_4q (4q), local, noise=0.015, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3456)
# Experiment 2113/2925: ghz_indep_4q (4q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3457)
# Experiment 2115/2925: ghz_indep_4q (4q), local, noise=0.015, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3458)
# Experiment 2117/2925: ghz_indep_4q (4q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3459)
# Experiment 2119/2925: ghz_indep_4q (4q), local, noise=0.02, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3460)
# Experiment 2121/2925: ghz_indep_4q (4q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3461)
# Experiment 2123/2925: ghz_indep_4q (4q), local, noise=0.02, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3462)
# Experiment 2125/2925: ghz_indep_4q (4q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3463)
# Experiment 2127/2925: ghz_indep_4q (4q), local, noise=0.02, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3464)
# Experiment 2129/2925: ghz_indep_4q (4q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3465)
# Experiment 2131/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3466)
# Experiment 2133/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3467)
# Experiment 2135/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3468)
# Experiment 2137/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3469)
# Experiment 2139/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3470)
# Experiment 2141/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3471)
# Experiment 2143/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3472)
# Experiment 2145/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3473)
# Experiment 2147/2925: ghz_indep_8q (8q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3474)
# Experiment 2149/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3475)
# Experiment 2151/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3476)
# Experiment 2153/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3477)
# Experiment 2155/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3478)
# Experiment 2157/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3479)
# Experiment 2159/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3480)
# Experiment 2161/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3481)
# Experiment 2163/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3482)
# Experiment 2165/2925: ghz_indep_8q (8q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3483)
# Experiment 2167/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3484)
# Experiment 2169/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3485)
# Experiment 2171/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3486)
# Experiment 2173/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3487)
# Experiment 2175/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3488)
# Experiment 2177/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3489)
# Experiment 2179/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3490)
# Experiment 2181/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3491)
# Experiment 2183/2925: ghz_indep_8q (8q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3492)
# Experiment 2185/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3493)
# Experiment 2187/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3494)
# Experiment 2189/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3495)
# Experiment 2191/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3496)
# Experiment 2193/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3497)
# Experiment 2195/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3498)
# Experiment 2197/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3499)
# Experiment 2199/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3500)
# Experiment 2201/2925: ghz_indep_8q (8q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3501)
# Experiment 2203/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3502)
# Experiment 2205/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3503)
# Experiment 2207/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3504)
# Experiment 2209/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3505)
# Experiment 2211/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3506)
# Experiment 2213/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3507)
# Experiment 2215/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 3508)
# Experiment 2217/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3509)
# Experiment 2219/2925: ghz_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3510)
# Experiment 2221/2925: ghz_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3511)
# Experiment 2223/2925: ghz_indep_3q (3q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3512)
# Experiment 2225/2925: ghz_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3513)
# Experiment 2227/2925: ghz_indep_3q (3q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3514)
# Experiment 2229/2925: ghz_indep_3q (3q), local, noise=0.001, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3515)
# Experiment 2231/2925: ghz_indep_3q (3q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3516)
# Experiment 2233/2925: ghz_indep_3q (3q), local, noise=0.005, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3517)
# Experiment 2235/2925: ghz_indep_3q (3q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3518)
# Experiment 2237/2925: ghz_indep_3q (3q), local, noise=0.005, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3519)
# Experiment 2239/2925: ghz_indep_3q (3q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3520)
# Experiment 2241/2925: ghz_indep_3q (3q), local, noise=0.005, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3521)
# Experiment 2243/2925: ghz_indep_3q (3q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3522)
# Experiment 2245/2925: ghz_indep_3q (3q), local, noise=0.01, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3523)
# Experiment 2247/2925: ghz_indep_3q (3q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3524)
# Experiment 2249/2925: ghz_indep_3q (3q), local, noise=0.01, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3525)
# Experiment 2251/2925: ghz_indep_3q (3q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3526)
# Experiment 2253/2925: ghz_indep_3q (3q), local, noise=0.01, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3527)
# Experiment 2255/2925: ghz_indep_3q (3q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3528)
# Experiment 2257/2925: ghz_indep_3q (3q), local, noise=0.015, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3529)
# Experiment 2259/2925: ghz_indep_3q (3q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3530)
# Experiment 2261/2925: ghz_indep_3q (3q), local, noise=0.015, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3531)
# Experiment 2263/2925: ghz_indep_3q (3q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3532)
# Experiment 2265/2925: ghz_indep_3q (3q), local, noise=0.015, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3533)
# Experiment 2267/2925: ghz_indep_3q (3q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3534)
# Experiment 2269/2925: ghz_indep_3q (3q), local, noise=0.02, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3535)
# Experiment 2271/2925: ghz_indep_3q (3q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3536)
# Experiment 2273/2925: ghz_indep_3q (3q), local, noise=0.02, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3537)
# Experiment 2275/2925: ghz_indep_3q (3q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3538)
# Experiment 2277/2925: ghz_indep_3q (3q), local, noise=0.02, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3539)
# Experiment 2279/2925: ghz_indep_3q (3q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3540)
# Experiment 2281/2925: ghz_indep_2q (2q), local, noise=0.001, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3541)
# Experiment 2283/2925: ghz_indep_2q (2q), local, noise=0.001, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3542)
# Experiment 2285/2925: ghz_indep_2q (2q), local, noise=0.001, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3543)
# Experiment 2287/2925: ghz_indep_2q (2q), local, noise=0.005, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3544)
# Experiment 2289/2925: ghz_indep_2q (2q), local, noise=0.005, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3545)
# Experiment 2291/2925: ghz_indep_2q (2q), local, noise=0.005, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3546)
# Experiment 2293/2925: ghz_indep_2q (2q), local, noise=0.01, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3547)
# Experiment 2295/2925: ghz_indep_2q (2q), local, noise=0.01, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3548)
# Experiment 2297/2925: ghz_indep_2q (2q), local, noise=0.01, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3549)
# Experiment 2299/2925: ghz_indep_2q (2q), local, noise=0.015, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3550)
# Experiment 2301/2925: ghz_indep_2q (2q), local, noise=0.015, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3551)
# Experiment 2303/2925: ghz_indep_2q (2q), local, noise=0.015, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3552)
# Experiment 2305/2925: ghz_indep_2q (2q), local, noise=0.02, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3553)
# Experiment 2307/2925: ghz_indep_2q (2q), local, noise=0.02, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3554)
# Experiment 2309/2925: ghz_indep_2q (2q), local, noise=0.02, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 3555)
# Experiment 2311/2925: ghz_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 3556)
# Experiment 2313/2925: ghz_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 3557)
# Experiment 2315/2925: ghz_indep_10q (10q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 3558)
# Experiment 2317/2925: ghz_indep_10q (10q), local, noise=0.001, comm=1.1x, tp, parts=1
# ...
# Experiment 3713/2925: dj_indep_8q (8q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4257)
# Experiment 3715/2925: dj_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4258)
# Experiment 3717/2925: dj_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4259)
# Experiment 3719/2925: dj_indep_8q (8q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4260)
# Experiment 3721/2925: dj_indep_4q (4q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4261)
# Experiment 3723/2925: dj_indep_4q (4q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4262)
# Experiment 3725/2925: dj_indep_4q (4q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4263)
# Experiment 3727/2925: dj_indep_4q (4q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4264)
# Experiment 3729/2925: dj_indep_4q (4q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4265)
# Experiment 3731/2925: dj_indep_4q (4q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4266)
# Experiment 3733/2925: dj_indep_4q (4q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4267)
# Experiment 3735/2925: dj_indep_4q (4q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4268)
# Experiment 3737/2925: dj_indep_4q (4q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4269)
# Experiment 3739/2925: dj_indep_4q (4q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4270)
# Experiment 3741/2925: dj_indep_4q (4q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4271)
# Experiment 3743/2925: dj_indep_4q (4q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4272)
# Experiment 3745/2925: dj_indep_4q (4q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4273)
# Experiment 3747/2925: dj_indep_4q (4q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4274)
# Experiment 3749/2925: dj_indep_4q (4q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4275)
# Experiment 3751/2925: dj_indep_4q (4q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4276)
# Experiment 3753/2925: dj_indep_4q (4q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4277)
# Experiment 3755/2925: dj_indep_4q (4q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4278)
# Experiment 3757/2925: dj_indep_4q (4q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4279)
# Experiment 3759/2925: dj_indep_4q (4q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4280)
# Experiment 3761/2925: dj_indep_4q (4q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4281)
# Experiment 3763/2925: dj_indep_4q (4q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4282)
# Experiment 3765/2925: dj_indep_4q (4q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4283)
# Experiment 3767/2925: dj_indep_4q (4q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4284)
# Experiment 3769/2925: dj_indep_4q (4q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4285)
# Experiment 3771/2925: dj_indep_4q (4q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4286)
# Experiment 3773/2925: dj_indep_4q (4q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4287)
# Experiment 3775/2925: dj_indep_4q (4q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4288)
# Experiment 3777/2925: dj_indep_4q (4q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4289)
# Experiment 3779/2925: dj_indep_4q (4q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4290)
# Experiment 3781/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4291)
# Experiment 3783/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4292)
# Experiment 3785/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4293)
# Experiment 3787/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4294)
# Experiment 3789/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4295)
# Experiment 3791/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4296)
# Experiment 3793/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4297)
# Experiment 3795/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4298)
# Experiment 3797/2925: dj_indep_7q (7q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4299)
# Experiment 3799/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4300)
# Experiment 3801/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4301)
# Experiment 3803/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4302)
# Experiment 3805/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4303)
# Experiment 3807/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4304)
# Experiment 3809/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4305)
# Experiment 3811/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4306)
# Experiment 3813/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4307)
# Experiment 3815/2925: dj_indep_7q (7q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4308)
# Experiment 3817/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4309)
# Experiment 3819/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4310)
# Experiment 3821/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4311)
# Experiment 3823/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4312)
# Experiment 3825/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4313)
# Experiment 3827/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4314)
# Experiment 3829/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4315)
# Experiment 3831/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4316)
# Experiment 3833/2925: dj_indep_7q (7q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4317)
# Experiment 3835/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4318)
# Experiment 3837/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4319)
# Experiment 3839/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4320)
# Experiment 3841/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4321)
# Experiment 3843/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4322)
# Experiment 3845/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4323)
# Experiment 3847/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4324)
# Experiment 3849/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4325)
# Experiment 3851/2925: dj_indep_7q (7q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4326)
# Experiment 3853/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4327)
# Experiment 3855/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4328)
# Experiment 3857/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4329)
# Experiment 3859/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4330)
# Experiment 3861/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4331)
# Experiment 3863/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4332)
# Experiment 3865/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4333)
# Experiment 3867/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4334)
# Experiment 3869/2925: dj_indep_7q (7q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4335)
# Experiment 3871/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4336)
# Experiment 3873/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4337)
# Experiment 3875/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4338)
# Experiment 3877/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4339)
# Experiment 3879/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4340)
# Experiment 3881/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4341)
# Experiment 3883/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4342)
# Experiment 3885/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4343)
# Experiment 3887/2925: dj_indep_6q (6q), local, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4344)
# Experiment 3889/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4345)
# Experiment 3891/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4346)
# Experiment 3893/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4347)
# Experiment 3895/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4348)
# Experiment 3897/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4349)
# Experiment 3899/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4350)
# Experiment 3901/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4351)
# Experiment 3903/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4352)
# Experiment 3905/2925: dj_indep_6q (6q), local, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4353)
# Experiment 3907/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4354)
# Experiment 3909/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4355)
# Experiment 3911/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4356)
# Experiment 3913/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4357)
# Experiment 3915/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4358)
# Experiment 3917/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4359)
# Experiment 3919/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4360)
# Experiment 3921/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4361)
# Experiment 3923/2925: dj_indep_6q (6q), local, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4362)
# Experiment 3925/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4363)
# Experiment 3927/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4364)
# Experiment 3929/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4365)
# Experiment 3931/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4366)
# Experiment 3933/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4367)
# Experiment 3935/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4368)
# Experiment 3937/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4369)
# Experiment 3939/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4370)
# Experiment 3941/2925: dj_indep_6q (6q), local, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4371)
# Experiment 3943/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4372)
# Experiment 3945/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4373)
# Experiment 3947/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4374)
# Experiment 3949/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4375)
# Experiment 3951/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4376)
# Experiment 3953/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4377)
# Experiment 3955/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4378)
# Experiment 3957/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4379)
# Experiment 3959/2925: dj_indep_6q (6q), local, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4380)
#
# ======================================================================
# 4. RESULTS SUMMARY
# ======================================================================
# Experiments completed: 4380
# Results saved to: results.csv
# Skipped (simulator limit): 0
#
# Origins tested:
#   dj_indep_10q: 178 experiments
#   dj_indep_2q: 60 experiments
#   dj_indep_3q: 90 experiments
#   dj_indep_5q: 165 experiments
#   dj_indep_9q: 225 experiments
#   dj_indep_8q: 225 experiments
#   dj_indep_4q: 150 experiments
#   dj_indep_7q: 225 experiments
#   dj_indep_6q: 225 experiments
#   ghz_indep_9q: 180 experiments
#   ghz_indep_5q: 135 experiments
#   ghz_indep_4q: 120 experiments
#   ghz_indep_8q: 180 experiments
#   ghz_indep_3q: 75 experiments
#   ghz_indep_2q: 60 experiments
#   ghz_indep_10q: 180 experiments
#   ghz_indep_7q: 180 experiments
#   ghz_indep_6q: 180 experiments
#   wstate_indep_7q: 180 experiments
#   wstate_indep_10q: 212 experiments
#   wstate_indep_6q: 225 experiments
#   wstate_indep_3q: 90 experiments
#   wstate_indep_2q: 75 experiments
#   wstate_indep_9q: 225 experiments
#   wstate_indep_5q: 165 experiments
#   wstate_indep_4q: 150 experiments
#   wstate_indep_8q: 225 experiments

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 3, 5],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10 for QASM files...
# Found 27 QASM files
#   Loading: ghz_indep_qiskit_9.qasm -> ghz_indep (9 qubits)
#     LOADED: ghz_indep_9q, depth=9
#   Loading: wstate_indep_qiskit_7.qasm -> wstate_indep (7 qubits)
#     LOADED: wstate_indep_7q, depth=14
#   Loading: ghz_indep_qiskit_5.qasm -> ghz_indep (5 qubits)
#     LOADED: ghz_indep_5q, depth=5
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_3.qasm -> dj_indep (3 qubits)
#     LOADED: dj_indep_3q, depth=4
#   Loading: wstate_indep_qiskit_10.qasm -> wstate_indep (10 qubits)
#     LOADED: wstate_indep_10q, depth=20
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: ghz_indep_qiskit_4.qasm -> ghz_indep (4 qubits)
#     LOADED: ghz_indep_4q, depth=4
#   Loading: wstate_indep_qiskit_6.qasm -> wstate_indep (6 qubits)
#     LOADED: wstate_indep_6q, depth=12
#   Loading: ghz_indep_qiskit_8.qasm -> ghz_indep (8 qubits)
#     LOADED: ghz_indep_8q, depth=8
#   Loading: ghz_indep_qiskit_3.qasm -> ghz_indep (3 qubits)
#     LOADED: ghz_indep_3q, depth=3
#   Loading: dj_indep_qiskit_5.qasm -> dj_indep (5 qubits)
#     LOADED: dj_indep_5q, depth=6
#   Loading: dj_indep_qiskit_9.qasm -> dj_indep (9 qubits)
#     LOADED: dj_indep_9q, depth=10
#   Loading: dj_indep_qiskit_8.qasm -> dj_indep (8 qubits)
#     LOADED: dj_indep_8q, depth=9
#   Loading: dj_indep_qiskit_4.qasm -> dj_indep (4 qubits)
#     LOADED: dj_indep_4q, depth=5
#   Loading: ghz_indep_qiskit_2.qasm -> ghz_indep (2 qubits)
#     LOADED: ghz_indep_2q, depth=2
#   Loading: dj_indep_qiskit_7.qasm -> dj_indep (7 qubits)
#     LOADED: dj_indep_7q, depth=8
#   Loading: wstate_indep_qiskit_3.qasm -> wstate_indep (3 qubits)
#     LOADED: wstate_indep_3q, depth=6
#   Loading: ghz_indep_qiskit_10.qasm -> ghz_indep (10 qubits)
#     LOADED: ghz_indep_10q, depth=10
#   Loading: wstate_indep_qiskit_2.qasm -> wstate_indep (2 qubits)
#     LOADED: wstate_indep_2q, depth=4
#   Loading: dj_indep_qiskit_6.qasm -> dj_indep (6 qubits)
#     LOADED: dj_indep_6q, depth=7
#   Loading: wstate_indep_qiskit_9.qasm -> wstate_indep (9 qubits)
#     LOADED: wstate_indep_9q, depth=18
#   Loading: ghz_indep_qiskit_7.qasm -> ghz_indep (7 qubits)
#     LOADED: ghz_indep_7q, depth=7
#   Loading: wstate_indep_qiskit_5.qasm -> wstate_indep (5 qubits)
#     LOADED: wstate_indep_5q, depth=10
#   Loading: wstate_indep_qiskit_4.qasm -> wstate_indep (4 qubits)
#     LOADED: wstate_indep_4q, depth=8
#   Loading: ghz_indep_qiskit_6.qasm -> ghz_indep (6 qubits)
#     LOADED: ghz_indep_6q, depth=6
#   Loading: wstate_indep_qiskit_8.qasm -> wstate_indep (8 qubits)
#     LOADED: wstate_indep_8q, depth=16
#
# Total circuits loaded: 27
#   Origins: ['ghz_indep', 'wstate_indep', 'dj_indep']
#   Qubit range: 2 - 10
#
# Loaded progress: 2925 experiments already completed
# Loaded existing results: 4380 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 3960
# Already completed: 2925
# Remaining: 1035
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 2926/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4381)
# Experiment 2928/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4382)
# Experiment 2930/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4383)
# Experiment 2932/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4384)
# Experiment 2934/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4385)
# Experiment 2936/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4386)
# Experiment 2938/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4387)
# Experiment 2940/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4388)
# Experiment 2942/3960: ghz_indep_9q (9q), global, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4389)
# Experiment 2944/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4390)
# Experiment 2946/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4391)
# Experiment 2948/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4392)
# Experiment 2950/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4393)
# Experiment 2952/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4394)
# Experiment 2954/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4395)
# Experiment 2956/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4396)
# Experiment 2958/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4397)
# Experiment 2960/3960: ghz_indep_9q (9q), global, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4398)
# Experiment 2962/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4399)
# Experiment 2964/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4400)
# Experiment 2966/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4401)
# Experiment 2968/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4402)
# Experiment 2970/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4403)
# Experiment 2972/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4404)
# Experiment 2974/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4405)
# Experiment 2976/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4406)
# Experiment 2978/3960: ghz_indep_9q (9q), global, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4407)
# Experiment 2980/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4408)
# Experiment 2982/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4409)
# Experiment 2984/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4410)
# Experiment 2986/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4411)
# Experiment 2988/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4412)
# Experiment 2990/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4413)
# Experiment 2992/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4414)
# Experiment 2994/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4415)
# Experiment 2996/3960: ghz_indep_9q (9q), global, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4416)
# Experiment 2998/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4417)
# Experiment 3000/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4418)
# Experiment 3002/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4419)
# Experiment 3004/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4420)
# Experiment 3006/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4421)
# Experiment 3008/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4422)
# Experiment 3010/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4423)
# Experiment 3012/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4424)
# Experiment 3014/3960: ghz_indep_9q (9q), global, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4425)
# Experiment 3016/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4426)
# Experiment 3018/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4427)
# Experiment 3020/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4428)
# Experiment 3022/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4429)
# Experiment 3024/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4430)
# Experiment 3026/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4431)
# Experiment 3028/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4432)
# Experiment 3030/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4433)
# Experiment 3032/3960: ghz_indep_5q (5q), global, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4434)
# Experiment 3034/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4435)
# Experiment 3036/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4436)
# Experiment 3038/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4437)
# Experiment 3040/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4438)
# Experiment 3042/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4439)
# Experiment 3044/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4440)
# Experiment 3046/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4441)
# Experiment 3048/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4442)
# Experiment 3050/3960: ghz_indep_5q (5q), global, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4443)
# Experiment 3052/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4444)
# Experiment 3054/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4445)
# Experiment 3056/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4446)
# Experiment 3058/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4447)
# Experiment 3060/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4448)
# Experiment 3062/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4449)
# Experiment 3064/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4450)
# Experiment 3066/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4451)
# Experiment 3068/3960: ghz_indep_5q (5q), global, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4452)
# Experiment 3070/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4453)
# Experiment 3072/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4454)
# Experiment 3074/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4455)
# Experiment 3076/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4456)
# Experiment 3078/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4457)
# Experiment 3080/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4458)
# Experiment 3082/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4459)
# Experiment 3084/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4460)
# Experiment 3086/3960: ghz_indep_5q (5q), global, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4461)
# Experiment 3088/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4462)
# Experiment 3090/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4463)
# Experiment 3092/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4464)
# Experiment 3094/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4465)
# Experiment 3096/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4466)
# Experiment 3098/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4467)
# Experiment 3100/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4468)
# Experiment 3102/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4469)
# Experiment 3104/3960: ghz_indep_5q (5q), global, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4470)
# Experiment 3106/3960: ghz_indep_4q (4q), global, noise=0.001, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4471)
# Experiment 3108/3960: ghz_indep_4q (4q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4472)
# Experiment 3110/3960: ghz_indep_4q (4q), global, noise=0.001, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4473)
# Experiment 3112/3960: ghz_indep_4q (4q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4474)
# Experiment 3114/3960: ghz_indep_4q (4q), global, noise=0.001, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4475)
# Experiment 3116/3960: ghz_indep_4q (4q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4476)
# Experiment 3118/3960: ghz_indep_4q (4q), global, noise=0.005, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4477)
# Experiment 3120/3960: ghz_indep_4q (4q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4478)
# Experiment 3122/3960: ghz_indep_4q (4q), global, noise=0.005, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4479)
# Experiment 3124/3960: ghz_indep_4q (4q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4480)
# Experiment 3126/3960: ghz_indep_4q (4q), global, noise=0.005, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4481)
# Experiment 3128/3960: ghz_indep_4q (4q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4482)
# Experiment 3130/3960: ghz_indep_4q (4q), global, noise=0.01, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4483)
# Experiment 3132/3960: ghz_indep_4q (4q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4484)
# Experiment 3134/3960: ghz_indep_4q (4q), global, noise=0.01, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4485)
# Experiment 3136/3960: ghz_indep_4q (4q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4486)
# Experiment 3138/3960: ghz_indep_4q (4q), global, noise=0.01, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4487)
# Experiment 3140/3960: ghz_indep_4q (4q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4488)
# Experiment 3142/3960: ghz_indep_4q (4q), global, noise=0.015, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4489)
# Experiment 3144/3960: ghz_indep_4q (4q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4490)
# Experiment 3146/3960: ghz_indep_4q (4q), global, noise=0.015, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4491)
# Experiment 3148/3960: ghz_indep_4q (4q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4492)
# Experiment 3150/3960: ghz_indep_4q (4q), global, noise=0.015, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4493)
# Experiment 3152/3960: ghz_indep_4q (4q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4494)
# Experiment 3154/3960: ghz_indep_4q (4q), global, noise=0.02, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4495)
# Experiment 3156/3960: ghz_indep_4q (4q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4496)
# Experiment 3158/3960: ghz_indep_4q (4q), global, noise=0.02, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4497)
# Experiment 3160/3960: ghz_indep_4q (4q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4498)
# Experiment 3162/3960: ghz_indep_4q (4q), global, noise=0.02, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4499)
# Experiment 3164/3960: ghz_indep_4q (4q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4500)
# Experiment 3166/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4501)
# Experiment 3168/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4502)
# Experiment 3170/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4503)
# Experiment 3172/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4504)
# Experiment 3174/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4505)
# Experiment 3176/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4506)
# Experiment 3178/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4507)
# Experiment 3180/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4508)
# Experiment 3182/3960: ghz_indep_8q (8q), global, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4509)
# Experiment 3184/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4510)
# Experiment 3186/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4511)
# Experiment 3188/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4512)
# Experiment 3190/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4513)
# Experiment 3192/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4514)
# Experiment 3194/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4515)
# Experiment 3196/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4516)
# Experiment 3198/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4517)
# Experiment 3200/3960: ghz_indep_8q (8q), global, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4518)
# Experiment 3202/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4519)
# Experiment 3204/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4520)
# Experiment 3206/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4521)
# Experiment 3208/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4522)
# Experiment 3210/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4523)
# Experiment 3212/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4524)
# Experiment 3214/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4525)
# Experiment 3216/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4526)
# Experiment 3218/3960: ghz_indep_8q (8q), global, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4527)
# Experiment 3220/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4528)
# Experiment 3222/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4529)
# Experiment 3224/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4530)
# Experiment 3226/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4531)
# Experiment 3228/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4532)
# Experiment 3230/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4533)
# Experiment 3232/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4534)
# Experiment 3234/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4535)
# Experiment 3236/3960: ghz_indep_8q (8q), global, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4536)
# Experiment 3238/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4537)
# Experiment 3240/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4538)
# Experiment 3242/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4539)
# Experiment 3244/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4540)
# Experiment 3246/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4541)
# Experiment 3248/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4542)
# Experiment 3250/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4543)
# Experiment 3252/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4544)
# Experiment 3254/3960: ghz_indep_8q (8q), global, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4545)
# Experiment 3256/3960: ghz_indep_3q (3q), global, noise=0.001, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4546)
# Experiment 3258/3960: ghz_indep_3q (3q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4547)
# Experiment 3260/3960: ghz_indep_3q (3q), global, noise=0.001, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4548)
# Experiment 3262/3960: ghz_indep_3q (3q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4549)
# Experiment 3264/3960: ghz_indep_3q (3q), global, noise=0.001, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4550)
# Experiment 3266/3960: ghz_indep_3q (3q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4551)
# Experiment 3268/3960: ghz_indep_3q (3q), global, noise=0.005, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4552)
# Experiment 3270/3960: ghz_indep_3q (3q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4553)
# Experiment 3272/3960: ghz_indep_3q (3q), global, noise=0.005, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4554)
# Experiment 3274/3960: ghz_indep_3q (3q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4555)
# Experiment 3276/3960: ghz_indep_3q (3q), global, noise=0.005, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4556)
# Experiment 3278/3960: ghz_indep_3q (3q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4557)
# Experiment 3280/3960: ghz_indep_3q (3q), global, noise=0.01, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4558)
# Experiment 3282/3960: ghz_indep_3q (3q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4559)
# Experiment 3284/3960: ghz_indep_3q (3q), global, noise=0.01, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4560)
# Experiment 3286/3960: ghz_indep_3q (3q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4561)
# Experiment 3288/3960: ghz_indep_3q (3q), global, noise=0.01, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4562)
# Experiment 3290/3960: ghz_indep_3q (3q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4563)
# Experiment 3292/3960: ghz_indep_3q (3q), global, noise=0.015, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4564)
# Experiment 3294/3960: ghz_indep_3q (3q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4565)
# Experiment 3296/3960: ghz_indep_3q (3q), global, noise=0.015, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4566)
# Experiment 3298/3960: ghz_indep_3q (3q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4567)
# Experiment 3300/3960: ghz_indep_3q (3q), global, noise=0.015, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4568)
# Experiment 3302/3960: ghz_indep_3q (3q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4569)
# Experiment 3304/3960: ghz_indep_3q (3q), global, noise=0.02, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4570)
# Experiment 3306/3960: ghz_indep_3q (3q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4571)
# Experiment 3308/3960: ghz_indep_3q (3q), global, noise=0.02, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4572)
# Experiment 3310/3960: ghz_indep_3q (3q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4573)
# Experiment 3312/3960: ghz_indep_3q (3q), global, noise=0.02, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4574)
# Experiment 3314/3960: ghz_indep_3q (3q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4575)
# Experiment 3316/3960: ghz_indep_2q (2q), global, noise=0.001, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4576)
# Experiment 3318/3960: ghz_indep_2q (2q), global, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4577)
# Experiment 3320/3960: ghz_indep_2q (2q), global, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4578)
# Experiment 3322/3960: ghz_indep_2q (2q), global, noise=0.005, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4579)
# Experiment 3324/3960: ghz_indep_2q (2q), global, noise=0.005, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4580)
# Experiment 3326/3960: ghz_indep_2q (2q), global, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4581)
# Experiment 3328/3960: ghz_indep_2q (2q), global, noise=0.01, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4582)
# Experiment 3330/3960: ghz_indep_2q (2q), global, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4583)
# Experiment 3332/3960: ghz_indep_2q (2q), global, noise=0.01, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4584)
# Experiment 3334/3960: ghz_indep_2q (2q), global, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4585)
# Experiment 3336/3960: ghz_indep_2q (2q), global, noise=0.015, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4586)
# Experiment 3338/3960: ghz_indep_2q (2q), global, noise=0.015, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4587)
# Experiment 3340/3960: ghz_indep_2q (2q), global, noise=0.02, comm=1.0x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4588)
# Experiment 3342/3960: ghz_indep_2q (2q), global, noise=0.02, comm=1.1x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4589)
# Experiment 3344/3960: ghz_indep_2q (2q), global, noise=0.02, comm=1.2x, tp, parts=1
# /usr/local/lib/python3.10/site-packages/mitiq/zne/inference.py:88: UserWarning: The input circuit is very short. This may reduce the accuracy of noise scaling.
#   warnings.warn(
#   SUCCESS - Saved (Total rows: 4590)
# Experiment 3346/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4591)
# Experiment 3348/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4592)
# Experiment 3350/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4593)
# Experiment 3352/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4594)
# Experiment 3354/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4595)
# Experiment 3356/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4596)
# Experiment 3358/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 4597)
# Experiment 3360/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4598)
# Experiment 3362/3960: ghz_indep_10q (10q), global, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4599)
# Experiment 3364/3960: ghz_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4600)
# Experiment 3366/3960: ghz_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4601)
# Experiment 3368/3960: ghz_indep_10q (10q), global, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4602)
# Experiment 3370/3960: ghz_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 4603)
# Experiment 3372/3960: ghz_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 4604)
# Experiment 3374/3960: ghz_indep_10q (10q), global, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 4605)
# Experiment 3376/3960: ghz_indep_10q (10q), global, noise=0.005, comm=1.2x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
# ...
#   SUCCESS - Saved (Total rows: 5296)
# Experiment 4758/3960: dj_indep_4q (4q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5297)
# Experiment 4760/3960: dj_indep_4q (4q), global, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5298)
# Experiment 4762/3960: dj_indep_4q (4q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5299)
# Experiment 4764/3960: dj_indep_4q (4q), global, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5300)
# Experiment 4766/3960: dj_indep_4q (4q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5301)
# Experiment 4768/3960: dj_indep_4q (4q), global, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5302)
# Experiment 4770/3960: dj_indep_4q (4q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5303)
# Experiment 4772/3960: dj_indep_4q (4q), global, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5304)
# Experiment 4774/3960: dj_indep_4q (4q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5305)
# Experiment 4776/3960: dj_indep_4q (4q), global, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5306)
# Experiment 4778/3960: dj_indep_4q (4q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5307)
# Experiment 4780/3960: dj_indep_4q (4q), global, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5308)
# Experiment 4782/3960: dj_indep_4q (4q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5309)
# Experiment 4784/3960: dj_indep_4q (4q), global, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5310)
# Experiment 4786/3960: dj_indep_4q (4q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5311)
# Experiment 4788/3960: dj_indep_4q (4q), global, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5312)
# Experiment 4790/3960: dj_indep_4q (4q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5313)
# Experiment 4792/3960: dj_indep_4q (4q), global, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5314)
# Experiment 4794/3960: dj_indep_4q (4q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5315)
# Experiment 4796/3960: dj_indep_4q (4q), global, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5316)
# Experiment 4798/3960: dj_indep_4q (4q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5317)
# Experiment 4800/3960: dj_indep_4q (4q), global, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5318)
# Experiment 4802/3960: dj_indep_4q (4q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5319)
# Experiment 4804/3960: dj_indep_4q (4q), global, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5320)
# Experiment 4806/3960: dj_indep_4q (4q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5321)
# Experiment 4808/3960: dj_indep_4q (4q), global, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5322)
# Experiment 4810/3960: dj_indep_4q (4q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5323)
# Experiment 4812/3960: dj_indep_4q (4q), global, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5324)
# Experiment 4814/3960: dj_indep_4q (4q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5325)
# Experiment 4816/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5326)
# Experiment 4818/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5327)
# Experiment 4820/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5328)
# Experiment 4822/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5329)
# Experiment 4824/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5330)
# Experiment 4826/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5331)
# Experiment 4828/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5332)
# Experiment 4830/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5333)
# Experiment 4832/3960: dj_indep_7q (7q), global, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5334)
# Experiment 4834/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5335)
# Experiment 4836/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5336)
# Experiment 4838/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5337)
# Experiment 4840/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5338)
# Experiment 4842/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5339)
# Experiment 4844/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5340)
# Experiment 4846/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5341)
# Experiment 4848/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5342)
# Experiment 4850/3960: dj_indep_7q (7q), global, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5343)
# Experiment 4852/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5344)
# Experiment 4854/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5345)
# Experiment 4856/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5346)
# Experiment 4858/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5347)
# Experiment 4860/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5348)
# Experiment 4862/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5349)
# Experiment 4864/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5350)
# Experiment 4866/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5351)
# Experiment 4868/3960: dj_indep_7q (7q), global, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5352)
# Experiment 4870/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5353)
# Experiment 4872/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5354)
# Experiment 4874/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5355)
# Experiment 4876/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5356)
# Experiment 4878/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5357)
# Experiment 4880/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5358)
# Experiment 4882/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5359)
# Experiment 4884/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5360)
# Experiment 4886/3960: dj_indep_7q (7q), global, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5361)
# Experiment 4888/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5362)
# Experiment 4890/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5363)
# Experiment 4892/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5364)
# Experiment 4894/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5365)
# Experiment 4896/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5366)
# Experiment 4898/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5367)
# Experiment 4900/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5368)
# Experiment 4902/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5369)
# Experiment 4904/3960: dj_indep_7q (7q), global, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5370)
# Experiment 4906/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5371)
# Experiment 4908/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5372)
# Experiment 4910/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5373)
# Experiment 4912/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5374)
# Experiment 4914/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5375)
# Experiment 4916/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5376)
# Experiment 4918/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5377)
# Experiment 4920/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5378)
# Experiment 4922/3960: dj_indep_6q (6q), global, noise=0.001, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5379)
# Experiment 4924/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5380)
# Experiment 4926/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5381)
# Experiment 4928/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5382)
# Experiment 4930/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5383)
# Experiment 4932/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5384)
# Experiment 4934/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5385)
# Experiment 4936/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5386)
# Experiment 4938/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5387)
# Experiment 4940/3960: dj_indep_6q (6q), global, noise=0.005, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5388)
# Experiment 4942/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.0x, tp, parts=1
# /Users/mariagragera/Desktop/ZNE-DQC/mqt.py:315: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_df], ignore_index=True)
#   SUCCESS - Saved (Total rows: 5389)
# Experiment 4944/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5390)
# Experiment 4946/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5391)
# Experiment 4948/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5392)
# Experiment 4950/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5393)
# Experiment 4952/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5394)
# Experiment 4954/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5395)
# Experiment 4956/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5396)
# Experiment 4958/3960: dj_indep_6q (6q), global, noise=0.01, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5397)
# Experiment 4960/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5398)
# Experiment 4962/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5399)
# Experiment 4964/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5400)
# Experiment 4966/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5401)
# Experiment 4968/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5402)
# Experiment 4970/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5403)
# Experiment 4972/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5404)
# Experiment 4974/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5405)
# Experiment 4976/3960: dj_indep_6q (6q), global, noise=0.015, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5406)
# Experiment 4978/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5407)
# Experiment 4980/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.0x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5408)
# Experiment 4982/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.0x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5409)
# Experiment 4984/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.1x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5410)
# Experiment 4986/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.1x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5411)
# Experiment 4988/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.1x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5412)
# Experiment 4990/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.2x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5413)
# Experiment 4992/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.2x, tp, parts=3
#   SUCCESS - Saved (Total rows: 5414)
# Experiment 4994/3960: dj_indep_6q (6q), global, noise=0.02, comm=1.2x, tp, parts=5
#   SUCCESS - Saved (Total rows: 5415)
#
# ======================================================================
# 4. RESULTS SUMMARY
# ======================================================================
# Experiments completed: 5415
# Results saved to: results.csv
# Skipped (simulator limit): 0
#
# Origins tested:
#   dj_indep_10q: 223 experiments
#   dj_indep_2q: 75 experiments
#   dj_indep_3q: 120 experiments
#   dj_indep_5q: 210 experiments
#   dj_indep_9q: 270 experiments
#   dj_indep_8q: 270 experiments
#   dj_indep_4q: 180 experiments
#   dj_indep_7q: 270 experiments
#   dj_indep_6q: 270 experiments
#   ghz_indep_9q: 225 experiments
#   ghz_indep_5q: 180 experiments
#   ghz_indep_4q: 150 experiments
#   ghz_indep_8q: 225 experiments
#   ghz_indep_3q: 105 experiments
#   ghz_indep_2q: 75 experiments
#   ghz_indep_10q: 225 experiments
#   ghz_indep_7q: 225 experiments
#   ghz_indep_6q: 225 experiments
#   wstate_indep_7q: 225 experiments
#   wstate_indep_10q: 257 experiments
#   wstate_indep_6q: 270 experiments
#   wstate_indep_3q: 120 experiments
#   wstate_indep_2q: 90 experiments
#   wstate_indep_9q: 270 experiments
#   wstate_indep_5q: 210 experiments
#   wstate_indep_4q: 180 experiments
#   wstate_indep_8q: 270 experiments

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10_qft',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ======================================================================
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_under10_qft for QASM files...
# Found 9 QASM files
#   Loading: qft_indep_qiskit_7.qasm -> qft_indep (7 qubits)
#     LOADED: qft_indep_7q, depth=14
#   Loading: qft_indep_qiskit_6.qasm -> qft_indep (6 qubits)
#     LOADED: qft_indep_6q, depth=12
#   Loading: qft_indep_qiskit_10.qasm -> qft_indep (10 qubits)
#     LOADED: qft_indep_10q, depth=20
#   Loading: qft_indep_qiskit_3.qasm -> qft_indep (3 qubits)
#     LOADED: qft_indep_3q, depth=6
#   Loading: qft_indep_qiskit_2.qasm -> qft_indep (2 qubits)
#     LOADED: qft_indep_2q, depth=4
#   Loading: qft_indep_qiskit_9.qasm -> qft_indep (9 qubits)
#     LOADED: qft_indep_9q, depth=18
#   Loading: qft_indep_qiskit_5.qasm -> qft_indep (5 qubits)
#     Warning: Expected 5 qubits, got 0
#     LOADED: qft_indep_0q, depth=0
#   Loading: qft_indep_qiskit_4.qasm -> qft_indep (4 qubits)
#     LOADED: qft_indep_4q, depth=8
#   Loading: qft_indep_qiskit_8.qasm -> qft_indep (8 qubits)
#     LOADED: qft_indep_8q, depth=16
#
# Total circuits loaded: 9
#   Origins: ['qft_indep']
#   Qubit range: 0 - 10
#
# Loaded progress: 3960 experiments already completed
# Loaded existing results: 5415 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 4560
# Already completed: 3960
# Remaining: 600
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
#
# 3. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Experiment 3961/4560: qft_indep_7q (7q), global, noise=0.001, comm=1.0x, tp, parts=1
#   SUCCESS - Saved (Total rows: 5416)
# Experiment 3963/4560: qft_indep_7q (7q), global, noise=0.001, comm=1.0x, tp, parts=2
#   SUCCESS - Saved (Total rows: 5417)
# Experiment 3965/4560: qft_indep_7q (7q), global, noise=0.001, comm=1.0x, tp, parts=3

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10_qft',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10_qaoa',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['local'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQT_under10_qaoa',
    min_qubits=2,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
