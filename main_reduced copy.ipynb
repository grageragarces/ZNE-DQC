# %%
from mqt import run_mqt_bench_experiments_parallel

# %% [markdown]
# after this is the 15 qubit range

# %%
test_df = run_mqt_bench_experiments_parallel(
    mqt_folder='MQT_w',
    min_qubits=2,
    max_qubits=5,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress_w_small.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (PARALLEL)
# ======================================================================
# Simulator qubit limit: 31
# Parallel workers: 11
# Batch save interval: 10 experiments
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_w for QASM files...
# Found 24 QASM files
#   Loading: wstate_indep_qiskit_3.qasm -> wstate_indep (3 qubits)
#     LOADED: wstate_indep_3q, depth=6
#   Loading: wstate_indep_qiskit_2.qasm -> wstate_indep (2 qubits)
#     LOADED: wstate_indep_2q, depth=4
#   Loading: wstate_indep_qiskit_5.qasm -> wstate_indep (5 qubits)
#     LOADED: wstate_indep_5q, depth=10
#   Loading: wstate_indep_qiskit_4.qasm -> wstate_indep (4 qubits)
#     LOADED: wstate_indep_4q, depth=8
#
# Total circuits loaded: 4
#   Origins: ['wstate_indep']
#   Qubit range: 2 - 5
#
# Loaded progress: 90 experiments already completed
# Loaded existing results: 3671 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 210
# Already completed: 90
# Remaining: 120
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
# 3. RUNNING EXPERIMENTS IN PARALLEL
# ----------------------------------------------------------------------
# [91/210] ✓ wstate_indep_5q_global_0.005_1.2_tp_1... (43.3%, ETA: 0:17:38)
# [92/210] ✓ wstate_indep_5q_global_0.005_1.2_tp_2... (43.8%, ETA: 0:17:56)
# [93/210] ✓ wstate_indep_5q_global_0.005_1.2_tp_3... (44.3%, ETA: 1:30:02)

# %%
test_df = run_mqt_bench_experiments_parallel(
    mqt_folder='MQT_w',
    min_qubits=6,
    max_qubits=10,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress_w.json'
)

# %%
test_df = run_mqt_bench_experiments_parallel(
    mqt_folder='MQT_w',
    min_qubits=10,
    max_qubits=15,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress_w15.json'
)

# %%
test_df = run_mqt_bench_experiments_parallel(
    mqt_folder='MQT_nondj',
    min_qubits=2,
    max_qubits=15,
    max_circuits_per_origin=10,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['tp'],
    partition_counts=[1, 2, 3, 4, 5, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress_copy.json'
)
# Out:
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (PARALLEL)
# ======================================================================
# Simulator qubit limit: 31
# Parallel workers: 11
# Batch save interval: 10 experiments
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQT_nondj for QASM files...
# Found 48 QASM files
#   Loading: ghz_indep_qiskit_9.qasm -> ghz_indep (9 qubits)
#     LOADED: ghz_indep_9q, depth=9
#   Loading: ghz_indep_qiskit_15.qasm -> ghz_indep (15 qubits)
#     LOADED: ghz_indep_15q, depth=15
#   Loading: wstate_indep_qiskit_7.qasm -> wstate_indep (7 qubits)
#     LOADED: wstate_indep_7q, depth=14
#   Loading: ghz_indep_qiskit_5.qasm -> ghz_indep (5 qubits)
#     LOADED: ghz_indep_5q, depth=5
#   Loading: wstate_indep_qiskit_10.qasm -> wstate_indep (10 qubits)
#     LOADED: wstate_indep_10q, depth=20
#   Loading: wstate_indep_qiskit_11.qasm -> wstate_indep (11 qubits)
#     LOADED: wstate_indep_11q, depth=22
#   Loading: ghz_indep_qiskit_4.qasm -> ghz_indep (4 qubits)
#     LOADED: ghz_indep_4q, depth=4
#   Loading: wstate_indep_qiskit_6.qasm -> wstate_indep (6 qubits)
#     LOADED: wstate_indep_6q, depth=12
#   Loading: ghz_indep_qiskit_14.qasm -> ghz_indep (14 qubits)
#     LOADED: ghz_indep_14q, depth=14
#   Loading: ghz_indep_qiskit_8.qasm -> ghz_indep (8 qubits)
#     LOADED: ghz_indep_8q, depth=8
#   Loading: ghz_indep_qiskit_3.qasm -> ghz_indep (3 qubits)
#     LOADED: ghz_indep_3q, depth=3
#   Loading: ghz_indep_qiskit_13.qasm -> ghz_indep (13 qubits)
#     LOADED: ghz_indep_13q, depth=13
#   Loading: ghz_indep_qiskit_12.qasm -> ghz_indep (12 qubits)
#     LOADED: ghz_indep_12q, depth=12
#   Loading: ghz_indep_qiskit_2.qasm -> ghz_indep (2 qubits)
#     LOADED: ghz_indep_2q, depth=2
#   Loading: wstate_indep_qiskit_14.qasm -> wstate_indep (14 qubits)
#     LOADED: wstate_indep_14q, depth=28
#   Loading: wstate_indep_qiskit_3.qasm -> wstate_indep (3 qubits)
#     LOADED: wstate_indep_3q, depth=6
#   Loading: wstate_indep_qiskit_2.qasm -> wstate_indep (2 qubits)
#     LOADED: wstate_indep_2q, depth=4
#   Loading: wstate_indep_qiskit_15.qasm -> wstate_indep (15 qubits)
#     LOADED: wstate_indep_15q, depth=30
#   Loading: wstate_indep_qiskit_9.qasm -> wstate_indep (9 qubits)
#     LOADED: wstate_indep_9q, depth=18
#   Loading: wstate_indep_qiskit_12.qasm -> wstate_indep (12 qubits)
#     LOADED: wstate_indep_12q, depth=24
#
# Total circuits loaded: 20
#   Origins: ['ghz_indep', 'wstate_indep']
#   Qubit range: 2 - 15
#
# Loaded progress: 0 experiments already completed
# Loaded existing results: 3471 rows
#
# 2. EXPERIMENT PLANNING
# ----------------------------------------------------------------------
# Total valid experiments: 1545
# Already completed: 0
# Remaining: 1545
# Skipped (exceeds 31 qubit limit): 0
#
# Output file: results.csv
#
# 3. RUNNING EXPERIMENTS IN PARALLEL
# ----------------------------------------------------------------------
# [1/1545] ✓ ghz_indep_9q_global_0.001_1.0_tp_1... (0.1%, ETA: 7:19:38)
# [2/1545] ✓ ghz_indep_9q_global_0.001_1.1_tp_1... (0.1%, ETA: 3:45:46)
# [3/1545] ✓ ghz_indep_9q_global_0.001_1.0_tp_2... (0.2%, ETA: 3:15:29)
