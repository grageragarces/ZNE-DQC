# %% [markdown]
# # Local vs Global Encoding in ZNE: Simulation Framework
#
# This notebook tests whether local or global encoding makes more sense in the context of Zero Noise Extrapolation (ZNE) for partitioned quantum circuits.

# %% [markdown]
# ## 1. Setup and Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from qiskit import QuantumCircuit
import warnings
warnings.filterwarnings('ignore')

# Import custom modules
from algs import get_algorithm, create_random_circuit
from partitioning import partitioning
from simulate import (
    run_simulation_experiment, 
    run_batch_experiments,
    create_noise_model
)

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 2. Generate Test Circuits

# %%
# Configuration
NUM_QUBITS = [4, 6, 8]
ALGORITHMS = ['random', 'qft', 'ghz', 'hardware_efficient']
DEPTH = 5

# Generate circuits
test_circuits = []

for n_qubits in NUM_QUBITS:
    for alg_name in ALGORITHMS:
        try:
            circuit = get_algorithm(alg_name, n_qubits, depth=DEPTH, seed=42)
            test_circuits.append((circuit, f"{alg_name}_{n_qubits}q"))
            print(f"Created {alg_name} circuit with {n_qubits} qubits")
        except Exception as e:
            print(f"Failed to create {alg_name} with {n_qubits} qubits: {e}")

print(f"\nTotal circuits generated: {len(test_circuits)}")
# Out:
# Created random circuit with 4 qubits
# Created qft circuit with 4 qubits
# Created ghz circuit with 4 qubits
# Created hardware_efficient circuit with 4 qubits
# Created random circuit with 6 qubits
# Created qft circuit with 6 qubits
# Created ghz circuit with 6 qubits
# Created hardware_efficient circuit with 6 qubits
# Created random circuit with 8 qubits
# Created qft circuit with 8 qubits
# Created ghz circuit with 8 qubits
# Created hardware_efficient circuit with 8 qubits
#
# Total circuits generated: 12

# %% [markdown]
# ## 3. Visualize Sample Circuits

# %%
# Display a sample circuit
if test_circuits:
    sample_circuit, sample_name = test_circuits[0]
    print(f"Sample circuit: {sample_name}")
    print(f"Qubits: {sample_circuit.num_qubits}, Depth: {sample_circuit.depth()}")
    print(sample_circuit)
# Out:
# Sample circuit: random_4q
# Qubits: 4, Depth: 5
#      ┌───┐┌───┐┌───┐    ┌───┐         ┌───┐
# q_0: ┤ T ├┤ Y ├┤ T ├────┤ H ├─────────┤ Z ├─────
#      ├───┤├───┤└───┘    ├───┤     ┌───┴───┴────┐
# q_1: ┤ Z ├┤ X ├──■──────┤ H ├─────┤ Rx(5.9735) ├
#      ├───┤├───┤  │  ┌───┴───┴────┐└────────────┘
# q_2: ┤ H ├┤ S ├──┼──┤ Rz(2.3533) ├──────────────
#      ├───┤└───┘  │  └───┬───┬────┘
# q_3: ┤ S ├───────■──────┤ Z ├───────────────────
#      └───┘              └───┘

# %% [markdown]
# ## 4. Test Single Experiment
#
# Run a single experiment to verify the pipeline works.

# %%
# Test with a small circuit
test_qc = create_random_circuit(num_qubits=4, depth=3, seed=42)

print("Testing GLOBAL optimization:")
result_global = run_simulation_experiment(
    circuit=test_qc,
    strategy='global',
    algorithm_name='test_random',
    local_noise=0.01,
    comm_noise_multiplier=1.1,
    comm_primitive='cat',
    shots=1024,
    seed=42
)

print("\nGlobal optimization results:")
for key, value in result_global.items():
    print(f"  {key}: {value}")

print("\n" + "="*60)
print("Testing LOCAL optimization:")
result_local = run_simulation_experiment(
    circuit=test_qc,
    strategy='local',
    algorithm_name='test_random',
    local_noise=0.01,
    comm_noise_multiplier=1.1,
    comm_primitive='cat',
    shots=1024,
    seed=42
)

print("\nLocal optimization results:")
for key, value in result_local.items():
    print(f"  {key}: {value}")
# Out:
# Testing GLOBAL optimization:
#
# Global optimization results:
#   origin: test_random
#   strategy: global
#   communication_noise_multiplier: 1.1
#   local_noise: 0.01
#   communication_primitive: cat
#   num_qubits: 4
#   circuit_depth: 5
#   partitioned_depth: 7
#   num_partitions_requested: 2
#   num_partitions_tested: 2
#   noise_free_expectation: 0.041015625
#   noisy_expectation: -0.041015625
#   zne_expectation: 0.056640625
#   noisy_error: 0.08203125
#   zne_error: 0.015625
#   error_reduction: 0.8095238095238095
#   partition_time: 0.0020380020141601562
#   shots: 1024
#   seed: 42
#
# ============================================================
# Testing LOCAL optimization:
#
# Local optimization results:
#   origin: test_random
#   strategy: local
#   communication_noise_multiplier: 1.1
#   local_noise: 0.01
#   communication_primitive: cat
#   num_qubits: 4
#   circuit_depth: 5
#   partitioned_depth: 7
#   num_partitions_requested: 2
#   num_partitions_tested: 2
#   noise_free_expectation: 0.041015625
#   noisy_expectation: -0.041015625
#   zne_expectation: 0.013671875
#   noisy_error: 0.08203125
#   zne_error: 0.02734375
#   error_reduction: 0.6666666666666666
#   partition_time: 0.0022525787353515625
#   shots: 1024
#   seed: 42

# %% [markdown]
# ## 5. Run Batch Experiments
#
# Run comprehensive experiments across all configurations.

# %%
# Experimental parameters
STRATEGIES = ['global', 'local']
LOCAL_NOISE_LEVELS = [0.01, 0.02, 0.05]
COMM_NOISE_MULTIPLIERS = [1.0, 1.05, 1.1, 1.2]  # As specified
COMM_PRIMITIVES = ['cat', 'teleportation']
SHOTS = 1024

# Run experiments
results_df = run_batch_experiments(
    circuits=test_circuits[:20],  # Start with subset for testing
    strategies=STRATEGIES,
    noise_levels=LOCAL_NOISE_LEVELS,
    comm_noise_multipliers=COMM_NOISE_MULTIPLIERS,
    comm_primitives=COMM_PRIMITIVES,
    shots=SHOTS,
    output_file='results.csv'
)

print("\nExperiments completed!")
print(f"Total results: {len(results_df)}")
# Out:
# Running 2880 experiments...
# Experiment 1/2880: random_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 2/2880: random_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 3/2880: random_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 4/2880: random_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 5/2880: random_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 6/2880: random_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 7/2880: random_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 8/2880: random_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 9/2880: random_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 10/2880: random_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 11/2880: random_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 12/2880: random_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 13/2880: random_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 14/2880: random_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 15/2880: random_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 16/2880: random_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 17/2880: random_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 18/2880: random_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 19/2880: random_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 20/2880: random_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 21/2880: random_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 22/2880: random_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 23/2880: random_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 24/2880: random_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 25/2880: random_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 26/2880: random_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 27/2880: random_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 28/2880: random_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 29/2880: random_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 30/2880: random_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 31/2880: random_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 32/2880: random_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 33/2880: random_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 34/2880: random_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 35/2880: random_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 36/2880: random_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 37/2880: random_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 38/2880: random_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 39/2880: random_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 40/2880: random_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 41/2880: random_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 42/2880: random_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 43/2880: random_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 44/2880: random_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 45/2880: random_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 46/2880: random_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 47/2880: random_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 48/2880: random_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 49/2880: random_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 50/2880: random_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 51/2880: random_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 52/2880: random_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 53/2880: random_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 54/2880: random_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 55/2880: random_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 56/2880: random_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 57/2880: random_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 58/2880: random_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 59/2880: random_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 60/2880: random_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 61/2880: random_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 62/2880: random_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 63/2880: random_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 64/2880: random_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 65/2880: random_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 66/2880: random_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 67/2880: random_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 68/2880: random_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 69/2880: random_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 70/2880: random_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 71/2880: random_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 72/2880: random_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 73/2880: random_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 74/2880: random_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 75/2880: random_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 76/2880: random_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 77/2880: random_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 78/2880: random_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 79/2880: random_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 80/2880: random_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 81/2880: random_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 82/2880: random_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 83/2880: random_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 84/2880: random_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 85/2880: random_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 86/2880: random_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 87/2880: random_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 88/2880: random_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 89/2880: random_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 90/2880: random_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 91/2880: random_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 92/2880: random_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 93/2880: random_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 94/2880: random_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 95/2880: random_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 96/2880: random_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 97/2880: qft_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 98/2880: qft_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 99/2880: qft_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 100/2880: qft_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 101/2880: qft_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 102/2880: qft_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 103/2880: qft_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 104/2880: qft_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 105/2880: qft_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 106/2880: qft_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 107/2880: qft_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 108/2880: qft_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 109/2880: qft_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 110/2880: qft_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 111/2880: qft_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 112/2880: qft_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 113/2880: qft_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 114/2880: qft_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 115/2880: qft_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 116/2880: qft_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 117/2880: qft_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 118/2880: qft_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 119/2880: qft_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 120/2880: qft_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 121/2880: qft_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 122/2880: qft_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 123/2880: qft_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 124/2880: qft_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 125/2880: qft_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 126/2880: qft_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 127/2880: qft_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 128/2880: qft_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 129/2880: qft_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 130/2880: qft_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 131/2880: qft_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 132/2880: qft_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 133/2880: qft_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 134/2880: qft_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 135/2880: qft_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 136/2880: qft_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 137/2880: qft_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 138/2880: qft_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 139/2880: qft_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 140/2880: qft_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 141/2880: qft_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 142/2880: qft_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 143/2880: qft_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 144/2880: qft_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 145/2880: qft_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 146/2880: qft_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 147/2880: qft_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 148/2880: qft_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 149/2880: qft_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 150/2880: qft_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 151/2880: qft_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 152/2880: qft_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 153/2880: qft_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 154/2880: qft_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 155/2880: qft_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 156/2880: qft_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 157/2880: qft_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 158/2880: qft_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 159/2880: qft_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 160/2880: qft_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 161/2880: qft_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 162/2880: qft_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 163/2880: qft_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 164/2880: qft_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 165/2880: qft_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 166/2880: qft_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 167/2880: qft_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 168/2880: qft_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 169/2880: qft_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 170/2880: qft_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 171/2880: qft_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 172/2880: qft_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 173/2880: qft_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 174/2880: qft_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 175/2880: qft_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 176/2880: qft_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 177/2880: qft_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 178/2880: qft_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 179/2880: qft_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 180/2880: qft_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 181/2880: qft_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 182/2880: qft_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 183/2880: qft_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 184/2880: qft_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 185/2880: qft_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 186/2880: qft_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 187/2880: qft_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 188/2880: qft_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 189/2880: qft_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 190/2880: qft_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 191/2880: qft_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 192/2880: qft_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 193/2880: ghz_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 194/2880: ghz_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 195/2880: ghz_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 196/2880: ghz_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 197/2880: ghz_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 198/2880: ghz_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 199/2880: ghz_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 200/2880: ghz_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 201/2880: ghz_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 202/2880: ghz_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 203/2880: ghz_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 204/2880: ghz_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 205/2880: ghz_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 206/2880: ghz_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 207/2880: ghz_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 208/2880: ghz_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 209/2880: ghz_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 210/2880: ghz_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 211/2880: ghz_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 212/2880: ghz_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 213/2880: ghz_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 214/2880: ghz_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 215/2880: ghz_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 216/2880: ghz_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 217/2880: ghz_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 218/2880: ghz_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 219/2880: ghz_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 220/2880: ghz_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 221/2880: ghz_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 222/2880: ghz_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 223/2880: ghz_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 224/2880: ghz_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 225/2880: ghz_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 226/2880: ghz_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 227/2880: ghz_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 228/2880: ghz_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 229/2880: ghz_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 230/2880: ghz_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 231/2880: ghz_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 232/2880: ghz_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 233/2880: ghz_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 234/2880: ghz_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 235/2880: ghz_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 236/2880: ghz_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 237/2880: ghz_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 238/2880: ghz_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 239/2880: ghz_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 240/2880: ghz_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 241/2880: ghz_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 242/2880: ghz_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 243/2880: ghz_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 244/2880: ghz_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 245/2880: ghz_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 246/2880: ghz_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 247/2880: ghz_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 248/2880: ghz_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 249/2880: ghz_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 250/2880: ghz_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 251/2880: ghz_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 252/2880: ghz_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 253/2880: ghz_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 254/2880: ghz_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 255/2880: ghz_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 256/2880: ghz_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 257/2880: ghz_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 258/2880: ghz_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 259/2880: ghz_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 260/2880: ghz_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 261/2880: ghz_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 262/2880: ghz_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 263/2880: ghz_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 264/2880: ghz_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 265/2880: ghz_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 266/2880: ghz_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 267/2880: ghz_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 268/2880: ghz_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 269/2880: ghz_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 270/2880: ghz_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 271/2880: ghz_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 272/2880: ghz_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 273/2880: ghz_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 274/2880: ghz_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 275/2880: ghz_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 276/2880: ghz_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 277/2880: ghz_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 278/2880: ghz_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 279/2880: ghz_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 280/2880: ghz_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 281/2880: ghz_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 282/2880: ghz_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 283/2880: ghz_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 284/2880: ghz_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 285/2880: ghz_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 286/2880: ghz_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 287/2880: ghz_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 288/2880: ghz_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 289/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 290/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 291/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 292/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 293/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 294/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 295/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 296/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 297/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 298/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 299/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 300/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 301/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 302/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 303/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 304/2880: hardware_efficient_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 305/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 306/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 307/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 308/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 309/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 310/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 311/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 312/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 313/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 314/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 315/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 316/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 317/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 318/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 319/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 320/2880: hardware_efficient_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 321/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 322/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 323/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 324/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 325/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 326/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 327/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 328/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 329/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 330/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 331/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 332/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 333/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 334/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 335/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 336/2880: hardware_efficient_4q (4q), global, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 337/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 338/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 339/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 340/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 341/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 342/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 343/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 344/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 345/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 346/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 347/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 348/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 349/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 350/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 351/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 352/2880: hardware_efficient_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 353/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 354/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 355/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 356/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 357/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 358/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 359/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 360/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 361/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 362/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 363/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 364/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 365/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 366/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 367/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 368/2880: hardware_efficient_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 369/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 370/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 371/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 372/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 373/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 374/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 375/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 376/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 377/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 378/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 379/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 380/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 381/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 382/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 383/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 384/2880: hardware_efficient_4q (4q), local, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 385/2880: random_6q (6q), global, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 386/2880: random_6q (6q), global, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 387/2880: random_6q (6q), global, noise=0.01, comm=1.0x, cat, parts=6
# Experiment 388/2880: random_6q (6q), global, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 389/2880: random_6q (6q), global, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 390/2880: random_6q (6q), global, noise=0.01, comm=1.0x, teleportation, parts=6
# Experiment 391/2880: random_6q (6q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 392/2880: random_6q (6q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 393/2880: random_6q (6q), global, noise=0.01, comm=1.05x, cat, parts=6
# Experiment 394/2880: random_6q (6q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 395/2880: random_6q (6q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 396/2880: random_6q (6q), global, noise=0.01, comm=1.05x, teleportation, parts=6
# Experiment 397/2880: random_6q (6q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 398/2880: random_6q (6q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 399/2880: random_6q (6q), global, noise=0.01, comm=1.1x, cat, parts=6
# Experiment 400/2880: random_6q (6q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 401/2880: random_6q (6q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 402/2880: random_6q (6q), global, noise=0.01, comm=1.1x, teleportation, parts=6
# Experiment 403/2880: random_6q (6q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 404/2880: random_6q (6q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 405/2880: random_6q (6q), global, noise=0.01, comm=1.2x, cat, parts=6
# Experiment 406/2880: random_6q (6q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 407/2880: random_6q (6q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 408/2880: random_6q (6q), global, noise=0.01, comm=1.2x, teleportation, parts=6
# Experiment 409/2880: random_6q (6q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 410/2880: random_6q (6q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 411/2880: random_6q (6q), global, noise=0.02, comm=1.0x, cat, parts=6
# Experiment 412/2880: random_6q (6q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 413/2880: random_6q (6q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 414/2880: random_6q (6q), global, noise=0.02, comm=1.0x, teleportation, parts=6
# Experiment 415/2880: random_6q (6q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 416/2880: random_6q (6q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 417/2880: random_6q (6q), global, noise=0.02, comm=1.05x, cat, parts=6
# Experiment 418/2880: random_6q (6q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 419/2880: random_6q (6q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 420/2880: random_6q (6q), global, noise=0.02, comm=1.05x, teleportation, parts=6
# Experiment 421/2880: random_6q (6q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 422/2880: random_6q (6q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 423/2880: random_6q (6q), global, noise=0.02, comm=1.1x, cat, parts=6
# Experiment 424/2880: random_6q (6q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 425/2880: random_6q (6q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 426/2880: random_6q (6q), global, noise=0.02, comm=1.1x, teleportation, parts=6
# Experiment 427/2880: random_6q (6q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 428/2880: random_6q (6q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 429/2880: random_6q (6q), global, noise=0.02, comm=1.2x, cat, parts=6
# Experiment 430/2880: random_6q (6q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 431/2880: random_6q (6q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 432/2880: random_6q (6q), global, noise=0.02, comm=1.2x, teleportation, parts=6
# Experiment 433/2880: random_6q (6q), global, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 434/2880: random_6q (6q), global, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 435/2880: random_6q (6q), global, noise=0.05, comm=1.0x, cat, parts=6
# Experiment 436/2880: random_6q (6q), global, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 437/2880: random_6q (6q), global, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 438/2880: random_6q (6q), global, noise=0.05, comm=1.0x, teleportation, parts=6
# Experiment 439/2880: random_6q (6q), global, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 440/2880: random_6q (6q), global, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 441/2880: random_6q (6q), global, noise=0.05, comm=1.05x, cat, parts=6
# Experiment 442/2880: random_6q (6q), global, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 443/2880: random_6q (6q), global, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 444/2880: random_6q (6q), global, noise=0.05, comm=1.05x, teleportation, parts=6
# Experiment 445/2880: random_6q (6q), global, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 446/2880: random_6q (6q), global, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 447/2880: random_6q (6q), global, noise=0.05, comm=1.1x, cat, parts=6
# Experiment 448/2880: random_6q (6q), global, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 449/2880: random_6q (6q), global, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 450/2880: random_6q (6q), global, noise=0.05, comm=1.1x, teleportation, parts=6
# Experiment 451/2880: random_6q (6q), global, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 452/2880: random_6q (6q), global, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 453/2880: random_6q (6q), global, noise=0.05, comm=1.2x, cat, parts=6
# Experiment 454/2880: random_6q (6q), global, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 455/2880: random_6q (6q), global, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 456/2880: random_6q (6q), global, noise=0.05, comm=1.2x, teleportation, parts=6
# Experiment 457/2880: random_6q (6q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 458/2880: random_6q (6q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 459/2880: random_6q (6q), local, noise=0.01, comm=1.0x, cat, parts=6
# Experiment 460/2880: random_6q (6q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 461/2880: random_6q (6q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 462/2880: random_6q (6q), local, noise=0.01, comm=1.0x, teleportation, parts=6
# Experiment 463/2880: random_6q (6q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 464/2880: random_6q (6q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 465/2880: random_6q (6q), local, noise=0.01, comm=1.05x, cat, parts=6
# Experiment 466/2880: random_6q (6q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 467/2880: random_6q (6q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 468/2880: random_6q (6q), local, noise=0.01, comm=1.05x, teleportation, parts=6
# Experiment 469/2880: random_6q (6q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 470/2880: random_6q (6q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 471/2880: random_6q (6q), local, noise=0.01, comm=1.1x, cat, parts=6
# Experiment 472/2880: random_6q (6q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 473/2880: random_6q (6q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 474/2880: random_6q (6q), local, noise=0.01, comm=1.1x, teleportation, parts=6
# Experiment 475/2880: random_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 476/2880: random_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 477/2880: random_6q (6q), local, noise=0.01, comm=1.2x, cat, parts=6
# Experiment 478/2880: random_6q (6q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 479/2880: random_6q (6q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 480/2880: random_6q (6q), local, noise=0.01, comm=1.2x, teleportation, parts=6
# Experiment 481/2880: random_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 482/2880: random_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 483/2880: random_6q (6q), local, noise=0.02, comm=1.0x, cat, parts=6
# Experiment 484/2880: random_6q (6q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 485/2880: random_6q (6q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 486/2880: random_6q (6q), local, noise=0.02, comm=1.0x, teleportation, parts=6
# Experiment 487/2880: random_6q (6q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 488/2880: random_6q (6q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 489/2880: random_6q (6q), local, noise=0.02, comm=1.05x, cat, parts=6
# Experiment 490/2880: random_6q (6q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 491/2880: random_6q (6q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 492/2880: random_6q (6q), local, noise=0.02, comm=1.05x, teleportation, parts=6
# Experiment 493/2880: random_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 494/2880: random_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 495/2880: random_6q (6q), local, noise=0.02, comm=1.1x, cat, parts=6
# Experiment 496/2880: random_6q (6q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 497/2880: random_6q (6q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 498/2880: random_6q (6q), local, noise=0.02, comm=1.1x, teleportation, parts=6
# Experiment 499/2880: random_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 500/2880: random_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 501/2880: random_6q (6q), local, noise=0.02, comm=1.2x, cat, parts=6
# Experiment 502/2880: random_6q (6q), local, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 503/2880: random_6q (6q), local, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 504/2880: random_6q (6q), local, noise=0.02, comm=1.2x, teleportation, parts=6
# Experiment 505/2880: random_6q (6q), local, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 506/2880: random_6q (6q), local, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 507/2880: random_6q (6q), local, noise=0.05, comm=1.0x, cat, parts=6
# Experiment 508/2880: random_6q (6q), local, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 509/2880: random_6q (6q), local, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 510/2880: random_6q (6q), local, noise=0.05, comm=1.0x, teleportation, parts=6
# Experiment 511/2880: random_6q (6q), local, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 512/2880: random_6q (6q), local, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 513/2880: random_6q (6q), local, noise=0.05, comm=1.05x, cat, parts=6
# Experiment 514/2880: random_6q (6q), local, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 515/2880: random_6q (6q), local, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 516/2880: random_6q (6q), local, noise=0.05, comm=1.05x, teleportation, parts=6
# Experiment 517/2880: random_6q (6q), local, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 518/2880: random_6q (6q), local, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 519/2880: random_6q (6q), local, noise=0.05, comm=1.1x, cat, parts=6
# Experiment 520/2880: random_6q (6q), local, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 521/2880: random_6q (6q), local, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 522/2880: random_6q (6q), local, noise=0.05, comm=1.1x, teleportation, parts=6
# Experiment 523/2880: random_6q (6q), local, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 524/2880: random_6q (6q), local, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 525/2880: random_6q (6q), local, noise=0.05, comm=1.2x, cat, parts=6
# Experiment 526/2880: random_6q (6q), local, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 527/2880: random_6q (6q), local, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 528/2880: random_6q (6q), local, noise=0.05, comm=1.2x, teleportation, parts=6
# Experiment 529/2880: qft_6q (6q), global, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 530/2880: qft_6q (6q), global, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 531/2880: qft_6q (6q), global, noise=0.01, comm=1.0x, cat, parts=6
# Experiment 532/2880: qft_6q (6q), global, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 533/2880: qft_6q (6q), global, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 534/2880: qft_6q (6q), global, noise=0.01, comm=1.0x, teleportation, parts=6
# Experiment 535/2880: qft_6q (6q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 536/2880: qft_6q (6q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 537/2880: qft_6q (6q), global, noise=0.01, comm=1.05x, cat, parts=6
# Experiment 538/2880: qft_6q (6q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 539/2880: qft_6q (6q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 540/2880: qft_6q (6q), global, noise=0.01, comm=1.05x, teleportation, parts=6
# Experiment 541/2880: qft_6q (6q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 542/2880: qft_6q (6q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 543/2880: qft_6q (6q), global, noise=0.01, comm=1.1x, cat, parts=6
# Experiment 544/2880: qft_6q (6q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 545/2880: qft_6q (6q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 546/2880: qft_6q (6q), global, noise=0.01, comm=1.1x, teleportation, parts=6
# Experiment 547/2880: qft_6q (6q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 548/2880: qft_6q (6q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 549/2880: qft_6q (6q), global, noise=0.01, comm=1.2x, cat, parts=6
# Experiment 550/2880: qft_6q (6q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 551/2880: qft_6q (6q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 552/2880: qft_6q (6q), global, noise=0.01, comm=1.2x, teleportation, parts=6
# Experiment 553/2880: qft_6q (6q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 554/2880: qft_6q (6q), global, noise=0.02, comm=1.0x, cat, parts=4
# ...
# Experiment 1568/2880: hardware_efficient_8q (8q), global, noise=0.01, comm=1.2x, teleportation, parts=8
# Experiment 1569/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 1570/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 1571/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=6
# Experiment 1572/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, cat, parts=8
# Experiment 1573/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 1574/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 1575/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, teleportation, parts=6
# Experiment 1576/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.0x, teleportation, parts=8
# Experiment 1577/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 1578/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 1579/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, cat, parts=6
# Experiment 1580/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, cat, parts=8
# Experiment 1581/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 1582/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 1583/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, teleportation, parts=6
# Experiment 1584/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.05x, teleportation, parts=8
# Experiment 1585/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 1586/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 1587/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=6
# Experiment 1588/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, cat, parts=8
# Experiment 1589/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 1590/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 1591/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, teleportation, parts=6
# Experiment 1592/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.1x, teleportation, parts=8
# Experiment 1593/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 1594/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 1595/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=6
# Experiment 1596/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, cat, parts=8
# Experiment 1597/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 1598/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 1599/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, teleportation, parts=6
# Experiment 1600/2880: hardware_efficient_8q (8q), global, noise=0.02, comm=1.2x, teleportation, parts=8
# Experiment 1601/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 1602/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 1603/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, cat, parts=6
# Experiment 1604/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, cat, parts=8
# Experiment 1605/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 1606/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 1607/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, teleportation, parts=6
# Experiment 1608/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.0x, teleportation, parts=8
# Experiment 1609/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 1610/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 1611/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, cat, parts=6
# Experiment 1612/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, cat, parts=8
# Experiment 1613/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 1614/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 1615/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, teleportation, parts=6
# Experiment 1616/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.05x, teleportation, parts=8
# Experiment 1617/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 1618/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 1619/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, cat, parts=6
# Experiment 1620/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, cat, parts=8
# Experiment 1621/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 1622/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 1623/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, teleportation, parts=6
# Experiment 1624/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.1x, teleportation, parts=8
# Experiment 1625/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 1626/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 1627/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, cat, parts=6
# Experiment 1628/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, cat, parts=8
# Experiment 1629/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 1630/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 1631/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, teleportation, parts=6
# Experiment 1632/2880: hardware_efficient_8q (8q), global, noise=0.05, comm=1.2x, teleportation, parts=8
# Experiment 1633/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 1634/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 1635/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, cat, parts=6
# Experiment 1636/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, cat, parts=8
# Experiment 1637/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 1638/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 1639/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, teleportation, parts=6
# Experiment 1640/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.0x, teleportation, parts=8
# Experiment 1641/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 1642/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 1643/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, cat, parts=6
# Experiment 1644/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, cat, parts=8
# Experiment 1645/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 1646/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 1647/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, teleportation, parts=6
# Experiment 1648/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.05x, teleportation, parts=8
# Experiment 1649/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 1650/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 1651/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, cat, parts=6
# Experiment 1652/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, cat, parts=8
# Experiment 1653/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 1654/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 1655/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, teleportation, parts=6
# Experiment 1656/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.1x, teleportation, parts=8
# Experiment 1657/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 1658/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 1659/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, cat, parts=6
# Experiment 1660/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, cat, parts=8
# Experiment 1661/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 1662/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 1663/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, teleportation, parts=6
# Experiment 1664/2880: hardware_efficient_8q (8q), local, noise=0.01, comm=1.2x, teleportation, parts=8
# Experiment 1665/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 1666/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 1667/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, cat, parts=6
# Experiment 1668/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, cat, parts=8
# Experiment 1669/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 1670/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 1671/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, teleportation, parts=6
# Experiment 1672/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.0x, teleportation, parts=8
# Experiment 1673/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 1674/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 1675/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, cat, parts=6
# Experiment 1676/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, cat, parts=8
# Experiment 1677/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 1678/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 1679/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, teleportation, parts=6
# Experiment 1680/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.05x, teleportation, parts=8
# Experiment 1681/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 1682/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 1683/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, cat, parts=6
# Experiment 1684/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, cat, parts=8
# Experiment 1685/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 1686/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 1687/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, teleportation, parts=6
# Experiment 1688/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.1x, teleportation, parts=8
# Experiment 1689/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 1690/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 1691/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, cat, parts=6
# Experiment 1692/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, cat, parts=8
# Experiment 1693/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 1694/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 1695/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, teleportation, parts=6
# Experiment 1696/2880: hardware_efficient_8q (8q), local, noise=0.02, comm=1.2x, teleportation, parts=8
# Experiment 1697/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, cat, parts=2
# Experiment 1698/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, cat, parts=4
# Experiment 1699/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, cat, parts=6
# Experiment 1700/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, cat, parts=8
# Experiment 1701/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, teleportation, parts=2
# Experiment 1702/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, teleportation, parts=4
# Experiment 1703/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, teleportation, parts=6
# Experiment 1704/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.0x, teleportation, parts=8
# Experiment 1705/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, cat, parts=2
# Experiment 1706/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, cat, parts=4
# Experiment 1707/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, cat, parts=6
# Experiment 1708/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, cat, parts=8
# Experiment 1709/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, teleportation, parts=2
# Experiment 1710/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, teleportation, parts=4
# Experiment 1711/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, teleportation, parts=6
# Experiment 1712/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.05x, teleportation, parts=8
# Experiment 1713/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, cat, parts=2
# Experiment 1714/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, cat, parts=4
# Experiment 1715/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, cat, parts=6
# Experiment 1716/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, cat, parts=8
# Experiment 1717/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, teleportation, parts=2
# Experiment 1718/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, teleportation, parts=4
# Experiment 1719/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, teleportation, parts=6
# Experiment 1720/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.1x, teleportation, parts=8
# Experiment 1721/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, cat, parts=2
# Experiment 1722/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, cat, parts=4
# Experiment 1723/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, cat, parts=6
# Experiment 1724/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, cat, parts=8
# Experiment 1725/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, teleportation, parts=2
# Experiment 1726/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, teleportation, parts=4
# Experiment 1727/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, teleportation, parts=6
# Experiment 1728/2880: hardware_efficient_8q (8q), local, noise=0.05, comm=1.2x, teleportation, parts=8
#
# Results saved to results.csv
#
# Experiments completed!
# Total results: 1728

# %% [markdown]
# ## 6. Results

# %%
"""
Script to plot Error Reduction vs Number of Partitions
Compares Global vs Local optimization strategies
"""

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12

def plot_error_reduction_vs_partitions(csv_file='results.csv', output_file='error_reduction_vs_partitions.png'):
    """
    Plot error reduction vs number of partitions for global and local strategies.
    
    Args:
        csv_file: Path to results CSV file
        output_file: Path to save the plot
    """
    # Load data
    df = pd.read_csv(csv_file)
    
    print(f"Loaded {len(df)} experiments")
    print(f"Unique partition counts: {sorted(df['num_partitions_tested'].unique())}")
    print(f"Strategies: {df['strategy'].unique()}")
    
    # Filter out rows with missing error_reduction
    df_clean = df.dropna(subset=['error_reduction', 'num_partitions_tested'])
    
    if len(df_clean) == 0:
        print("ERROR: No valid data with error_reduction values!")
        print("Make sure your experiments have completed successfully.")
        return
    
    # Group by strategy and num_partitions, calculate mean and std
    grouped = df_clean.groupby(['strategy', 'num_partitions_tested'])['error_reduction'].agg(['mean', 'std', 'count']).reset_index()
    
    print("\nGrouped data:")
    print(grouped)
    
    # Create the plot
    fig, ax = plt.subplots(figsize=(12, 8))
    
    # Define colors and markers for each strategy
    colors = {'global': '#2E86AB', 'local': '#A23B72'}
    markers = {'global': 'o', 'local': 's'}
    
    # Plot each strategy
    for strategy in ['global', 'local']:
        strategy_data = grouped[grouped['strategy'] == strategy].sort_values('num_partitions_tested')
        
        if len(strategy_data) == 0:
            print(f"WARNING: No data for {strategy} strategy")
            continue
        
        x = strategy_data['num_partitions_tested']
        y = strategy_data['mean']
        yerr = strategy_data['std']
        
        # Plot line with error bars
        ax.errorbar(x, y, yerr=yerr, 
                   label=f'{strategy.capitalize()} Optimization',
                   marker=markers[strategy], 
                   markersize=10,
                   linewidth=2.5,
                   capsize=5,
                   capthick=2,
                   color=colors[strategy],
                   alpha=0.8)
        
        # Add data point count as text
        for xi, yi, count in zip(x, y, strategy_data['count']):
            ax.annotate(f'n={int(count)}', 
                       xy=(xi, yi), 
                       xytext=(5, 5),
                       textcoords='offset points',
                       fontsize=9,
                       alpha=0.7)
    
    # Formatting
    ax.set_xlabel('Number of Partitions', fontsize=14, fontweight='bold')
    ax.set_ylabel('Error Reduction (ZNE Improvement)', fontsize=14, fontweight='bold')
    ax.set_title('Error Reduction vs Number of Partitions\nGlobal vs Local Optimization with ZNE', 
                fontsize=16, fontweight='bold', pad=20)
    
    # Add horizontal line at y=0 (no improvement)
    ax.axhline(y=0, color='red', linestyle='--', linewidth=1.5, alpha=0.5, label='No Improvement')
    
    # Legend
    ax.legend(loc='best', fontsize=12, framealpha=0.9)
    
    # Grid
    ax.grid(True, alpha=0.3, linestyle='--')
    
    # Set x-axis to show integer partition counts
    if len(grouped['num_partitions_tested'].unique()) > 0:
        partition_counts = sorted(grouped['num_partitions_tested'].unique())
        ax.set_xticks(partition_counts)
        ax.set_xticklabels([int(p) for p in partition_counts])
    
    # Add note about error reduction interpretation
    note_text = "Error Reduction > 0: ZNE improves results\nError Reduction < 0: ZNE makes results worse"
    ax.text(0.02, 0.98, note_text, 
           transform=ax.transAxes,
           fontsize=10,
           verticalalignment='top',
           bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.tight_layout()
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    print(f"\n✓ Plot saved to {output_file}")
    plt.show()
    
    # Print summary statistics
    print("\n" + "="*60)
    print("SUMMARY STATISTICS")
    print("="*60)
    for strategy in ['global', 'local']:
        strategy_data = grouped[grouped['strategy'] == strategy]
        if len(strategy_data) > 0:
            print(f"\n{strategy.upper()} Strategy:")
            print(f"  Partition counts tested: {sorted(strategy_data['num_partitions_tested'].values)}")
            print(f"  Mean error reduction: {strategy_data['mean'].mean():.4f}")
            print(f"  Best partition count: {strategy_data.loc[strategy_data['mean'].idxmax(), 'num_partitions_tested']:.0f} "
                  f"(reduction: {strategy_data['mean'].max():.4f})")


def generate_sample_data_for_testing():
    """
    Generate sample data to test the plotting function.
    This creates synthetic data with different partition counts.
    """
    np.random.seed(42)
    
    data = []
    partition_counts = [1, 2, 4, 6, 8, 10]
    
    for strategy in ['global', 'local']:
        for n_parts in partition_counts:
            for _ in range(5):  # 5 trials per configuration
                # Global tends to do better with more partitions
                if strategy == 'global':
                    base_reduction = 0.3 + 0.05 * n_parts
                else:
                    base_reduction = 0.25 + 0.03 * n_parts
                
                # Add some noise
                error_reduction = base_reduction + np.random.normal(0, 0.1)
                
                data.append({
                    'origin': 'random_4q',
                    'strategy': strategy,
                    'num_partitions_tested': n_parts,
                    'error_reduction': error_reduction,
                    'noisy_error': 0.05,
                    'zne_error': 0.05 * (1 - error_reduction)
                })
    
    df = pd.DataFrame(data)
    df.to_csv('sample_results.csv', index=False)
    print("Generated sample_results.csv for testing")
    return df


if __name__ == "__main__":
    import sys
    
    # Check if results file exists
    import os
    
    if not os.path.exists('results.csv'):
        print("WARNING: results.csv not found!")
        print("Generating sample data for demonstration...")
        generate_sample_data_for_testing()
        plot_error_reduction_vs_partitions('sample_results.csv', 'sample_plot.png')
    else:
        # Load and check the actual data
        df = pd.read_csv('results.csv')
        
        print("Current data summary:")
        print(f"  Total experiments: {len(df)}")
        print(f"  Partition counts: {sorted(df['num_partitions_tested'].unique())}")
        print(f"  Strategies: {df['strategy'].unique()}")
        
        # Check if we have enough data
        n_partitions = len(df['num_partitions_tested'].unique())
        
        if n_partitions < 2:
            print("\n⚠️  WARNING: Only 1 partition count in data!")
            print("   You need to run experiments with multiple partition counts.")
            print("   Run this to generate more data:")
            print("   >>> from simulate import run_batch_experiments")
            print("   >>> from alg import create_random_circuit")
            print("   >>> circuits = [(create_random_circuit(10, 5, seed=i), f'random_{i}') for i in range(3)]")
            print("   >>> df = run_batch_experiments(circuits, partition_counts=[2, 4, 6, 8])")
            print("\nGenerating sample plot with synthetic data for reference...")
            generate_sample_data_for_testing()
            plot_error_reduction_vs_partitions('sample_results.csv', 'sample_plot.png')
        else:
            # Plot the actual data
            plot_error_reduction_vs_partitions('results.csv', 'error_reduction_vs_partitions.png')
# Out:
# Current data summary:
#   Total experiments: 1728
#   Partition counts: [1, 2, 4, 6, 8]
#   Strategies: ['global' 'local']
# Loaded 1728 experiments
# Unique partition counts: [1, 2, 4, 6, 8]
# Strategies: ['global' 'local']
#
# Grouped data:
#   strategy  num_partitions_tested          mean           std  count
# 0   global                      1 -7.309096e-01  2.802711e+00    643
# 1   global                      2  8.287954e-16  3.893575e-17     72
# 2   global                      4  8.354232e-16  3.717052e-17     72
# 3   global                      6  8.332983e-16  3.781778e-17     48
# 4   global                      8  8.261335e-16  3.999507e-17     24
# 5    local                      1 -9.229885e-01  3.372752e+00    642
# 6    local                      2  8.383665e-16  3.827245e-17     72
# 7    local                      4  8.296733e-16  3.975984e-17     72
# 8    local                      6  8.299630e-16  4.081825e-17     48
# 9    local                      8  8.370719e-16  3.929832e-17     24
#
# ✓ Plot saved to error_reduction_vs_partitions.png
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# GLOBAL Strategy:
#   Partition counts tested: [1, 2, 4, 6, 8]
#   Mean error reduction: -0.1462
#   Best partition count: 4 (reduction: 0.0000)
#
# LOCAL Strategy:
#   Partition counts tested: [1, 2, 4, 6, 8]
#   Mean error reduction: -0.1846
#   Best partition count: 2 (reduction: 0.0000)

# %% [markdown]
# # MQT bench

# %%
import sys
sys.argv = ['mqt.py', '3']  

# %run mqt.py
# Out:
# MQT Bench Circuit Experiment Runner
# ======================================================================
#
# Options:
#   1. Quick test (1-2 circuits, 2 partition counts) - ~5 minutes
#   2. Medium test (2-3 circuits per origin, 4 partition counts) - ~30 minutes
#   3. Full experiment (3 circuits per origin, all partitions) - ~1-2 hours
#
# Running full experiment...
# ======================================================================
# MQT BENCH ZNE PARTITIONING EXPERIMENTS
# ======================================================================
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQTBench for QASM files...
# Found 3877 QASM files
#   Loading: graphstate_nativegates_ibm_qiskit_opt0_4.qasm -> graphstate_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: graphstate_nativegates_ibm_opt0_4q, depth=18
#   Loading: qpeinexact_nativegates_ibm_qiskit_opt0_18.qasm -> qpeinexact_nativegates_ibm_opt0 (18 qubits)
#     ✓ Loaded: qpeinexact_nativegates_ibm_opt0_18q, depth=203
#   Loading: qwalk-noancilla_indep_qiskit_13.qasm -> qwalk-noancilla_indep (13 qubits)
#     ✓ Loaded: qwalk-noancilla_indep_13q, depth=98131
#   Loading: qpeexact_nativegates_ibm_qiskit_opt0_86.qasm -> qpeexact_nativegates_ibm_opt0 (86 qubits)
#     ✓ Loaded: qpeexact_nativegates_ibm_opt0_86q, depth=1019
#   Loading: su2random_indep_qiskit_54.qasm -> su2random_indep (54 qubits)
#     ✓ Loaded: su2random_indep_54q, depth=217
#   Loading: qpeexact_indep_qiskit_54.qasm -> qpeexact_indep (54 qubits)
#     ✓ Loaded: qpeexact_indep_54q, depth=160
#   Loading: qft_nativegates_ibm_qiskit_opt0_94.qasm -> qft_nativegates_ibm_opt0 (94 qubits)
#     ✓ Loaded: qft_nativegates_ibm_opt0_94q, depth=750
#   Loading: ghz_indep_qiskit_100.qasm -> ghz_indep (100 qubits)
#     ✓ Loaded: ghz_indep_100q, depth=100
#   Loading: wstate_indep_qiskit_26.qasm -> wstate_indep (26 qubits)
#     ✓ Loaded: wstate_indep_26q, depth=52
#   Loading: graphstate_indep_qiskit_30.qasm -> graphstate_indep (30 qubits)
#     ✓ Loaded: graphstate_indep_30q, depth=8
#   Loading: dj_nativegates_ibm_qiskit_opt0_8.qasm -> dj_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: dj_nativegates_ibm_opt0_8q, depth=15
#   Loading: qpeexact_nativegates_ibm_qiskit_opt0_69.qasm -> qpeexact_nativegates_ibm_opt0 (69 qubits)
#     ✓ Loaded: qpeexact_nativegates_ibm_opt0_69q, depth=815
#   Loading: ae_nativegates_ibm_qiskit_opt0_24.qasm -> ae_nativegates_ibm_opt0 (24 qubits)
#     ✓ Loaded: ae_nativegates_ibm_opt0_24q, depth=476
#   Loading: realamprandom_nativegates_ibm_qiskit_opt0_90.qasm -> realamprandom_nativegates_ibm_opt0 (90 qubits)
#     ✓ Loaded: realamprandom_nativegates_ibm_opt0_90q, depth=377
#   Loading: random_nativegates_ibm_qiskit_opt0_95.qasm -> random_nativegates_ibm_opt0 (95 qubits)
#     ✓ Loaded: random_nativegates_ibm_opt0_95q, depth=3129
#   Loading: random_indep_qiskit_100.qasm -> random_indep (100 qubits)
#     ✓ Loaded: random_indep_100q, depth=1335
#   Loading: graphstate_indep_qiskit_120.qasm -> graphstate_indep (120 qubits)
#     ✓ Loaded: graphstate_indep_120q, depth=8
#   Loading: qnn_indep_qiskit_8.qasm -> qnn_indep (8 qubits)
#     ✓ Loaded: qnn_indep_8q, depth=74
#   Loading: twolocalrandom_indep_qiskit_128.qasm -> twolocalrandom_indep (128 qubits)
#     ✓ Loaded: twolocalrandom_indep_128q, depth=513
#   Loading: qftentangled_nativegates_ibm_qiskit_opt0_42.qasm -> qftentangled_nativegates_ibm_opt0 (42 qubits)
#     ✓ Loaded: qftentangled_nativegates_ibm_opt0_42q, depth=338
#   Loading: graphstate_nativegates_ibm_qiskit_opt0_112.qasm -> graphstate_nativegates_ibm_opt0 (112 qubits)
#     ✓ Loaded: graphstate_nativegates_ibm_opt0_112q, depth=37
#   Loading: su2random_nativegates_ibm_qiskit_opt0_128.qasm -> su2random_nativegates_ibm_opt0 (128 qubits)
#     ✓ Loaded: su2random_nativegates_ibm_opt0_128q, depth=533
#   Loading: twolocalrandom_indep_qiskit_27.qasm -> twolocalrandom_indep (27 qubits)
#     ✓ Loaded: twolocalrandom_indep_27q, depth=109
#   Loading: ghz_indep_qiskit_81.qasm -> ghz_indep (81 qubits)
#     ✓ Loaded: ghz_indep_81q, depth=81
#   Loading: ghz_nativegates_ibm_qiskit_opt0_48.qasm -> ghz_nativegates_ibm_opt0 (48 qubits)
#     ✓ Loaded: ghz_nativegates_ibm_opt0_48q, depth=50
#   Loading: su2random_nativegates_ibm_qiskit_opt0_15.qasm -> su2random_nativegates_ibm_opt0 (15 qubits)
#     ✓ Loaded: su2random_nativegates_ibm_opt0_15q, depth=81
#   Loading: qaoa_indep_qiskit_6.qasm -> qaoa_indep (6 qubits)
#     ✓ Loaded: qaoa_indep_6q, depth=8
#   Loading: realamprandom_nativegates_ibm_qiskit_opt0_125.qasm -> realamprandom_nativegates_ibm_opt0 (125 qubits)
#     ✓ Loaded: realamprandom_nativegates_ibm_opt0_125q, depth=517
#   Loading: graphstate_indep_qiskit_88.qasm -> graphstate_indep (88 qubits)
#     ✓ Loaded: graphstate_indep_88q, depth=6
#   Loading: twolocalrandom_nativegates_ibm_qiskit_opt0_107.qasm -> twolocalrandom_nativegates_ibm_opt0 (107 qubits)
#     ✓ Loaded: twolocalrandom_nativegates_ibm_opt0_107q, depth=445
#   Loading: realamprandom_nativegates_ibm_qiskit_opt0_28.qasm -> realamprandom_nativegates_ibm_opt0 (28 qubits)
#     ✓ Loaded: realamprandom_nativegates_ibm_opt0_28q, depth=129
#   Loading: wstate_nativegates_ibm_qiskit_opt0_127.qasm -> wstate_nativegates_ibm_opt0 (127 qubits)
#     ✓ Loaded: wstate_nativegates_ibm_opt0_127q, depth=1143
#   Loading: qftentangled_indep_qiskit_85.qasm -> qftentangled_indep (85 qubits)
#     ✓ Loaded: qftentangled_indep_85q, depth=172
#   Loading: wstate_indep_qiskit_112.qasm -> wstate_indep (112 qubits)
#     ✓ Loaded: wstate_indep_112q, depth=224
#   Loading: qft_indep_qiskit_116.qasm -> qft_indep (116 qubits)
#     ✓ Loaded: qft_indep_116q, depth=232
#   Loading: twolocalrandom_nativegates_ibm_qiskit_opt0_53.qasm -> twolocalrandom_nativegates_ibm_opt0 (53 qubits)
#     ✓ Loaded: twolocalrandom_nativegates_ibm_opt0_53q, depth=229
#   Loading: ae_nativegates_ibm_qiskit_opt0_73.qasm -> ae_nativegates_ibm_opt0 (73 qubits)
#     ✓ Loaded: ae_nativegates_ibm_opt0_73q, depth=1505
#   Loading: ae_indep_qiskit_118.qasm -> ae_indep (118 qubits)
#     ✓ Loaded: ae_indep_118q, depth=701
#   Loading: wstate_indep_qiskit_71.qasm -> wstate_indep (71 qubits)
#     ✓ Loaded: wstate_indep_71q, depth=142
#   Loading: ae_indep_qiskit_53.qasm -> ae_indep (53 qubits)
#     ✓ Loaded: ae_indep_53q, depth=311
#   Loading: qftentangled_nativegates_ibm_qiskit_opt0_15.qasm -> qftentangled_nativegates_ibm_opt0 (15 qubits)
#     ✓ Loaded: qftentangled_nativegates_ibm_opt0_15q, depth=122
#   Loading: qftentangled_indep_qiskit_112.qasm -> qftentangled_indep (112 qubits)
#     ✓ Loaded: qftentangled_indep_112q, depth=226
#   Loading: ghz_indep_qiskit_39.qasm -> ghz_indep (39 qubits)
#     ✓ Loaded: ghz_indep_39q, depth=39
#   Loading: shor_15_4_indep_qiskit_18.qasm -> shor_15_4_indep (18 qubits)
#     ✓ Loaded: shor_15_4_indep_18q, depth=6213
#   Loading: wstate_nativegates_ibm_qiskit_opt0_52.qasm -> wstate_nativegates_ibm_opt0 (52 qubits)
#     ✓ Loaded: wstate_nativegates_ibm_opt0_52q, depth=468
#   Loading: su2random_nativegates_ibm_qiskit_opt0_42.qasm -> su2random_nativegates_ibm_opt0 (42 qubits)
#     ✓ Loaded: su2random_nativegates_ibm_opt0_42q, depth=189
#   Loading: qpeexact_nativegates_ibm_qiskit_opt0_102.qasm -> qpeexact_nativegates_ibm_opt0 (102 qubits)
#     ✓ Loaded: qpeexact_nativegates_ibm_opt0_102q, depth=1211
#   Loading: qnn_nativegates_ibm_qiskit_opt0_104.qasm -> qnn_nativegates_ibm_opt0 (104 qubits)
#     ✓ Loaded: qnn_nativegates_ibm_opt0_104q, depth=1048
#   Loading: twolocalrandom_indep_qiskit_70.qasm -> twolocalrandom_indep (70 qubits)
#     ✓ Loaded: twolocalrandom_indep_70q, depth=281
#   Loading: qaoa_nativegates_ibm_qiskit_opt0_4.qasm -> qaoa_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: qaoa_nativegates_ibm_opt0_4q, depth=28
#   Loading: qnn_indep_qiskit_84.qasm -> qnn_indep (84 qubits)
#     ✓ Loaded: qnn_indep_84q, depth=834
#   Loading: qpeinexact_nativegates_ibm_qiskit_opt0_59.qasm -> qpeinexact_nativegates_ibm_opt0 (59 qubits)
#     ✓ Loaded: qpeinexact_nativegates_ibm_opt0_59q, depth=695
#   Loading: portfoliovqe_indep_qiskit_8.qasm -> portfoliovqe_indep (8 qubits)
#     ✓ Loaded: portfoliovqe_indep_8q, depth=33
#   Loading: qftentangled_indep_qiskit_93.qasm -> qftentangled_indep (93 qubits)
#     ✓ Loaded: qftentangled_indep_93q, depth=188
#   Loading: vqe_indep_qiskit_11.qasm -> vqe_indep (11 qubits)
#     ✓ Loaded: vqe_indep_11q, depth=15
#   Loading: twolocalrandom_nativegates_ibm_qiskit_opt0_111.qasm -> twolocalrandom_nativegates_ibm_opt0 (111 qubits)
#     ✓ Loaded: twolocalrandom_nativegates_ibm_opt0_111q, depth=461
#   Loading: su2random_indep_qiskit_15.qasm -> su2random_indep (15 qubits)
#     ✓ Loaded: su2random_indep_15q, depth=61
#   Loading: qpeexact_indep_qiskit_15.qasm -> qpeexact_indep (15 qubits)
#     ✓ Loaded: qpeexact_indep_15q, depth=43
#   Loading: qpeexact_indep_qiskit_127.qasm -> qpeexact_indep (127 qubits)
#     ✓ Loaded: qpeexact_indep_127q, depth=379
#   Loading: ae_indep_qiskit_45.qasm -> ae_indep (45 qubits)
#     ✓ Loaded: ae_indep_45q, depth=263
#   Loading: pricingput_nativegates_ibm_qiskit_opt0_19.qasm -> pricingput_nativegates_ibm_opt0 (19 qubits)
#     ✓ Loaded: pricingput_nativegates_ibm_opt0_19q, depth=3817
#   Loading: ae_nativegates_ibm_qiskit_opt0_65.qasm -> ae_nativegates_ibm_opt0 (65 qubits)
#     ✓ Loaded: ae_nativegates_ibm_opt0_65q, depth=1337
#   Loading: qpeinexact_indep_qiskit_48.qasm -> qpeinexact_indep (48 qubits)
#     ✓ Loaded: qpeinexact_indep_48q, depth=142
#   Loading: qft_indep_qiskit_100.qasm -> qft_indep (100 qubits)
#     ✓ Loaded: qft_indep_100q, depth=200
#   Loading: qnn_indep_qiskit_123.qasm -> qnn_indep (123 qubits)
#     ✓ Loaded: qnn_indep_123q, depth=1224
#   Loading: wstate_nativegates_ibm_qiskit_opt0_44.qasm -> wstate_nativegates_ibm_opt0 (44 qubits)
#     ✓ Loaded: wstate_nativegates_ibm_opt0_44q, depth=396
#   Loading: su2random_indep_qiskit_108.qasm -> su2random_indep (108 qubits)
#     ✓ Loaded: su2random_indep_108q, depth=433
#   Loading: ghz_nativegates_ibm_qiskit_opt0_124.qasm -> ghz_nativegates_ibm_opt0 (124 qubits)
#     ✓ Loaded: ghz_nativegates_ibm_opt0_124q, depth=126
#   Loading: realamprandom_indep_qiskit_120.qasm -> realamprandom_indep (120 qubits)
#     ✓ Loaded: realamprandom_indep_120q, depth=481
#   Loading: qnn_nativegates_ibm_qiskit_opt0_112.qasm -> qnn_nativegates_ibm_opt0 (112 qubits)
#     ✓ Loaded: qnn_nativegates_ibm_opt0_112q, depth=1128
#   Loading: qft_nativegates_ibm_qiskit_opt0_82.qasm -> qft_nativegates_ibm_opt0 (82 qubits)
#     ✓ Loaded: qft_nativegates_ibm_opt0_82q, depth=654
#   Loading: random_indep_qiskit_116.qasm -> random_indep (116 qubits)
#     ✓ Loaded: random_indep_116q, depth=1532
#   Loading: random_nativegates_ibm_qiskit_opt0_83.qasm -> random_nativegates_ibm_opt0 (83 qubits)
#     ✓ Loaded: random_nativegates_ibm_opt0_83q, depth=2744
#   Loading: qftentangled_nativegates_ibm_qiskit_opt0_54.qasm -> qftentangled_nativegates_ibm_opt0 (54 qubits)
#     ✓ Loaded: qftentangled_nativegates_ibm_opt0_54q, depth=434
#   Loading: qpeinexact_indep_qiskit_118.qasm -> qpeinexact_indep (118 qubits)
#     ✓ Loaded: qpeinexact_indep_118q, depth=352
#   Loading: portfoliovqe_indep_qiskit_17.qasm -> portfoliovqe_indep (17 qubits)
#     ✓ Loaded: portfoliovqe_indep_17q, depth=69
#   Loading: qpeinexact_nativegates_ibm_qiskit_opt0_127.qasm -> qpeinexact_nativegates_ibm_opt0 (127 qubits)
#     ✓ Loaded: qpeinexact_nativegates_ibm_opt0_127q, depth=1511
#   Loading: pricingput_nativegates_ibm_qiskit_opt0_7.qasm -> pricingput_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: pricingput_nativegates_ibm_opt0_7q, depth=273
#   Loading: qwalk-v-chain_nativegates_ibm_qiskit_opt0_13.qasm -> qwalk-v-chain_nativegates_ibm_opt0 (13 qubits)
#     ✓ Loaded: qwalk-v-chain_nativegates_ibm_opt0_13q, depth=2202
#   Loading: graphstate_nativegates_ibm_qiskit_opt0_104.qasm -> graphstate_nativegates_ibm_opt0 (104 qubits)
#     ✓ Loaded: graphstate_nativegates_ibm_opt0_104q, depth=30
#   Loading: vqe_nativegates_ibm_qiskit_opt0_4.qasm -> vqe_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: vqe_nativegates_ibm_opt0_4q, depth=20
#   Loading: qwalk-noancilla_indep_qiskit_7.qasm -> qwalk-noancilla_indep (7 qubits)
#     ✓ Loaded: qwalk-noancilla_indep_7q, depth=1507
#   Loading: qpeinexact_indep_qiskit_64.qasm -> qpeinexact_indep (64 qubits)
#     ✓ Loaded: qpeinexact_indep_64q, depth=190
#   Loading: qft_indep_qiskit_76.qasm -> qft_indep (76 qubits)
#     ✓ Loaded: qft_indep_76q, depth=152
#   Loading: realamprandom_indep_qiskit_67.qasm -> realamprandom_indep (67 qubits)
#     ✓ Loaded: realamprandom_indep_67q, depth=269
#   Loading: random_indep_qiskit_76.qasm -> random_indep (76 qubits)
#     ✓ Loaded: random_indep_76q, depth=956
#   Loading: qft_nativegates_ibm_qiskit_opt0_16.qasm -> qft_nativegates_ibm_opt0 (16 qubits)
#     ✓ Loaded: qft_nativegates_ibm_opt0_16q, depth=126
#   Loading: qnn_nativegates_ibm_qiskit_opt0_26.qasm -> qnn_nativegates_ibm_opt0 (26 qubits)
#     ✓ Loaded: qnn_nativegates_ibm_opt0_26q, depth=268
#   Loading: realamprandom_indep_qiskit_88.qasm -> realamprandom_indep (88 qubits)
#     ✓ Loaded: realamprandom_indep_88q, depth=353
#   Loading: groundstate_medium_indep_qiskit_12.qasm -> groundstate_medium_indep (12 qubits)
#     ✓ Loaded: groundstate_medium_indep_12q, depth=36
#   Loading: random_nativegates_ibm_qiskit_opt0_17.qasm -> random_nativegates_ibm_opt0 (17 qubits)
#     ✓ Loaded: random_nativegates_ibm_opt0_17q, depth=409
#   Loading: dj_indep_qiskit_26.qasm -> dj_indep (26 qubits)
#     ✓ Loaded: dj_indep_26q, depth=27
#   Loading: ghz_nativegates_ibm_qiskit_opt0_25.qasm -> ghz_nativegates_ibm_opt0 (25 qubits)
#     ✓ Loaded: ghz_nativegates_ibm_opt0_25q, depth=27
#   Loading: dj_nativegates_ibm_qiskit_opt0_115.qasm -> dj_nativegates_ibm_opt0 (115 qubits)
#     ✓ Loaded: dj_nativegates_ibm_opt0_115q, depth=122
#   Loading: dj_nativegates_ibm_qiskit_opt0_70.qasm -> dj_nativegates_ibm_opt0 (70 qubits)
#     ✓ Loaded: dj_nativegates_ibm_opt0_70q, depth=77
#   Loading: dj_indep_qiskit_127.qasm -> dj_indep (127 qubits)
#     ✓ Loaded: dj_indep_127q, depth=128
#   Loading: qwalk-v-chain_nativegates_ibm_qiskit_opt0_7.qasm -> qwalk-v-chain_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: qwalk-v-chain_nativegates_ibm_opt0_7q, depth=582
#   Loading: dj_indep_qiskit_71.qasm -> dj_indep (71 qubits)
#     ✓ Loaded: dj_indep_71q, depth=72
#   Loading: qaoa_nativegates_ibm_qiskit_opt0_14.qasm -> qaoa_nativegates_ibm_opt0 (14 qubits)
#     ✓ Loaded: qaoa_nativegates_ibm_opt0_14q, depth=31
#   Loading: portfoliovqe_nativegates_ibm_qiskit_opt0_10.qasm -> portfoliovqe_nativegates_ibm_opt0 (10 qubits)
#     ✓ Loaded: portfoliovqe_nativegates_ibm_opt0_10q, depth=217
#   Loading: qwalk-v-chain_nativegates_ibm_qiskit_opt0_29.qasm -> qwalk-v-chain_nativegates_ibm_opt0 (29 qubits)
#     ✓ Loaded: qwalk-v-chain_nativegates_ibm_opt0_29q, depth=11274
#   Loading: qwalk-noancilla_nativegates_ibm_qiskit_opt0_7.qasm -> qwalk-noancilla_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: qwalk-noancilla_nativegates_ibm_opt0_7q, depth=3674
#   Loading: pricingput_nativegates_ibm_qiskit_opt0_23.qasm -> pricingput_nativegates_ibm_opt0 (23 qubits)
#     ✓ Loaded: pricingput_nativegates_ibm_opt0_23q, depth=13210
#   Loading: qwalk-v-chain_indep_qiskit_11.qasm -> qwalk-v-chain_indep (11 qubits)
#     ✓ Loaded: qwalk-v-chain_indep_11q, depth=163
#   Loading: groundstate_small_indep_qiskit_4.qasm -> groundstate_small_indep (4 qubits)
#     ✓ Loaded: groundstate_small_indep_4q, depth=12
#   Loading: portfoliovqe_nativegates_ibm_qiskit_opt0_7.qasm -> portfoliovqe_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: portfoliovqe_nativegates_ibm_opt0_7q, depth=151
#   Loading: qwalk-noancilla_nativegates_ibm_qiskit_opt0_10.qasm -> qwalk-noancilla_nativegates_ibm_opt0 (10 qubits)
#     ✓ Loaded: qwalk-noancilla_nativegates_ibm_opt0_10q, depth=30374
#   Loading: vqe_nativegates_ibm_qiskit_opt0_16.qasm -> vqe_nativegates_ibm_opt0 (16 qubits)
#     ✓ Loaded: vqe_nativegates_ibm_opt0_16q, depth=32
#   Loading: qaoa_nativegates_ibm_qiskit_opt0_8.qasm -> qaoa_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: qaoa_nativegates_ibm_opt0_8q, depth=28
#   Loading: qwalk-v-chain_indep_qiskit_31.qasm -> qwalk-v-chain_indep (31 qubits)
#     ✓ Loaded: qwalk-v-chain_indep_31q, depth=1363
#   Loading: shor_9_4_nativegates_ibm_qiskit_opt0_18.qasm -> shor_9_4_nativegates_ibm_opt0 (18 qubits)
#     ✓ Loaded: shor_9_4_nativegates_ibm_opt0_18q, depth=18744
#   Loading: groundstate_large_nativegates_ibm_qiskit_opt0_14.qasm -> groundstate_large_nativegates_ibm_opt0 (14 qubits)
#     ✓ Loaded: groundstate_large_nativegates_ibm_opt0_14q, depth=218
#   Loading: qwalk-v-chain_indep_qiskit_27.qasm -> qwalk-v-chain_indep (27 qubits)
#     ✓ Loaded: qwalk-v-chain_indep_27q, depth=1027
#   Loading: portfoliovqe_indep_qiskit_4.qasm -> portfoliovqe_indep (4 qubits)
#     ✓ Loaded: portfoliovqe_indep_4q, depth=17
#   Loading: qaoa_indep_qiskit_12.qasm -> qaoa_indep (12 qubits)
#     ✓ Loaded: qaoa_indep_12q, depth=10
#   Loading: vqe_nativegates_ibm_qiskit_opt0_8.qasm -> vqe_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: vqe_nativegates_ibm_opt0_8q, depth=24
#   Loading: vqe_indep_qiskit_6.qasm -> vqe_indep (6 qubits)
#     ✓ Loaded: vqe_indep_6q, depth=10
#   Loading: portfolioqaoa_indep_qiskit_15.qasm -> portfolioqaoa_indep (15 qubits)
#     ✓ Loaded: portfolioqaoa_indep_15q, depth=61
#   Loading: portfolioqaoa_nativegates_ibm_qiskit_opt0_15.qasm -> portfolioqaoa_nativegates_ibm_opt0 (15 qubits)
#     ✓ Loaded: portfolioqaoa_nativegates_ibm_opt0_15q, depth=192
#   Loading: portfolioqaoa_nativegates_ibm_qiskit_opt0_14.qasm -> portfolioqaoa_nativegates_ibm_opt0 (14 qubits)
#     ✓ Loaded: portfolioqaoa_nativegates_ibm_opt0_14q, depth=180
#   Loading: grover-v-chain_indep_qiskit_15.qasm -> grover-v-chain_indep (15 qubits)
#     ✓ Loaded: grover-v-chain_indep_15q, depth=17597
#   Loading: pricingcall_indep_qiskit_23.qasm -> pricingcall_indep (23 qubits)
#     ✓ Loaded: pricingcall_indep_23q, depth=4094
#   Loading: pricingcall_nativegates_ibm_qiskit_opt0_21.qasm -> pricingcall_nativegates_ibm_opt0 (21 qubits)
#     ✓ Loaded: pricingcall_nativegates_ibm_opt0_21q, depth=6970
#   Loading: pricingput_indep_qiskit_25.qasm -> pricingput_indep (25 qubits)
#     ✓ Loaded: pricingput_indep_25q, depth=7434
#   Loading: portfolioqaoa_indep_qiskit_14.qasm -> portfolioqaoa_indep (14 qubits)
#     ✓ Loaded: portfolioqaoa_indep_14q, depth=57
#   Loading: vqe_indep_qiskit_7.qasm -> vqe_indep (7 qubits)
#     ✓ Loaded: vqe_indep_7q, depth=11
#   Loading: qaoa_indep_qiskit_13.qasm -> qaoa_indep (13 qubits)
#     ✓ Loaded: qaoa_indep_13q, depth=9
#   Loading: qwalk-noancilla_nativegates_ibm_qiskit_opt0_11.qasm -> qwalk-noancilla_nativegates_ibm_opt0 (11 qubits)
#     ✓ Loaded: qwalk-noancilla_nativegates_ibm_opt0_11q, depth=61034
#   Loading: portfoliovqe_nativegates_ibm_qiskit_opt0_6.qasm -> portfoliovqe_nativegates_ibm_opt0 (6 qubits)
#     ✓ Loaded: portfoliovqe_nativegates_ibm_opt0_6q, depth=129
#   Loading: pricingcall_indep_qiskit_19.qasm -> pricingcall_indep (19 qubits)
#     ✓ Loaded: pricingcall_indep_19q, depth=1138
#   Loading: qwalk-noancilla_indep_qiskit_6.qasm -> qwalk-noancilla_indep (6 qubits)
#     ✓ Loaded: qwalk-noancilla_indep_6q, depth=763
#   Loading: tsp_nativegates_ibm_qiskit_opt0_16.qasm -> tsp_nativegates_ibm_opt0 (16 qubits)
#     ✓ Loaded: tsp_nativegates_ibm_opt0_16q, depth=125
#   Loading: pricingput_indep_qiskit_13.qasm -> pricingput_indep (13 qubits)
#     ✓ Loaded: pricingput_indep_13q, depth=204
#   Loading: pricingcall_nativegates_ibm_qiskit_opt0_17.qasm -> pricingcall_nativegates_ibm_opt0 (17 qubits)
#     ✓ Loaded: pricingcall_nativegates_ibm_opt0_17q, depth=2134
#   Loading: pricingcall_indep_qiskit_15.qasm -> pricingcall_indep (15 qubits)
#     ✓ Loaded: pricingcall_indep_15q, depth=342
#   Loading: grover-noancilla_nativegates_ibm_qiskit_opt0_5.qasm -> grover-noancilla_nativegates_ibm_opt0 (5 qubits)
#     ✓ Loaded: grover-noancilla_nativegates_ibm_opt0_5q, depth=345
#   Loading: portfolioqaoa_indep_qiskit_13.qasm -> portfolioqaoa_indep (13 qubits)
#     ✓ Loaded: portfolioqaoa_indep_13q, depth=53
#   Loading: grover-noancilla_indep_qiskit_11.qasm -> grover-noancilla_indep (11 qubits)
#     ✓ Loaded: grover-noancilla_indep_11q, depth=76676
#   Loading: grover-v-chain_indep_qiskit_4.qasm -> grover-v-chain_indep (4 qubits)
#     ✓ Loaded: grover-v-chain_indep_4q, depth=33
#   Loading: portfolioqaoa_nativegates_ibm_qiskit_opt0_4.qasm -> portfolioqaoa_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: portfolioqaoa_nativegates_ibm_opt0_4q, depth=60
#   Loading: groundstate_large_indep_qiskit_14.qasm -> groundstate_large_indep (14 qubits)
#     ✓ Loaded: groundstate_large_indep_14q, depth=42
#   Loading: grover-noancilla_indep_qiskit_7.qasm -> grover-noancilla_indep (7 qubits)
#     ✓ Loaded: grover-noancilla_indep_7q, depth=1123
#   Loading: grover-noancilla_nativegates_ibm_qiskit_opt0_9.qasm -> grover-noancilla_nativegates_ibm_opt0 (9 qubits)
#     ✓ Loaded: grover-noancilla_nativegates_ibm_opt0_9q, depth=23091
#   Loading: grover-v-chain_nativegates_ibm_qiskit_opt0_4.qasm -> grover-v-chain_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: grover-v-chain_nativegates_ibm_opt0_4q, depth=119
#   Loading: tsp_indep_qiskit_9.qasm -> tsp_indep (9 qubits)
#     ✓ Loaded: tsp_indep_9q, depth=22
#   Loading: grover-v-chain_nativegates_ibm_qiskit_opt0_5.qasm -> grover-v-chain_nativegates_ibm_opt0 (5 qubits)
#     ✓ Loaded: grover-v-chain_nativegates_ibm_opt0_5q, depth=334
#   Loading: grover-v-chain_indep_qiskit_9.qasm -> grover-v-chain_indep (9 qubits)
#     ✓ Loaded: grover-v-chain_indep_9q, depth=800
#   Loading: routing_nativegates_ibm_qiskit_opt0_6.qasm -> routing_nativegates_ibm_opt0 (6 qubits)
#     ✓ Loaded: routing_nativegates_ibm_opt0_6q, depth=29
#   Loading: pricingcall_nativegates_ibm_qiskit_opt0_7.qasm -> pricingcall_nativegates_ibm_opt0 (7 qubits)
#     ✓ Loaded: pricingcall_nativegates_ibm_opt0_7q, depth=274
#   Loading: pricingput_indep_qiskit_5.qasm -> pricingput_indep (5 qubits)
#     ✓ Loaded: pricingput_indep_5q, depth=35
#   Loading: grover-noancilla_nativegates_ibm_qiskit_opt0_8.qasm -> grover-noancilla_nativegates_ibm_opt0 (8 qubits)
#     ✓ Loaded: grover-noancilla_nativegates_ibm_opt0_8q, depth=7715
#   Loading: grover-noancilla_indep_qiskit_6.qasm -> grover-noancilla_indep (6 qubits)
#     ✓ Loaded: grover-noancilla_indep_6q, depth=401
#   Loading: tsp_indep_qiskit_4.qasm -> tsp_indep (4 qubits)
#     ✓ Loaded: tsp_indep_4q, depth=17
#   Loading: tsp_indep_qiskit_16.qasm -> tsp_indep (16 qubits)
#     ✓ Loaded: tsp_indep_16q, depth=29
#   Loading: grover-v-chain_nativegates_ibm_qiskit_opt0_9.qasm -> grover-v-chain_nativegates_ibm_opt0 (9 qubits)
#     ✓ Loaded: grover-v-chain_nativegates_ibm_opt0_9q, depth=2320
#   Loading: tsp_nativegates_ibm_qiskit_opt0_4.qasm -> tsp_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: tsp_nativegates_ibm_opt0_4q, depth=77
#   Loading: routing_nativegates_ibm_qiskit_opt0_12.qasm -> routing_nativegates_ibm_opt0 (12 qubits)
#     ✓ Loaded: routing_nativegates_ibm_opt0_12q, depth=35
#   Loading: tsp_nativegates_ibm_qiskit_opt0_9.qasm -> tsp_nativegates_ibm_opt0 (9 qubits)
#     ✓ Loaded: tsp_nativegates_ibm_opt0_9q, depth=97
#   Loading: routing_indep_qiskit_6.qasm -> routing_indep (6 qubits)
#     ✓ Loaded: routing_indep_6q, depth=13
#   Loading: groundstate_medium_nativegates_ibm_qiskit_opt0_12.qasm -> groundstate_medium_nativegates_ibm_opt0 (12 qubits)
#     ✓ Loaded: groundstate_medium_nativegates_ibm_opt0_12q, depth=188
#   Loading: shor_9_4_indep_qiskit_18.qasm -> shor_9_4_indep (18 qubits)
#     ✓ Loaded: shor_9_4_indep_18q, depth=6213
#   Loading: groundstate_small_nativegates_ibm_qiskit_opt0_4.qasm -> groundstate_small_nativegates_ibm_opt0 (4 qubits)
#     ✓ Loaded: groundstate_small_nativegates_ibm_opt0_4q, depth=68
#   Loading: shor_15_4_nativegates_ibm_qiskit_opt0_18.qasm -> shor_15_4_nativegates_ibm_opt0 (18 qubits)
#     ✓ Loaded: shor_15_4_nativegates_ibm_opt0_18q, depth=18744
#   Loading: routing_indep_qiskit_12.qasm -> routing_indep (12 qubits)
#     ✓ Loaded: routing_indep_12q, depth=19
#
# ✓ Total circuits loaded: 164
#   Origins: ['graphstate_nativegates_ibm_opt0', 'qpeinexact_nativegates_ibm_opt0', 'qwalk-noancilla_indep', 'qpeexact_nativegates_ibm_opt0', 'su2random_indep', 'qpeexact_indep', 'qft_nativegates_ibm_opt0', 'ghz_indep', 'wstate_indep', 'graphstate_indep', 'dj_nativegates_ibm_opt0', 'ae_nativegates_ibm_opt0', 'realamprandom_nativegates_ibm_opt0', 'random_nativegates_ibm_opt0', 'random_indep', 'qnn_indep', 'twolocalrandom_indep', 'qftentangled_nativegates_ibm_opt0', 'su2random_nativegates_ibm_opt0', 'ghz_nativegates_ibm_opt0', 'qaoa_indep', 'twolocalrandom_nativegates_ibm_opt0', 'wstate_nativegates_ibm_opt0', 'qftentangled_indep', 'qft_indep', 'ae_indep', 'shor_15_4_indep', 'qnn_nativegates_ibm_opt0', 'qaoa_nativegates_ibm_opt0', 'portfoliovqe_indep', 'vqe_indep', 'pricingput_nativegates_ibm_opt0', 'qpeinexact_indep', 'realamprandom_indep', 'qwalk-v-chain_nativegates_ibm_opt0', 'vqe_nativegates_ibm_opt0', 'groundstate_medium_indep', 'dj_indep', 'portfoliovqe_nativegates_ibm_opt0', 'qwalk-noancilla_nativegates_ibm_opt0', 'qwalk-v-chain_indep', 'groundstate_small_indep', 'shor_9_4_nativegates_ibm_opt0', 'groundstate_large_nativegates_ibm_opt0', 'portfolioqaoa_indep', 'portfolioqaoa_nativegates_ibm_opt0', 'grover-v-chain_indep', 'pricingcall_indep', 'pricingcall_nativegates_ibm_opt0', 'pricingput_indep', 'tsp_nativegates_ibm_opt0', 'grover-noancilla_nativegates_ibm_opt0', 'grover-noancilla_indep', 'groundstate_large_indep', 'grover-v-chain_nativegates_ibm_opt0', 'tsp_indep', 'routing_nativegates_ibm_opt0', 'routing_indep', 'groundstate_medium_nativegates_ibm_opt0', 'shor_9_4_indep', 'groundstate_small_nativegates_ibm_opt0', 'shor_15_4_nativegates_ibm_opt0']
#   Qubit range: 4 - 128
#
# 2. RUNNING EXPERIMENTS
# ----------------------------------------------------------------------
# Configuration:
#   Circuits: 164
#   Strategies: ['global', 'local']
#   Partition counts: [2, 4, 6, 8, 10]
#   Noise levels: [0.01, 0.02]
#   Communication multipliers: [1.0, 1.05, 1.1, 1.2]
#   Primitives: ['cat', 'teleportation']
#   Shots: 1024
#
# Running 26240 experiments...
# Experiment 1/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 2/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 3/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 4/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 5/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 6/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 7/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 8/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 9/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 10/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 11/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 12/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 13/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 14/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 15/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 16/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 17/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 18/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 19/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 20/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 21/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 22/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 23/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 24/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 25/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 26/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 27/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 28/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 29/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 30/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 31/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 32/26240: graphstate_nativegates_ibm_opt0_4q (4q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 33/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 34/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 35/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 36/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 37/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 38/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 39/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 40/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 41/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 42/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 43/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 44/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 45/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 46/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 47/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 48/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 49/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 50/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 51/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 52/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 53/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 54/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 55/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 56/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 57/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 58/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 59/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 60/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 61/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 62/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 63/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 64/26240: graphstate_nativegates_ibm_opt0_4q (4q), local, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 65/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, cat, parts=2
#   Error: division by zero
# Experiment 66/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, cat, parts=4
#   Error: division by zero
# Experiment 67/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, cat, parts=6
#   Error: division by zero
# Experiment 68/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, cat, parts=8
#   Error: division by zero
# Experiment 69/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, cat, parts=10
#   Error: division by zero
# Experiment 70/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, teleportation, parts=2
#   Error: division by zero
# Experiment 71/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, teleportation, parts=4
#   Error: division by zero
# Experiment 72/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, teleportation, parts=6
#   Error: division by zero
# Experiment 73/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, teleportation, parts=8
#   Error: division by zero
# Experiment 74/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.0x, teleportation, parts=10
#   Error: division by zero
# Experiment 75/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, cat, parts=2
#   Error: division by zero
# Experiment 76/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, cat, parts=4
#   Error: division by zero
# Experiment 77/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, cat, parts=6
#   Error: division by zero
# Experiment 78/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, cat, parts=8
#   Error: division by zero
# Experiment 79/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, cat, parts=10
#   Error: division by zero
# Experiment 80/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, teleportation, parts=2
#   Error: division by zero
# Experiment 81/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, teleportation, parts=4
#   Error: division by zero
# Experiment 82/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, teleportation, parts=6
#   Error: division by zero
# Experiment 83/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, teleportation, parts=8
#   Error: division by zero
# Experiment 84/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.05x, teleportation, parts=10
#   Error: division by zero
# Experiment 85/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, cat, parts=2
#   Error: division by zero
# Experiment 86/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, cat, parts=4
#   Error: division by zero
# Experiment 87/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, cat, parts=6
#   Error: division by zero
# Experiment 88/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, cat, parts=8
#   Error: division by zero
# Experiment 89/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, cat, parts=10
#   Error: division by zero
# Experiment 90/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, teleportation, parts=2
#   Error: division by zero
# Experiment 91/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, teleportation, parts=4
#   Error: division by zero
# Experiment 92/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, teleportation, parts=6
#   Error: division by zero
# Experiment 93/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, teleportation, parts=8
#   Error: division by zero
# Experiment 94/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.1x, teleportation, parts=10
#   Error: division by zero
# Experiment 95/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, cat, parts=2
#   Error: division by zero
# Experiment 96/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, cat, parts=4
#   Error: division by zero
# Experiment 97/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, cat, parts=6
#   Error: division by zero
# Experiment 98/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, cat, parts=8
#   Error: division by zero
# Experiment 99/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, cat, parts=10
#   Error: division by zero
# Experiment 100/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, teleportation, parts=2
#   Error: division by zero
# Experiment 101/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, teleportation, parts=4
#   Error: division by zero
# Experiment 102/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, teleportation, parts=6
#   Error: division by zero
# Experiment 103/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, teleportation, parts=8
#   Error: division by zero
# Experiment 104/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.01, comm=1.2x, teleportation, parts=10
#   Error: division by zero
# Experiment 105/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, cat, parts=2
#   Error: division by zero
# Experiment 106/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, cat, parts=4
#   Error: division by zero
# Experiment 107/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, cat, parts=6
#   Error: division by zero
# Experiment 108/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, cat, parts=8
#   Error: division by zero
# Experiment 109/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, cat, parts=10
#   Error: division by zero
# Experiment 110/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, teleportation, parts=2
#   Error: division by zero
# Experiment 111/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, teleportation, parts=4
#   Error: division by zero
# Experiment 112/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, teleportation, parts=6
#   Error: division by zero
# Experiment 113/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, teleportation, parts=8
#   Error: division by zero
# Experiment 114/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.0x, teleportation, parts=10
#   Error: division by zero
# Experiment 115/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, cat, parts=2
#   Error: division by zero
# Experiment 116/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, cat, parts=4
#   Error: division by zero
# Experiment 117/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, cat, parts=6
#   Error: division by zero
# Experiment 118/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, cat, parts=8
#   Error: division by zero
# Experiment 119/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, cat, parts=10
#   Error: division by zero
# Experiment 120/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, teleportation, parts=2
#   Error: division by zero
# Experiment 121/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, teleportation, parts=4
#   Error: division by zero
# Experiment 122/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, teleportation, parts=6
#   Error: division by zero
# Experiment 123/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, teleportation, parts=8
#   Error: division by zero
# Experiment 124/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.05x, teleportation, parts=10
#   Error: division by zero
# Experiment 125/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, cat, parts=2
#   Error: division by zero
# Experiment 126/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, cat, parts=4
#   Error: division by zero
# Experiment 127/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, cat, parts=6
#   Error: division by zero
# Experiment 128/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, cat, parts=8
#   Error: division by zero
# Experiment 129/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, cat, parts=10
#   Error: division by zero
# Experiment 130/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, teleportation, parts=2
#   Error: division by zero
# Experiment 131/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, teleportation, parts=4
#   Error: division by zero
# Experiment 132/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, teleportation, parts=6
#   Error: division by zero
# Experiment 133/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, teleportation, parts=8
#   Error: division by zero
# Experiment 134/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.1x, teleportation, parts=10
#   Error: division by zero
# Experiment 135/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, cat, parts=2
#   Error: division by zero
# Experiment 136/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, cat, parts=4
#   Error: division by zero
# Experiment 137/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, cat, parts=6
#   Error: division by zero
# Experiment 138/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, cat, parts=8
#   Error: division by zero
# Experiment 139/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, cat, parts=10
#   Error: division by zero
# Experiment 140/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, teleportation, parts=2
#   Error: division by zero
# Experiment 141/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, teleportation, parts=4
#   Error: division by zero
# Experiment 142/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, teleportation, parts=6
#   Error: division by zero
# Experiment 143/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, teleportation, parts=8
#   Error: division by zero
# Experiment 144/26240: graphstate_nativegates_ibm_opt0_112q (112q), global, noise=0.02, comm=1.2x, teleportation, parts=10
#   Error: division by zero
# Experiment 145/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, cat, parts=2
#   Error: division by zero
# Experiment 146/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, cat, parts=4
#   Error: division by zero
# Experiment 147/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, cat, parts=6
#   Error: division by zero
# Experiment 148/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, cat, parts=8
#   Error: division by zero
# Experiment 149/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, cat, parts=10
#   Error: division by zero
# Experiment 150/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, teleportation, parts=2
#   Error: division by zero
# Experiment 151/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, teleportation, parts=4
#   Error: division by zero
# Experiment 152/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, teleportation, parts=6
#   Error: division by zero
# Experiment 153/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, teleportation, parts=8
#   Error: division by zero
# Experiment 154/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.0x, teleportation, parts=10
#   Error: division by zero
# Experiment 155/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, cat, parts=2
#   Error: division by zero
# Experiment 156/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, cat, parts=4
#   Error: division by zero
# Experiment 157/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, cat, parts=6
#   Error: division by zero
# Experiment 158/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, cat, parts=8
#   Error: division by zero
# Experiment 159/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, cat, parts=10
#   Error: division by zero
# Experiment 160/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, teleportation, parts=2
#   Error: division by zero
# Experiment 161/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, teleportation, parts=4
#   Error: division by zero
# Experiment 162/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, teleportation, parts=6
#   Error: division by zero
# Experiment 163/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, teleportation, parts=8
#   Error: division by zero
# Experiment 164/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.05x, teleportation, parts=10
#   Error: division by zero
# Experiment 165/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.1x, cat, parts=2
#   Error: division by zero
# Experiment 166/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.1x, cat, parts=4
#   Error: division by zero
# Experiment 167/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.1x, cat, parts=6
#   Error: division by zero
# Experiment 168/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.1x, cat, parts=8
#   Error: division by zero
# Experiment 169/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.1x, cat, parts=10
#   Error: division by zero
# Experiment 170/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.1x, teleportation, parts=2
#   Error: division by zero
# Experiment 171/26240: graphstate_nativegates_ibm_opt0_112q (112q), local, noise=0.01, comm=1.1x, teleportation, parts=4
#   Error: division by zero
# ...
# Experiment 393/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.0x, teleportation, parts=8
# Experiment 394/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.0x, teleportation, parts=10
# Experiment 395/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 396/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 397/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, cat, parts=6
# Experiment 398/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, cat, parts=8
# Experiment 399/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, cat, parts=10
# Experiment 400/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 401/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 402/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, teleportation, parts=6
# Experiment 403/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, teleportation, parts=8
# Experiment 404/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.05x, teleportation, parts=10
# Experiment 405/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 406/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 407/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, cat, parts=6
# Experiment 408/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, cat, parts=8
# Experiment 409/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, cat, parts=10
# Experiment 410/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 411/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 412/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, teleportation, parts=6
# Experiment 413/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, teleportation, parts=8
# Experiment 414/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.1x, teleportation, parts=10
# Experiment 415/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 416/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 417/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, cat, parts=6
# Experiment 418/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, cat, parts=8
# Experiment 419/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, cat, parts=10
# Experiment 420/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 421/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 422/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, teleportation, parts=6
# Experiment 423/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, teleportation, parts=8
# Experiment 424/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.01, comm=1.2x, teleportation, parts=10
# Experiment 425/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 426/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 427/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, cat, parts=6
# Experiment 428/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, cat, parts=8
# Experiment 429/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, cat, parts=10
# Experiment 430/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 431/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 432/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, teleportation, parts=6
# Experiment 433/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, teleportation, parts=8
# Experiment 434/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.0x, teleportation, parts=10
# Experiment 435/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 436/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 437/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, cat, parts=6
# Experiment 438/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, cat, parts=8
# Experiment 439/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, cat, parts=10
# Experiment 440/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 441/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 442/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, teleportation, parts=6
# Experiment 443/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, teleportation, parts=8
# Experiment 444/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.05x, teleportation, parts=10
# Experiment 445/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 446/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 447/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, cat, parts=6
# Experiment 448/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, cat, parts=8
# Experiment 449/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, cat, parts=10
# Experiment 450/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 451/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 452/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, teleportation, parts=6
# Experiment 453/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, teleportation, parts=8
# Experiment 454/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.1x, teleportation, parts=10
# Experiment 455/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, cat, parts=2
# Experiment 456/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, cat, parts=4
# Experiment 457/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, cat, parts=6
# Experiment 458/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, cat, parts=8
# Experiment 459/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, cat, parts=10
# Experiment 460/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, teleportation, parts=2
# Experiment 461/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, teleportation, parts=4
# Experiment 462/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, teleportation, parts=6
# Experiment 463/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, teleportation, parts=8
# Experiment 464/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), global, noise=0.02, comm=1.2x, teleportation, parts=10
# Experiment 465/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, cat, parts=2
# Experiment 466/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, cat, parts=4
# Experiment 467/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, cat, parts=6
# Experiment 468/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, cat, parts=8
# Experiment 469/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, cat, parts=10
# Experiment 470/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, teleportation, parts=2
# Experiment 471/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, teleportation, parts=4
# Experiment 472/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, teleportation, parts=6
# Experiment 473/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, teleportation, parts=8
# Experiment 474/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.0x, teleportation, parts=10
# Experiment 475/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, cat, parts=2
# Experiment 476/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, cat, parts=4
# Experiment 477/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, cat, parts=6
# Experiment 478/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, cat, parts=8
# Experiment 479/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, cat, parts=10
# Experiment 480/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, teleportation, parts=2
# Experiment 481/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, teleportation, parts=4
# Experiment 482/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, teleportation, parts=6
# Experiment 483/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, teleportation, parts=8
# Experiment 484/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.05x, teleportation, parts=10
# Experiment 485/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, cat, parts=2
# Experiment 486/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, cat, parts=4
# Experiment 487/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, cat, parts=6
# Experiment 488/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, cat, parts=8
# Experiment 489/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, cat, parts=10
# Experiment 490/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, teleportation, parts=2
# Experiment 491/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, teleportation, parts=4
# Experiment 492/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, teleportation, parts=6
# Experiment 493/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, teleportation, parts=8
# Experiment 494/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.1x, teleportation, parts=10
# Experiment 495/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, cat, parts=2
# Experiment 496/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, cat, parts=4
# Experiment 497/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, cat, parts=6
# Experiment 498/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, cat, parts=8
# Experiment 499/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, cat, parts=10
# Experiment 500/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, teleportation, parts=2
# Experiment 501/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, teleportation, parts=4
# Experiment 502/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, teleportation, parts=6
# Experiment 503/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, teleportation, parts=8
# Experiment 504/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.01, comm=1.2x, teleportation, parts=10
# Experiment 505/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, cat, parts=2
# Experiment 506/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, cat, parts=4
# Experiment 507/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, cat, parts=6
# Experiment 508/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, cat, parts=8
# Experiment 509/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, cat, parts=10
# Experiment 510/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, teleportation, parts=2
# Experiment 511/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, teleportation, parts=4
# Experiment 512/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, teleportation, parts=6
# Experiment 513/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, teleportation, parts=8
# Experiment 514/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.0x, teleportation, parts=10
# Experiment 515/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, cat, parts=2
# Experiment 516/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, cat, parts=4
# Experiment 517/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, cat, parts=6
# Experiment 518/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, cat, parts=8
# Experiment 519/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, cat, parts=10
# Experiment 520/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, teleportation, parts=2
# Experiment 521/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, teleportation, parts=4
# Experiment 522/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, teleportation, parts=6
# Experiment 523/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, teleportation, parts=8
# Experiment 524/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.05x, teleportation, parts=10
# Experiment 525/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, cat, parts=2
# Experiment 526/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, cat, parts=4
# Experiment 527/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, cat, parts=6
# Experiment 528/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, cat, parts=8
# Experiment 529/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, cat, parts=10
# Experiment 530/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, teleportation, parts=2
# Experiment 531/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, teleportation, parts=4
# Experiment 532/26240: qpeinexact_nativegates_ibm_opt0_18q (18q), local, noise=0.02, comm=1.1x, teleportation, parts=6
