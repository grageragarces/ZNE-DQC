# %%
import sys
sys.argv = ['mqt.py']  

# %run test.py
# Out:
# Running comprehensive diagnostics...
# This will help identify what's wrong with your simulation.
#
# ...
# PARTITIONING DIAGNOSTIC TEST
# ...
#
# Original circuit:
#   Qubits: 6
#   Depth: 7
#   Gates: 16
#
# ----------------------------------------------------------------------
# Testing 2 partitions:
# ----------------------------------------------------------------------
#
# GLOBAL Strategy:
#   ERROR: 4
#
# LOCAL Strategy:
#   ERROR: 4
#
# ----------------------------------------------------------------------
# Testing 4 partitions:
# ----------------------------------------------------------------------
#
# GLOBAL Strategy:
#   ERROR: 4
#
# LOCAL Strategy:
#   ERROR: 4
#
# ...
# NOISE SIMULATION DIAGNOSTIC TEST
# ...
#
# 1. Executing WITHOUT noise:
#    Unique outcomes: 8
#    Top 3 results: [('0111', 191), ('0011', 186), ('1011', 170)]
#
# 2. Executing WITH noise:
#    Unique outcomes: 12
#    Top 3 results: [('0111', 189), ('0011', 184), ('1011', 169)]
#
# ...
