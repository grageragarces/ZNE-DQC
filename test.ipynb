# %%
import sys
sys.argv = ['mqt.py']  

# %run test.py
# Out:
# Running comprehensive diagnostics...
# This will help identify what's wrong with your simulation.
#
# ...
# PARTITIONING DIAGNOSTIC TEST
# ...
#
# Original circuit:
#   Qubits: 6
#   Depth: 7
#   Gates: 16
#
# ----------------------------------------------------------------------
# Testing 2 partitions:
# ----------------------------------------------------------------------
#
# GLOBAL Strategy:
#   ERROR: 4
#
# LOCAL Strategy:
#   ERROR: 4
#
# ----------------------------------------------------------------------
# Testing 4 partitions:
# ----------------------------------------------------------------------
#
# GLOBAL Strategy:
#   ERROR: 4
#
# LOCAL Strategy:
#   ERROR: 4
#
# ...
# NOISE SIMULATION DIAGNOSTIC TEST
# ...
# /Users/mariagragera/Desktop/ZNE-DQC/simulate.py:21: UserWarning: Mitiq import failed: No module named 'ply'. ZNE will use simplified fallback implementation.
#   warnings.warn(f"Mitiq import failed: {e}. ZNE will use simplified fallback implementation.")
# 1. Executing WITHOUT noise:
# ...
