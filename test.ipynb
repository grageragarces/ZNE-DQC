# %%
import sys
sys.argv = ['mqt.py']  

# %run test.py
# Out:
# Running comprehensive diagnostics...
# This will help identify what's wrong with your simulation.
#
# ...
# PARTITIONING DIAGNOSTIC TEST
# ...
#
# Original circuit:
#   Qubits: 6
#   Depth: 7
#   Gates: 16
#
# ----------------------------------------------------------------------
# Testing 2 partitions:
# ----------------------------------------------------------------------
#
# GLOBAL Strategy:
#   Output qubits: 6
#   Output depth: 27
#   Output gates: 48
#   First 5 gates:
#     0: t on qubits [0]
#     1: t on qubits [0]
#     2: tdg on qubits [0]
#     3: cz on qubits [0, 1]
#     4: cz on qubits [0, 1]
#
# LOCAL Strategy:
#   Output qubits: 6
#   Output depth: 27
#   Output gates: 48
#   First 5 gates:
#     0: t on qubits [0]
#     1: t on qubits [0]
#     2: tdg on qubits [0]
#     3: cz on qubits [0, 1]
#     4: cz on qubits [0, 1]
#
# COMPARISON:
#   ⚠️  WARNING: Circuits are IDENTICAL!
#   This suggests partitioning isn't working differently.
#
# ...
