# %%
from mqt import run_mqt_bench_experiments_incremental

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQTBench_reduced',
    min_qubits=2,
    max_qubits=31,
    max_circuits_per_origin=4,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
# Out:
# ...
# MQT BENCH ZNE PARTITIONING EXPERIMENTS (INCREMENTAL SAVE)
# ...
# Simulator qubit limit: 31
#
# 1. DISCOVERING CIRCUITS
# ----------------------------------------------------------------------
# Scanning MQTBench_reduced for QASM files...
# Found 16 QASM files
#   Loading: dj_indep_qiskit_30.qasm -> dj_indep (30 qubits)
#     LOADED: dj_indep_30q, depth=31
#   Loading: dj_indep_qiskit_10.qasm -> dj_indep (10 qubits)
#     LOADED: dj_indep_10q, depth=11
#   Loading: dj_indep_qiskit_2.qasm -> dj_indep (2 qubits)
#     LOADED: dj_indep_2q, depth=3
#   Loading: qft_indep_qiskit_20.qasm -> qft_indep (20 qubits)
#     LOADED: qft_indep_20q, depth=40
#   Loading: ae_indep_qiskit_2.qasm -> ae_indep (2 qubits)
#     LOADED: ae_indep_2q, depth=5
#   Loading: dj_indep_qiskit_20.qasm -> dj_indep (20 qubits)
#     LOADED: dj_indep_20q, depth=21
#   Loading: qft_indep_qiskit_30.qasm -> qft_indep (30 qubits)
#     LOADED: qft_indep_30q, depth=60
# ...

# %%
test_df = run_mqt_bench_experiments_incremental(
    mqt_folder='MQTBench_reduced',
    min_qubits=2,
    max_qubits=31,
    max_circuits_per_origin=4,
    strategies=['global'],
    noise_levels=[0.001, 0.005, 0.01, 0.015, 0.02],
    comm_noise_multipliers=[1.0,1.1,1.2],
    comm_primitives=['cat'],
    partition_counts=[2, 4, 6],
    shots=200,
    output_file='results.csv',
    progress_file='test_progress.json'
)
